# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## L2 SVM Compare metrics: ADlasso - DEGn

# %%
# read metrics from ADlasso features
# ad_svm_metrics = pd.read_csv(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_GSE\L2_by_lossdiff\SVM_classifiers_rbf_cuda\SVM_metrics_loss_diff_l2_AD_nostdscale_rbf_cuda.csv", index_col=0)
ad_svm_metrics = pd.read_csv('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_GSE/L2_by_lossdiff/SVM_classifiers_rbf_cuda/SVM_metrics_loss_diff_l2_AD_nostdscale_rbf_cuda.csv', index_col=0)

# read metrics from DEGn
# deg_svm_metrics = pd.read_csv(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_GSE\L2_by_lossdiff\L2_DEG\L2_loss_diff_DEGn_SVM_rbf_metrics.csv", index_col=0)
deg_svm_metrics = pd.read_csv('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_GSE/L2_by_lossdiff/L2_DEG/L2_loss_diff_DEGn_SVM_rbf_metrics.csv', index_col=0)

ad_svm_metrics.columns = deg_svm_metrics.columns

# %%
ad_svm_metrics
# Out:
#                    Accuracy  Precision    Recall  F1-score   ROC-AUC  \
# ASDC               0.999529   0.000000  0.000000  0.000000  0.500000
# B_intermediate     0.990573   0.818220  0.479177  0.604185  0.738777
# B_memory           0.996129   0.920779  0.885840  0.902830  0.942127
# B_naive            0.994575   0.950018  0.935537  0.942692  0.966535
# CD14_Mono          0.989815   0.975004  0.986706  0.980819  0.988818
# CD16_Mono          0.993795   0.896489  0.951146  0.922960  0.973337
# CD4_CTL            0.996685   0.904963  0.772509  0.833252  0.885813
# CD4_Naive          0.965900   0.848082  0.833869  0.840876  0.907882
# CD4_Proliferating  0.999691   0.821654  0.696732  0.750740  0.848312
# CD4_TCM            0.963728   0.814350  0.784820  0.799263  0.883342
# CD4_TEM            0.976548   0.743386  0.174548  0.282468  0.586452
# CD8_Naive          0.991577   0.943227  0.929418  0.936249  0.962714
# CD8_Proliferating  0.999521   0.900000  0.193333  0.306524  0.596655
# ...

# %%
deg_svm_metrics
# Out:
#                    Accuracy  Precision    Recall  F1-score   ROC-AUC  \
# ASDC               0.999784   0.900000  0.600000  0.720000  0.799985
# B_intermediate     0.984978   0.000000  0.000000  0.000000  0.500000
# B_memory           0.990758   0.783228  0.753425  0.768037  0.874551
# B_naive            0.994127   0.939040  0.937824  0.938432  0.967386
# CD14_Mono          0.990078   0.975466  0.987234  0.981314  0.989166
# CD16_Mono          0.993385   0.898331  0.936709  0.917119  0.966199
# CD4_CTL            0.993014   0.853801  0.420749  0.563707  0.709984
# CD4_Naive          0.958457   0.829455  0.774886  0.801242  0.877791
# CD4_Proliferating  0.999629   0.857143  0.545455  0.666667  0.772696
# CD4_TCM            0.926712   0.700330  0.356279  0.472290  0.670412
# CD4_TEM            0.973541   0.000000  0.000000  0.000000  0.500000
# CD8_Naive          0.979074   0.849173  0.833798  0.841415  0.911617
# CD8_Proliferating  0.999475   1.000000  0.055556  0.105263  0.527778
# ...

# %%
metric_diff = ad_svm_metrics - deg_svm_metrics
metric_diff
# Out:
#                    Accuracy  Precision    Recall  F1-score   ROC-AUC  \
# ASDC              -0.000255  -0.900000 -0.600000 -0.720000 -0.299985
# B_intermediate     0.005595   0.818220  0.479177  0.604185  0.238777
# B_memory           0.005371   0.137551  0.132415  0.134793  0.067576
# B_naive            0.000448   0.010978 -0.002287  0.004260 -0.000851
# CD14_Mono         -0.000262  -0.000462 -0.000527 -0.000495 -0.000347
# CD16_Mono          0.000410  -0.001842  0.014437  0.005841  0.007138
# CD4_CTL            0.003671   0.051162  0.351759  0.269546  0.175829
# CD4_Naive          0.007443   0.018627  0.058984  0.039634  0.030090
# CD4_Proliferating  0.000062  -0.035489  0.151277  0.084073  0.075616
# CD4_TCM            0.037016   0.114020  0.428541  0.326973  0.212930
# CD4_TEM            0.003007   0.743386  0.174548  0.282468  0.086452
# CD8_Naive          0.012503   0.094054  0.095620  0.094834  0.051097
# CD8_Proliferating  0.000046  -0.100000  0.137778  0.201261  0.068877
# ...

# %%
# Plot DEGn as features
cols = ['Precision', 'F1-score', 'ROC-AUC', 'PR-AUC', 'MCC']
ax = deg_svm_metrics[cols].plot.bar(rot=90, figsize=(15,6), title='SVM using DEGn as features (kernel=rbf)')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
# Plot ADlasso features minus DEGn as features

cols = ['Precision', 'F1-score', 'ROC-AUC', 'PR-AUC', 'MCC']
ax = metric_diff[cols].plot.bar(rot=90, figsize=(15,6), title='SVM metrics: ADlasso features minus DEGn as features (kernel=rbf)')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Add red dotted horizontal line at y = 0
ax.axhline(y=0, color='red', linestyle='dotted')
