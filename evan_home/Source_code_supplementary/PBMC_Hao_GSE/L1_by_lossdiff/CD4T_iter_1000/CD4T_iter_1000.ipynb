# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import os

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E2FD-3ACB
#
#  Directory of c:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_GSE\L1_by_lossdiff\CD4T_iter_1000
#
# 12/27/2023  20:21    <DIR>          .
# 12/27/2023  20:21    <DIR>          ..
# 12/27/2023  20:09            63,159 CD4T_iter_1000.ipynb
# 12/27/2023  17:26             4,559 CD4T_iter_1000.py
# 12/27/2023  20:21               245 CD4_T_description.txt
# 12/27/2023  20:21             3,647 CD4_T_features.txt
# 12/27/2023  20:21            29,152 CD4_T_loss_diff_history.json
# 12/27/2023  17:32            17,375 CD4_T_loss_diff_history581.json
# 12/27/2023  20:21            27,505 CD4_T_loss_history.json
# 12/27/2023  17:32            15,925 CD4_T_loss_history581.json
#                8 File(s)        161,567 bytes
#                2 Dir(s)  1,676,509,057,024 bytes free

# %%
with open('CD4_T_loss_history.json', 'r') as f:
    cd4t_loss_history = json.load(f)
with open('CD4_T_loss_diff_history.json', 'r') as f:
    loss_diff_history = json.load(f)

# %%
stop_iter = 632

# %%
iteration = np.arange(0, 1000, 1)

# Set figure size
plt.figure(figsize=(6, 3))

# Plot loss history
plt.plot(iteration, cd4t_loss_history.values())

# Plot red vertical line at x=477
plt.axvline(x=stop_iter, color='red')

# Set title and labels
plt.title('CD4 T cells loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()

# %%
iteration = np.arange(0, 1000, 1)

# Set figure size
plt.figure(figsize=(6, 3))

# Plot loss history
plt.plot(iteration, loss_diff_history.values())

# Plot red vertical line at x=477
plt.axvline(x=stop_iter, color='red')
plt.axhline(y=1e-6, color='red', linestyle='--')

# Set x-axis limit
# plt.ylim(top = 0.1)
plt.yscale('log')

# Set title and labels
plt.title('CD4 T cells weight difference history')
plt.xlabel('Iteration')
plt.ylabel('Weight difference')

plt.show()
