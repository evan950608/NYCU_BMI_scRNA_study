# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import sys

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
import scanpy as sc
# import scvelo as scv

# read the full GSE dataset
adata = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Harmony_and_ztrans\Hao_Harmony_test_no_scale.h5ad")
adata.shape
# Out:
# (161764, 33538)

# %%
adata.obs['celltype.l2'] = adata.obs['celltype.l2'].str.replace(' ', '_')

label = adata.obs['celltype.l2'].tolist()
types = np.unique(label).tolist()
print(types)
# Out:
# ['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC']

# %%
# Briefly view adata.X (raw counts)
rows, cols = adata.X[:5,:].nonzero()
i = 0
for row, col in zip(rows, cols):
    if i == 20: break
    print(f'Row {row}, Column {col}, Value {adata.X[row, col]}')
    i += 1
# Out:
# Row 0, Column 12, Value 0.4895154535770416
# Row 0, Column 43, Value 0.8167138695716858
# Row 0, Column 48, Value 0.8167138695716858
# Row 0, Column 53, Value 0.8167138695716858
# Row 0, Column 55, Value 1.424944519996643
# Row 0, Column 66, Value 0.4895154535770416
# Row 0, Column 77, Value 0.8167138695716858
# Row 0, Column 78, Value 1.424944519996643
# Row 0, Column 89, Value 0.8167138695716858
# Row 0, Column 93, Value 1.0628387928009033
# Row 0, Column 102, Value 0.8167138695716858
# Row 0, Column 154, Value 2.4626553058624268
# Row 0, Column 178, Value 0.8167138695716858
# Row 0, Column 185, Value 0.4895154535770416
# Row 0, Column 190, Value 0.4895154535770416
# Row 0, Column 201, Value 1.8004224300384521
# Row 0, Column 224, Value 0.8167138695716858
# Row 0, Column 240, Value 0.4895154535770416
# Row 0, Column 259, Value 0.4895154535770416
# Row 0, Column 261, Value 1.566353440284729

# %% [markdown]
# ## Scale genes

# %%
# Scale each gene to unit variance
sc.pp.scale(adata)

# %% [markdown]
# ## Read features

# %%
import os
os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_ztrans_v2\Level2\feature_selection")

features_dict = {}
# Read features for each celltype
for celltype in types:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        features_dict[celltype] = feature_df
    except:
        print('skipping:', celltype)
        continue

# %%
count_df = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df = features_dict[celltype]
    feature_count = feature_df.shape[0]
    positive_count = feature_df[feature_df['Tendency'] == 1].shape[0]
    count_df.loc[celltype] = [feature_count, positive_count]
count_df
# Out:
#                    Feature_count  Positive_feature_count
# ASDC                         119                      61
# B_intermediate               107                      68
# B_memory                    1708                     793
# B_naive                       30                      23
# CD14_Mono                     18                      14
# CD16_Mono                   1149                     705
# CD4_CTL                      729                     356
# CD4_Naive                     63                      32
# CD4_Proliferating            205                     147
# CD4_TCM                      155                      95
# CD4_TEM                     1550                     781
# CD8_Naive                    744                     371
# CD8_Proliferating            301                     227
# CD8_TCM                     1373                     676
# CD8_TEM                       19                      16
# Doublet                      774                     550
# Eryth                        655                     113
# HSPC                         330                     223
# ILC                          490                     271
# MAIT                          76                      41
# NK                           483                     245
# NK_CD56bright               1543                     729
# NK_Proliferating            1292                     798
# Plasmablast                   67                      46
# Platelet                    1054                     614
# Treg                         160                      76
# cDC1                         830                     468
# cDC2                          44                      27
# dnT                          705                     335
# gdT                          387                     187
# pDC                         1024                     701

# %% [markdown]
# ## Get likelihood from LR model

# %%
def LR_likelihood_decision_score(data, all_features_dict, celltype):
    print('====================')
    print('Celltype:', celltype)
    # subset data to celltype features
    X = data[:, all_features_dict[celltype]['Gene'].tolist()].X
    # Binary label
    y = [1 if i==celltype else 0 for i in data.obs['celltype.l2'].tolist()]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

    clf = LogisticRegression(penalty='l2', solver='lbfgs', C=1.0, max_iter=1000)
    clf.fit(X_train, y_train)

    decision_scores = clf.decision_function(X)  # >0: predict celltype, <0: predict not celltype
    print('decision_scores > 0:', sum(decision_scores > 0))

    # calculate the likelihood of the positive class for each observation in X based on the decision scores
    likelihood = 1 / (1 + np.exp(-decision_scores))
    print('likelihood > 0.5:', sum(likelihood > 0.5))  # >0.5: predict celltype, <0.5: predict not celltype
    print(type(likelihood), likelihood.shape)
    #do the row-wise softmax
    # likelihood = np.exp(likelihood)/np.sum(np.exp(likelihood),1,keepdims=True)
    
    return likelihood


def LR_likelihood_pred_prob(data, all_features_dict, celltype):
    print('====================')
    print('Celltype:', celltype)
    # subset data to celltype features
    X = data[:, all_features_dict[celltype]['Gene'].tolist()].X
    # Binary label
    y = [1 if i==celltype else 0 for i in data.obs['celltype.l2'].tolist()]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

    clf = LogisticRegression(penalty='l2', solver='lbfgs', C=1.0, max_iter=1000, n_jobs=32)
    clf.fit(X_train, y_train)

    # likelihood of the positive class for each observation
    likelihood = clf.predict_proba(X)[:, 1]  # >0.5: predict celltype, <0.5: predict not celltype
    print('likelihood > 0.5:', sum(likelihood > 0.5))  # decision_scores > 0 的有幾個

    return likelihood

# %%
celltype = 'ASDC'
B_likelihood = LR_likelihood_pred_prob(adata, features_dict, celltype)
B_likelihood.shape
# Out:
# ====================
# Celltype: ASDC
# likelihood > 0.5: 76
# (161764,)

# %%
B_likelihood[:5]
# Out:
# array([3.71941615e-09, 5.11187911e-09, 8.52301163e-10, 3.98251002e-09,
#        2.00100794e-08])

# %%
likelihood_dict = {}
for celltype in types:
    likelihood_dict[celltype] = LR_likelihood_pred_prob(adata, features_dict, celltype)
# Out:
# ====================
# Celltype: ASDC
# likelihood > 0.5: 76
# ====================
# Celltype: B_intermediate
# likelihood > 0.5: 2269
# ====================
# Celltype: B_memory
# likelihood > 0.5: 3278
# ====================
# Celltype: B_naive
# likelihood > 0.5: 7736
# ====================
# Celltype: CD14_Mono
# likelihood > 0.5: 42872
# ====================
# Celltype: CD16_Mono
# likelihood > 0.5: 6287
# ====================
# Celltype: CD4_CTL
# likelihood > 0.5: 1721
# ====================
# Celltype: CD4_Naive
# likelihood > 0.5: 16991
# ====================
# Celltype: CD4_Proliferating
# likelihood > 0.5: 114
# ====================
# Celltype: CD4_TCM
# likelihood > 0.5: 14322
# ====================
# Celltype: CD4_TEM
# likelihood > 0.5: 3776
# ====================
# Celltype: CD8_Naive
# likelihood > 0.5: 10667
# ====================
# Celltype: CD8_Proliferating
# likelihood > 0.5: 89
# ====================
# Celltype: CD8_TCM
# likelihood > 0.5: 2668
# ====================
# Celltype: CD8_TEM
# likelihood > 0.5: 10708
# ====================
# Celltype: Doublet
# likelihood > 0.5: 295
# ====================
# Celltype: Eryth
# likelihood > 0.5: 84
# ====================
# Celltype: HSPC
# likelihood > 0.5: 325
# ====================
# Celltype: ILC
# likelihood > 0.5: 131
# ====================
# Celltype: MAIT
# likelihood > 0.5: 2742
# ====================
# Celltype: NK
# likelihood > 0.5: 17172
# ====================
# Celltype: NK_CD56bright
# likelihood > 0.5: 939
# ====================
# Celltype: NK_Proliferating
# likelihood > 0.5: 542
# ====================
# Celltype: Plasmablast
# likelihood > 0.5: 364
# ====================
# Celltype: Platelet
# likelihood > 0.5: 2281
# ====================
# Celltype: Treg
# likelihood > 0.5: 2201
# ====================
# Celltype: cDC1
# likelihood > 0.5: 151
# ====================
# Celltype: cDC2
# likelihood > 0.5: 2442
# ====================
# Celltype: dnT
# likelihood > 0.5: 362
# ====================
# Celltype: gdT
# likelihood > 0.5: 3394
# ====================
# Celltype: pDC
# likelihood > 0.5: 861

# %%
likelihood_dict.keys()
# Out:
# dict_keys(['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC'])

# %%
# turn likelihood_dict into dataframe
likelihood_df = pd.DataFrame(likelihood_dict)
likelihood_df.head()
# Out:
#            ASDC  B_intermediate      B_memory   B_naive  CD14_Mono  \
# 0  3.715237e-09        0.000052  3.687748e-13  0.000344   0.964839
# 1  5.101320e-09        0.000162  4.759851e-12  0.000207   0.000745
# 2  8.509303e-10        0.000025  2.528366e-11  0.000101   0.000587
# 3  3.974660e-09        0.000121  6.691025e-11  0.000037   0.000628
# 4  1.997291e-08        0.000036  5.429926e-08  0.000082   0.000246
#
#       CD16_Mono       CD4_CTL  CD4_Naive  CD4_Proliferating   CD4_TCM  ...  \
# 0  4.853600e-09  6.209092e-20   0.000029       9.359457e-11  0.000573  ...
# 1  1.439165e-10  5.709666e-06   0.117329       4.041331e-10  0.953542  ...
# 2  5.942407e-15  6.584337e-17   0.025124       1.640411e-11  0.000325  ...
# 3  1.389254e-19  3.224184e-17   0.002405       1.841979e-14  0.000009  ...
# 4  5.503078e-13  7.781616e-15   0.001848       4.704173e-11  0.000116  ...
#
#    NK_CD56bright  NK_Proliferating   Plasmablast      Platelet          Treg  \
# 0   2.184829e-10      1.555864e-10  1.204748e-08  8.896611e-10  7.627155e-07
# 1   3.213146e-06      3.997059e-14  5.004907e-08  1.067323e-06  4.956272e-04
# 2   1.483662e-09      7.097631e-14  4.408361e-08  3.737256e-10  6.965793e-03
# 3   7.092376e-12      4.605264e-06  2.814307e-08  3.715542e-18  8.771411e-06
# 4   2.347246e-08      5.258614e-14  2.092912e-08  8.679710e-07  9.589316e-04
#
#            cDC1      cDC2           dnT       gdT           pDC
# 0  5.305128e-08  0.000036  1.490733e-12  0.000001  3.128052e-08
# 1  2.410709e-08  0.000017  4.181838e-12  0.000014  1.997000e-08
# 2  2.876824e-08  0.000005  2.364524e-07  0.000068  1.508065e-08
# 3  2.402591e-08  0.000005  7.292961e-20  0.000060  1.672519e-08
# 4  4.396003e-08  0.000041  9.216575e-10  0.000146  1.419148e-08
#
# [5 rows x 31 columns]

# %%
likelihood_df.shape
# Out:
# (161764, 31)

# %%
# row sum
likelihood_df.sum(axis=1)
# Out:
# 0         0.966044
# 1         1.075897
# 2         1.102584
# 3         0.967877
# 4         1.047490
#             ...
# 161759    1.228259
# 161760    1.001683
# 161761    1.016640
# 161762    0.492009
# 161763    0.912105
# Length: 161764, dtype: float64

# %%
os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_ztrans_v2\Level2\LR_likelihood")
likelihood_df.to_csv('L2_likelihood_df.csv')

# %% [markdown]
# ## (1st_type / 2nd_type) >= 1.5

# %%
largest_values = []
second_largest_values = []
largest_columns = []
second_largest_columns = []
odds_ratio_list = []
assignments = []

# for index, row in likelihood_softmax.iterrows():
for index, row in likelihood_df.iterrows():
    # find 1st and 2nd largest values and their corresponding columns
    largest_value = row.max()
    largest_column = row.idxmax()
    second_largest_value = row.nlargest(2).iloc[-1]
    second_largest_column = row.nlargest(2).index[-1]
    
    largest_values.append(largest_value)
    second_largest_values.append(second_largest_value)
    largest_columns.append(largest_column)
    second_largest_columns.append(second_largest_column)

    # calculate odds ratio
    odds_ratio = largest_value / second_largest_value
    if odds_ratio >= 1.5:
        assign = largest_column
    else:
        assign = 'Uncertain'
    odds_ratio_list.append(odds_ratio)
    assignments.append(assign)

result_df = pd.DataFrame({'Largest Value': largest_values, 'Largest Column': largest_columns,
                          'Second Largest Value': second_largest_values, 'Second Largest Column': second_largest_columns, 
                          'Odds Ratio': odds_ratio_list, 'Assignment': assignments})
result_df.shape

# %%
result_df.head(20)

# %%
sum(result_df['Assignment'] == 'Uncertain')

# %%
12915/len(result_df)

# %% [markdown]
# ## Assign the celltype with the largest likelihood (no odds ratio)

# %%
largest_values = []
largest_columns = []
assignments = []
for index, row in likelihood_df.iterrows():
    # find largest value and their corresponding columns
    largest_value = row.max()
    largest_column = row.idxmax()
    largest_values.append(largest_value)
    largest_columns.append(largest_column)

    assign = largest_column
    assignments.append(assign)

result_df = pd.DataFrame({'Largest Value': largest_values, 'Largest Column': largest_columns, 'Assignment': assignments})
result_df.shape
# Out:
# (161764, 3)

# %%
result_df.head(20)
# Out:
#     Largest Value  Largest Column      Assignment
# 0        0.964839       CD14_Mono       CD14_Mono
# 1        0.953542         CD4_TCM         CD4_TCM
# 2        0.999993       CD8_Naive       CD8_Naive
# 3        0.962106              NK              NK
# 4        0.999977       CD8_Naive       CD8_Naive
# 5        0.686875         CD8_TEM         CD8_TEM
# 6        0.754081       CD16_Mono       CD16_Mono
# 7        0.999738  B_intermediate  B_intermediate
# 8        0.999999              NK              NK
# 9        0.999936       CD8_Naive       CD8_Naive
# 10       0.341299       CD4_Naive       CD4_Naive
# 11       0.218138         CD4_TCM         CD4_TCM
# 12       0.999799         CD4_CTL         CD4_CTL
# 13       0.999631         B_naive         B_naive
# 14       0.999767       CD14_Mono       CD14_Mono
# 15       0.986975         CD4_TCM         CD4_TCM
# 16       0.977918            MAIT            MAIT
# 17       0.999991              NK              NK
# 18       0.980300         CD4_TCM         CD4_TCM
# 19       0.999986              NK              NK

# %%
# count 'uncertain'
sum(result_df['Assignment'] == 'Uncertain')
# Out:
# 0

# %% [markdown]
# ## Confusion heatmap

# %%
import pandas as pd

# Get the true labels
true_labels = adata.obs['celltype.l2'].tolist()

# Get the predicted labels
predicted_labels = result_df['Assignment'].tolist()

# Create the confusion matrix
cm = pd.crosstab(true_labels, predicted_labels, rownames=['True'], colnames=['Predicted'], margins=False)

# reorder columns
# cm = cm.reindex(types + ['Uncertain'], axis=1)

# replace NaN with 0
cm = cm.fillna(0)
cm = cm.astype(int)

# %%
cm
# Out:
# Predicted          ASDC  B_intermediate  B_memory  B_naive  CD14_Mono  \
# True
# ASDC                 74               0         0        0          0
# B_intermediate        0            2146        25      241          2
# B_memory              0              29      3247        6          0
# B_naive               0             106        10     7587          3
# CD14_Mono             0               0         0        1      42433
# CD16_Mono             0               0         0        0        202
# CD4_CTL               0               0         0        0          0
# CD4_Naive             0               0         0        0          0
# CD4_Proliferating     0               0         0        0          0
# CD4_TCM               0               0         0        0          0
# CD4_TEM               0               0         0        0          0
# CD8_Naive             0               0         0        0          1
# CD8_Proliferating     0               0         0        0          0
# CD8_TCM               0               0         0        0          0
# CD8_TEM               0               0         0        0          2
# Doublet               0               0         0        0        211
# Eryth                 0               0         0        0          3
# HSPC                  0               0         0        0          1
# ILC                   0               0         0        0          0
# MAIT                  0               0         0        0          0
# NK                    0               0         0        0          0
# NK_CD56bright         0               0         0        0          0
# NK_Proliferating      0               0         0        0          0
# Plasmablast           0               1         2        0          0
# Platelet              0               0         0        2         30
# Treg                  0               0         0        0          2
# cDC1                  0               0         0        0          0
# cDC2                  0               0         0        0        208
# dnT                   0               0         0        0          0
# gdT                   0               0         0        0          2
# pDC                   0               0         0        0          1
#
# Predicted          CD16_Mono  CD4_CTL  CD4_Naive  CD4_Proliferating  CD4_TCM  \
# True
# ASDC                       0        0          0                  0        0
# B_intermediate             0        0          3                  0        2
# B_memory                   0        0          0                  0        0
# B_naive                    2        0          2                  0        2
# CD14_Mono                165        0         12                  0        1
# CD16_Mono               6098        0          0                  0        0
# CD4_CTL                    0     1696          0                  0        4
# CD4_Naive                  0        0      16881                  0      417
# CD4_Proliferating          0        0          0                104        1
# CD4_TCM                    0        6        822                  1    13315
# CD4_TEM                    0       13          8                  0      826
# CD8_Naive                  0        0        108                  0       14
# CD8_Proliferating          0        2          0                  2        0
# CD8_TCM                    0        0         32                  0      276
# CD8_TEM                    1       19         30                  0       46
# Doublet                   80        0         19                  0       12
# Eryth                      0        0          0                  0        0
# HSPC                       0        0          0                  0        0
# ILC                        0        0          0                  0        0
# MAIT                       0        0          2                  0       11
# NK                         0        3          0                  0        1
# NK_CD56bright              0        0          0                  0        0
# NK_Proliferating           0        0          0                  1        2
# Plasmablast                0        0          0                  0        0
# Platelet                   0        0         10                  0        0
# Treg                       0        0        258                  0      171
# cDC1                       0        0          0                  0        0
# cDC2                       1        0          0                  0        0
# dnT                        0        0          7                  0        2
# gdT                        0        3         45                  0        9
# pDC                        0        0          0                  0        0
#
# Predicted          ...  NK_CD56bright  NK_Proliferating  Plasmablast  \
# True               ...
# ASDC               ...              0                 0            0
# B_intermediate     ...              0                 0            0
# B_memory           ...              0                 0            0
# B_naive            ...              0                 0            0
# CD14_Mono          ...              0                 0            1
# CD16_Mono          ...              0                 0            0
# CD4_CTL            ...              0                 0            0
# CD4_Naive          ...              0                 0            0
# CD4_Proliferating  ...              0                 0            0
# CD4_TCM            ...              0                 0            0
# CD4_TEM            ...              0                 0            1
# CD8_Naive          ...              0                 0            0
# CD8_Proliferating  ...              0                 2            0
# CD8_TCM            ...              0                 0            0
# CD8_TEM            ...              0                 1            0
# Doublet            ...              0                 0            0
# Eryth              ...              0                 0            0
# HSPC               ...              0                 1            0
# ILC                ...              1                 0            0
# MAIT               ...              1                 0            0
# NK                 ...             11                 4            0
# NK_CD56bright      ...            924                 0            0
# NK_Proliferating   ...              0               531            0
# Plasmablast        ...              0                 0          363
# Platelet           ...              0                 0            0
# Treg               ...              0                 0            0
# cDC1               ...              0                 0            0
# cDC2               ...              0                 0            0
# dnT                ...              0                 0            0
# gdT                ...              0                 0            0
# pDC                ...              0                 0            0
#
# Predicted          Platelet  Treg  cDC1  cDC2  dnT   gdT  pDC
# True
# ASDC                      0     0     0     1    0     0    1
# B_intermediate            0     1     0     0    0     0    0
# B_memory                  0     0     0     0    0     1    0
# B_naive                   0     0     0     0    0     1    0
# CD14_Mono                15     1     0    43    0     0    0
# CD16_Mono                 0     0     0     5    0     0    0
# CD4_CTL                   0     0     0     0    0     1    0
# CD4_Naive                 6    97     0     0    8    10    0
# CD4_Proliferating         0     1     0     0    0     0    0
# CD4_TCM                   1   132     0     0    2     8    0
# CD4_TEM                   1    17     0     0    2     7    0
# CD8_Naive                 0     7     0     0    2     4    0
# CD8_Proliferating         0     0     0     0    0     0    0
# CD8_TCM                   0    12     0     0    1     4    0
# CD8_TEM                   3     2     0     0    3   225    0
# Doublet                   2     1     0     0    0     0    0
# Eryth                     0     0     0     0    0     0    0
# HSPC                      0     0     0     0    0     0    0
# ILC                       0     0     0     0    0     0    0
# MAIT                      0     0     0     0    0    11    0
# NK                        3     0     0     0    0    24    0
# NK_CD56bright             0     0     0     0    0     0    0
# NK_Proliferating          0     0     0     0    0     1    0
# Plasmablast               0     0     0     0    0     0    0
# Platelet               2209     0     0     2    0     4    0
# Treg                      1  2067     0     0    2     0    0
# cDC1                      0     0   150     1    0     0    0
# cDC2                      0     0     1  2290    0     0    0
# dnT                       0     2     0     0  315     4    0
# gdT                       0     4     0     0    3  3283    0
# pDC                       0     0     0     0    0     0  860
#
# [31 rows x 31 columns]

# %%
cm.to_csv('likelihood_assignment_confusion_matrix.csv')

# %% [markdown]
# ## Plot confusion matrix

# %%
# os.chdir('./LR_likelihood')
cm = pd.read_csv('likelihood_assignment_confusion_matrix.csv', index_col=0)
cm.shape
# Out:
# (31, 31)

# %%
# remove irrelevant cell types
irrelevant = ['Doublet', 'Eryth', 'Platelet']
cm = cm.drop(irrelevant, axis=0)
cm = cm.drop(irrelevant, axis=1)
cm.shape
# Out:
# (28, 28)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('LR Prediction Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
row_sum = cm.sum(axis=1)
row_sum
# Out:
# True
# ASDC                    76
# B_intermediate        2431
# B_memory              3285
# B_naive               7718
# CD14_Mono            42690
# CD16_Mono             6320
# CD4_CTL               1736
# CD4_Naive            17479
# CD4_Proliferating      108
# CD4_TCM              14889
# CD4_TEM               4282
# CD8_Naive            10768
# CD8_Proliferating       91
# CD8_TCM               2883
# CD8_TEM              11727
# Doublet                605
# Eryth                   83
# HSPC                   329
# ILC                    132
# MAIT                  2784
# NK                   17173
# NK_CD56bright          943
# NK_Proliferating       548
# Plasmablast            366
# Platelet              2293
# Treg                  2507
# cDC1                   151
# cDC2                  2501
# dnT                    356
# gdT                   3649
# pDC                    861
# dtype: int64

# %%
os.getcwd()
# Out:
# '/home/jovyan/work/GitHub/EvanPys/Progress/PBMC_Hao_ztrans_v2/Level2/LR_likelihood'

# %%
cm_proportion = cm.div(row_sum, axis=0)
cm_proportion *= 100
plt.figure(figsize=(20, 20))
sns.heatmap(cm_proportion, fmt=".1f", annot=True, cmap='Blues')
plt.title('LR Prediction Confusion Matrix (Proportion %)')
plt.savefig('cm_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ## Calculate accuracy

# %%
accuracy = sum(np.diag(cm)) / cm.values.sum()
accuracy
# Out:
# 0.9539019806631883

# %%
cm.values.sum()
# Out:
# 161764
