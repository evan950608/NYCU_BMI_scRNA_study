# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import sys

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
import scanpy as sc
# import scvelo as scv

# read the full GSE dataset
# adata = sc.read_h5ad('/Users/evanli/Documents/Research_datasets/PBMC_Hao/GSE164378_Hao/batch_corrected/Hao_PBMC_Harmony_unscaled.h5ad')
adata = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Batch_corrected\Hao_PBMC_Harmony_unscaled.h5ad")
adata.shape
# Out:
# (161764, 33538)

# %%
adata.obs['celltype.l2'] = adata.obs['celltype.l2'].str.replace(' ', '_')

label = adata.obs['celltype.l2'].tolist()
types = np.unique(label).tolist()
print(types)
# Out:
# ['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC']

# %% [markdown]
# ## Read features

# %%
import os
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch/Level2_log_inv/feature_selection')
os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch\Level2_log_inv\feature_selection")

features_dict = {}
# Read features for each celltype
for celltype in types:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        features_dict[celltype] = feature_df
    except:
        print('skipping:', celltype)
        continue


# read new features from lambda decision v3
os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch\Level2_log_inv\feature_selection_v3")
queue = ['dnT', 'Treg', 'CD8_Proliferating', 'ILC', 'CD8_TCM']
for celltype in queue:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        print('Updating features for:', celltype)
        features_dict[celltype] = feature_df
    except:
        print('skipping:', celltype)
        continue
# Out:
# Updating features for: dnT
# Updating features for: Treg
# Updating features for: CD8_Proliferating
# Updating features for: ILC
# Updating features for: CD8_TCM

# %%
count_df = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df = features_dict[celltype]
    feature_count = feature_df.shape[0]
    positive_count = feature_df[feature_df['Tendency'] == 1].shape[0]
    count_df.loc[celltype] = [feature_count, positive_count]
count_df
# Out:
#                    Feature_count  Positive_feature_count
# ASDC                          27                      16
# B_intermediate                16                       7
# B_memory                      35                      16
# B_naive                        8                       6
# CD14_Mono                     17                       9
# CD16_Mono                     15                       5
# CD4_CTL                       90                      31
# CD4_Naive                    151                      91
# CD4_Proliferating             26                      19
# CD4_TCM                       82                      48
# CD4_TEM                       52                      21
# CD8_Naive                     61                      36
# CD8_Proliferating             29                      14
# CD8_TCM                      333                     104
# CD8_TEM                       40                      15
# Doublet                       43                      16
# Eryth                          4                       1
# HSPC                          12                       7
# ILC                           57                      23
# MAIT                          11                       6
# NK                            31                      15
# NK_CD56bright                 32                      18
# NK_Proliferating              35                       7
# Plasmablast                    4                       1
# Platelet                       4                       3
# Treg                         282                     153
# cDC1                          20                      12
# cDC2                          12                       9
# dnT                           55                      25
# gdT                           24                      11
# pDC                           20                       9

# %% [markdown]
# ## Get likelihood from LR model

# %%
def LR_likelihood_decision_score(data, all_features_dict, celltype):
    print('====================')
    print('Celltype:', celltype)
    # subset data to celltype features
    X = data[:, all_features_dict[celltype]['Gene'].tolist()].X
    # Binary label
    y = [1 if i==celltype else 0 for i in data.obs['celltype.l2'].tolist()]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

    clf = LogisticRegression(penalty='l2', solver='lbfgs', C=1.0, max_iter=1000)
    clf.fit(X_train, y_train)

    decision_scores = clf.decision_function(X)  # >0: predict celltype, <0: predict not celltype
    print('decision_scores > 0:', sum(decision_scores > 0))

    # calculate the likelihood of the positive class for each observation in X based on the decision scores
    likelihood = 1 / (1 + np.exp(-decision_scores))
    print('likelihood > 0.5:', sum(likelihood > 0.5))  # >0.5: predict celltype, <0.5: predict not celltype
    print(type(likelihood), likelihood.shape)
    #do the row-wise softmax
    # likelihood = np.exp(likelihood)/np.sum(np.exp(likelihood),1,keepdims=True)
    
    return likelihood


def LR_likelihood_pred_prob(data, all_features_dict, celltype):
    print('====================')
    print('Celltype:', celltype)
    # subset data to celltype features
    X = data[:, all_features_dict[celltype]['Gene'].tolist()].X
    # Binary label
    y = [1 if i==celltype else 0 for i in data.obs['celltype.l2'].tolist()]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

    clf = LogisticRegression(penalty='l2', solver='lbfgs', C=1.0, max_iter=1000)
    clf.fit(X_train, y_train)

    # likelihood of the positive class for each observation
    likelihood = clf.predict_proba(X)[:, 1]  # >0.5: predict celltype, <0.5: predict not celltype
    print('likelihood > 0.5:', sum(likelihood > 0.5))  # decision_scores > 0 的有幾個

    return likelihood

# %%
celltype = 'ASDC'
AS_likelihood = LR_likelihood_pred_prob(adata, features_dict, celltype)
AS_likelihood.shape
# Out:
# ====================
# Celltype: ASDC
# likelihood > 0.5: 73
# (161764,)

# %%
likelihood_dict = {}
for celltype in types:
    likelihood_dict[celltype] = LR_likelihood_pred_prob(adata, features_dict, celltype)
# Out:
# ====================
# Celltype: ASDC
# likelihood > 0.5: 73
# ====================
# Celltype: B_intermediate
# likelihood > 0.5: 1681
# ====================
# Celltype: B_memory
# likelihood > 0.5: 3225
# ====================
# Celltype: B_naive
# likelihood > 0.5: 7737
# ====================
# Celltype: CD14_Mono
# likelihood > 0.5: 43045
# ====================
# Celltype: CD16_Mono
# likelihood > 0.5: 6327
# ====================
# Celltype: CD4_CTL
# likelihood > 0.5: 1592
# ====================
# Celltype: CD4_Naive
# likelihood > 0.5: 17384
# ====================
# Celltype: CD4_Proliferating
# likelihood > 0.5: 102
# ====================
# Celltype: CD4_TCM
# likelihood > 0.5: 14281
# ====================
# Celltype: CD4_TEM
# likelihood > 0.5: 2509
# ====================
# Celltype: CD8_Naive
# likelihood > 0.5: 10373
# ====================
# Celltype: CD8_Proliferating
# likelihood > 0.5: 62
# ====================
# Celltype: CD8_TCM
# likelihood > 0.5: 2261
# ====================
# Celltype: CD8_TEM
# likelihood > 0.5: 11204
# ====================
# Celltype: Doublet
# likelihood > 0.5: 156
# ====================
# Celltype: Eryth
# likelihood > 0.5: 84
# ====================
# Celltype: HSPC
# likelihood > 0.5: 322
# ====================
# Celltype: ILC
# likelihood > 0.5: 123
# ====================
# Celltype: MAIT
# likelihood > 0.5: 2646
# ====================
# Celltype: NK
# likelihood > 0.5: 17361
# ====================
# Celltype: NK_CD56bright
# likelihood > 0.5: 906
# ====================
# Celltype: NK_Proliferating
# likelihood > 0.5: 496
# ====================
# Celltype: Plasmablast
# likelihood > 0.5: 342
# ====================
# Celltype: Platelet
# likelihood > 0.5: 2177
# ====================
# Celltype: Treg
# likelihood > 0.5: 2260
# ====================
# Celltype: cDC1
# likelihood > 0.5: 150
# ====================
# Celltype: cDC2
# likelihood > 0.5: 2411
# ====================
# Celltype: dnT
# likelihood > 0.5: 239
# ====================
# Celltype: gdT
# likelihood > 0.5: 3172
# ====================
# Celltype: pDC
# likelihood > 0.5: 867

# %%
# turn likelihood_dict into dataframe
likelihood_df = pd.DataFrame(likelihood_dict)
likelihood_df.head()
# Out:
#            ASDC  B_intermediate      B_memory       B_naive     CD14_Mono  \
# 0  1.343484e-05        0.000010  1.378923e-05  1.151111e-05  9.763964e-01
# 1  4.854250e-08        0.000087  1.054397e-04  9.325639e-06  7.665299e-07
# 2  1.773020e-07        0.000072  8.910484e-06  4.521020e-06  2.655943e-08
# 3  8.567967e-08        0.000028  4.906752e-07  1.132355e-06  2.705006e-06
# 4  2.908055e-08        0.000113  5.180162e-05  9.821320e-07  7.962159e-08
#
#    CD16_Mono       CD4_CTL     CD4_Naive  CD4_Proliferating       CD4_TCM  \
# 0   0.001859  1.130727e-06  2.295751e-08       2.162827e-05  3.968692e-04
# 1   0.000006  6.255603e-06  1.604691e-02       2.041783e-04  9.539641e-01
# 2   0.000008  8.831190e-06  2.548628e-02       8.948075e-07  3.341922e-04
# 3   0.000309  6.376855e-07  1.524314e-06       7.453669e-09  8.451199e-07
# 4   0.000121  1.586302e-06  1.789914e-03       1.047226e-06  4.407222e-04
#
#    ...  NK_CD56bright  NK_Proliferating  Plasmablast  Platelet          Treg  \
# 0  ...   1.648412e-07      6.424289e-06     0.000013  0.000659  1.370129e-07
# 1  ...   2.280035e-04      3.321969e-07     0.000002  0.000315  1.118387e-04
# 2  ...   2.835597e-05      3.916500e-07     0.000002  0.000247  3.298359e-03
# 3  ...   1.051962e-05      7.185731e-05     0.000007  0.000310  2.045567e-07
# 4  ...   3.184529e-05      1.603735e-07     0.000005  0.000317  1.946429e-04
#
#            cDC1          cDC2       dnT           gdT           pDC
# 0  1.327704e-07  8.384308e-05  0.000005  3.967243e-07  1.809806e-07
# 1  2.436826e-07  7.612749e-09  0.000181  8.094163e-04  5.470405e-07
# 2  3.605246e-07  3.587770e-08  0.000962  4.418641e-03  7.836229e-07
# 3  1.080857e-06  5.625754e-09  0.000002  2.664005e-02  3.931551e-05
# 4  1.968709e-07  2.089452e-08  0.000305  2.711808e-03  2.485593e-07
#
# [5 rows x 31 columns]

# %%
# row sum
likelihood_df.sum(axis=1)
# Out:
# 0         0.981182
# 1         0.989940
# 2         1.100492
# 3         1.029832
# 4         1.143365
#             ...
# 161759    1.133704
# 161760    1.004289
# 161761    0.928488
# 161762    0.903915
# 161763    0.961100
# Length: 161764, dtype: float64

# %% [markdown]
# ## (1st_type / 2nd_type) >= 1.5

# %%
largest_values = []
second_largest_values = []
largest_columns = []
second_largest_columns = []
odds_ratio_list = []
assignments = []

# for index, row in likelihood_softmax.iterrows():
for index, row in likelihood_df.iterrows():
    # find 1st and 2nd largest values and their corresponding columns
    largest_value = row.max()
    largest_column = row.idxmax()
    second_largest_value = row.nlargest(2).iloc[-1]
    second_largest_column = row.nlargest(2).index[-1]
    
    largest_values.append(largest_value)
    second_largest_values.append(second_largest_value)
    largest_columns.append(largest_column)
    second_largest_columns.append(second_largest_column)

    # calculate odds ratio
    odds_ratio = largest_value / second_largest_value
    if odds_ratio >= 1.5:
        assign = largest_column
    else:
        assign = 'Uncertain'
    odds_ratio_list.append(odds_ratio)
    assignments.append(assign)

result_df = pd.DataFrame({'Largest Value': largest_values, 'Largest Column': largest_columns,
                          'Second Largest Value': second_largest_values, 'Second Largest Column': second_largest_columns, 
                          'Odds Ratio': odds_ratio_list, 'Assignment': assignments})
result_df.shape
# Out:
# (161764, 6)

# %%
result_df.head(20)
# Out:
#     Largest Value Largest Column  Second Largest Value Second Largest Column  \
# 0        0.268419           Mono              0.104696                 other
# 1        0.278682          CD4_T              0.104126                 CD8_T
# 2        0.278839          CD8_T              0.103761                 CD4_T
# 3        0.279107             NK              0.103758                 CD8_T
# 4        0.278274          CD8_T              0.103543                 other
# 5        0.197526          CD8_T              0.115211               other_T
# 6        0.276959           Mono              0.103424                 other
# 7        0.279251              B              0.103436                 other
# 8        0.279075             NK              0.104223               other_T
# 9        0.277877          CD8_T              0.107912                 CD4_T
# 10       0.265082          CD4_T              0.111071                 CD8_T
# 11       0.246705          CD4_T              0.108929                 CD8_T
# 12       0.199709          CD4_T              0.118333                 CD8_T
# 13       0.274263              B              0.119845                 CD8_T
# 14       0.259015           Mono              0.106179                 other
# 15       0.275142          CD4_T              0.108177               other_T
# 16       0.273582        other_T              0.110800                 CD8_T
# 17       0.278830             NK              0.103075                 CD8_T
# 18       0.233023          CD4_T              0.110619                 CD8_T
# 19       0.279502             NK              0.103043                 other
#
#     Odds Ratio Assignment
# 0     2.563802       Mono
# 1     2.676397      CD4_T
# 2     2.687309      CD8_T
# 3     2.689978         NK
# 4     2.687516      CD8_T
# 5     1.714464      CD8_T
# 6     2.677887       Mono
# 7     2.699742          B
# 8     2.677664         NK
# 9     2.575044      CD8_T
# 10    2.386597      CD4_T
# 11    2.264815      CD4_T
# 12    1.687685      CD4_T
# 13    2.288488          B
# 14    2.439427       Mono
# 15    2.543439      CD4_T
# 16    2.469142    other_T
# 17    2.705118         NK
# 18    2.106528      CD4_T
# 19    2.712476         NK

# %%
sum(result_df['Assignment'] == 'Uncertain')
# Out:
# 12915

# %%
12915/len(result_df)
# Out:
# 0.07983853020449544

# %% [markdown]
# ## Assign the celltype with the largest likelihood (no odds ratio)

# %%
largest_values = []
largest_columns = []
assignments = []
for index, row in likelihood_df.iterrows():
    # find largest value and their corresponding columns
    largest_value = row.max()
    largest_column = row.idxmax()
    largest_values.append(largest_value)
    largest_columns.append(largest_column)

    assign = largest_column
    assignments.append(assign)

result_df = pd.DataFrame({'Largest Value': largest_values, 'Largest Column': largest_columns, 'Assignment': assignments})
result_df.shape
# Out:
# (161764, 3)

# %%
result_df.head(20)
# Out:
#     Largest Value  Largest Column      Assignment
# 0        0.976396       CD14_Mono       CD14_Mono
# 1        0.953964         CD4_TCM         CD4_TCM
# 2        0.998570       CD8_Naive       CD8_Naive
# 3        0.998050              NK              NK
# 4        0.966889       CD8_Naive       CD8_Naive
# 5        0.985130         CD8_TEM         CD8_TEM
# 6        0.785592       CD14_Mono       CD14_Mono
# 7        0.790866  B_intermediate  B_intermediate
# 8        0.999914              NK              NK
# 9        0.981501       CD8_Naive       CD8_Naive
# 10       0.462976       CD4_Naive       CD4_Naive
# 11       0.366650         CD4_TCM         CD4_TCM
# 12       0.922839         CD4_CTL         CD4_CTL
# 13       0.993312         B_naive         B_naive
# 14       0.997486       CD14_Mono       CD14_Mono
# 15       0.973121         CD4_TCM         CD4_TCM
# 16       0.610858            MAIT            MAIT
# 17       0.999572              NK              NK
# 18       0.996153         CD4_TCM         CD4_TCM
# 19       0.999938              NK              NK

# %%
# count 'uncertain'
sum(result_df['Assignment'] == 'Uncertain')
# Out:
# 0

# %% [markdown]
# ## Confusion heatmap

# %%
import pandas as pd

# Get the true labels
true_labels = adata.obs['celltype.l2'].tolist()

# Get the predicted labels
predicted_labels = result_df['Assignment'].tolist()

# Create the confusion matrix
cm = pd.crosstab(true_labels, predicted_labels, rownames=['True'], colnames=['Predicted'], margins=False)

# reorder columns
# cm = cm.reindex(types + ['Uncertain'], axis=1)

# replace NaN with 0
cm = cm.fillna(0)
cm = cm.astype(int)

# %%
# remove irrelevant cell types
irrelevant = ['Doublet', 'Eryth', 'Platelet']
cm = cm.drop(irrelevant, axis=0)
cm = cm.drop(irrelevant, axis=1)
cm.shape
# Out:
# (28, 28)

# %%
cm
# Out:
# Predicted          ASDC  B_intermediate  B_memory  B_naive  CD14_Mono  \
# True
# ASDC                 61               0         0        0          0
# B_intermediate        0            1689       231      491          2
# B_memory              0             136      3110       27          1
# B_naive               0             120        58     7524          1
# CD14_Mono             0               1         1        2      42410
# CD16_Mono             0               0         1        0        370
# CD4_CTL               0               0         0        0          0
# CD4_Naive             0               0         0        0          0
# CD4_Proliferating     0               0         0        0          2
# CD4_TCM               0               0         0        0          1
# CD4_TEM               0               0         0        0          0
# CD8_Naive             0               0         0        0          1
# CD8_Proliferating     0               0         0        0          0
# CD8_TCM               0               0         0        0          0
# CD8_TEM               0               0         0        0          2
# HSPC                  0               0         0        0          0
# ILC                   0               0         0        0          0
# MAIT                  0               0         0        0          0
# NK                    0               1         0        0          0
# NK_CD56bright         0               0         0        0          0
# NK_Proliferating      0               0         0        0          0
# Plasmablast           0               1         9        0          1
# Treg                  0               0         1        0          0
# cDC1                  0               0         0        0          0
# cDC2                  0               0         0        0        189
# dnT                   0               0         0        0          0
# gdT                   0               0         0        0          2
# pDC                   0               0         0        0          2
#
# Predicted          CD16_Mono  CD4_CTL  CD4_Naive  CD4_Proliferating  CD4_TCM  \
# True
# ASDC                       0        0          0                  0        0
# B_intermediate             0        0          1                  0        4
# B_memory                   1        0          1                  1        1
# B_naive                    3        0          1                  0        0
# CD14_Mono                192        2          2                  0        2
# CD16_Mono               5936        0          0                  0        0
# CD4_CTL                    0     1597          1                  0        3
# CD4_Naive                  0        0      16906                  0      403
# CD4_Proliferating          0        0          0                 89        7
# CD4_TCM                    0       15        792                  0    13401
# CD4_TEM                    0       64         10                  0     1450
# CD8_Naive                  0        0        240                  0       28
# CD8_Proliferating          0        4          0                  2        0
# CD8_TCM                    0        1         18                  0      491
# CD8_TEM                    0       70          3                  0       36
# HSPC                       0        0          0                  0        0
# ILC                        0        0          0                  0       12
# MAIT                       0        6          0                  0       14
# NK                         0        1          0                  0        1
# NK_CD56bright              0        0          0                  0        0
# NK_Proliferating           0        1          0                 12        0
# Plasmablast                1        0          0                  0        0
# Treg                       0        0        238                  0      172
# cDC1                       0        0          0                  0        0
# cDC2                       1        0          0                  0        1
# dnT                        0        0         27                  0        8
# gdT                        0        5         63                  0       15
# pDC                        3        0          0                  0        0
#
# Predicted          ...     NK  NK_CD56bright  NK_Proliferating  Plasmablast  \
# True               ...
# ASDC               ...      0              0                 0            0
# B_intermediate     ...      6              0                 0            0
# B_memory           ...      0              0                 0            4
# B_naive            ...      3              2                 0            0
# CD14_Mono          ...      2              0                 0            3
# CD16_Mono          ...      2              0                 0            0
# CD4_CTL            ...      7              0                 0            0
# CD4_Naive          ...      0              0                 0            0
# CD4_Proliferating  ...      0              0                 3            0
# CD4_TCM            ...      1              0                 0            0
# CD4_TEM            ...      0              0                 0            1
# CD8_Naive          ...      0              0                 1            0
# CD8_Proliferating  ...      0              0                21            0
# CD8_TCM            ...      1              0                 0            0
# CD8_TEM            ...    101              2                 1            0
# HSPC               ...      0              0                 0            0
# ILC                ...      0              1                 0            0
# MAIT               ...      3              2                 0            0
# NK                 ...  16995             42                16            0
# NK_CD56bright      ...    165            772                 0            0
# NK_Proliferating   ...    149              5               373            0
# Plasmablast        ...      0              0                 0          350
# Treg               ...      0              0                 0            0
# cDC1               ...      0              0                 0            0
# cDC2               ...      0              0                 0            0
# dnT                ...      0              0                 0            0
# gdT                ...    142              1                 0            0
# pDC                ...      0              0                 0            0
#
# Predicted          Treg  cDC1  cDC2  dnT   gdT  pDC
# True
# ASDC                  0     0     9    0     0    6
# B_intermediate        0     0     0    1     0    0
# B_memory              0     0     0    0     1    0
# B_naive               0     0     0    1     1    0
# CD14_Mono             2     0    45    1     0    1
# CD16_Mono             0     0     7    0     0    0
# CD4_CTL               1     0     0    0     3    0
# CD4_Naive            82     0     0   13     6    0
# CD4_Proliferating     0     0     0    1     0    0
# CD4_TCM             127     0     0    5     9    0
# CD4_TEM              19     0     0   15    14    0
# CD8_Naive            12     0     0    6     4    0
# CD8_Proliferating     0     0     0    0     1    0
# CD8_TCM              21     0     0    1     8    0
# CD8_TEM               3     0     0    8   136    0
# HSPC                  0     0     0    0     0    0
# ILC                   0     0     0    0     0    0
# MAIT                  0     0     0    0    13    0
# NK                    2     0     0    0    30    0
# NK_CD56bright         0     0     0    0     2    0
# NK_Proliferating      0     0     0    1     4    0
# Plasmablast           0     0     0    1     0    0
# Treg               2089     0     0    1     0    0
# cDC1                  0   148     3    0     0    0
# cDC2                  0     2  2307    0     0    0
# dnT                  11     0     0  240     5    0
# gdT                  11     0     0    9  3017    0
# pDC                   0     0     0    0     0  856
#
# [28 rows x 28 columns]

# %%
os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch\Level2_log_inv")
cm.to_csv('confusion_matrix_v3.csv')

# %%
cm = pd.read_csv('confusion_matrix_v3.csv', index_col=0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('LR Prediction Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
row_sum = cm.sum(axis=1)
row_sum
# Out:
# True
# ASDC                    76
# B_intermediate        2430
# B_memory              3285
# B_naive               7718
# CD14_Mono            42674
# CD16_Mono             6316
# CD4_CTL               1736
# CD4_Naive            17477
# CD4_Proliferating      108
# CD4_TCM              14885
# CD4_TEM               4282
# CD8_Naive            10767
# CD8_Proliferating       91
# CD8_TCM               2883
# CD8_TEM              11726
# HSPC                   329
# ILC                    132
# MAIT                  2784
# NK                   17168
# NK_CD56bright          942
# NK_Proliferating       548
# Plasmablast            366
# Treg                  2505
# cDC1                   151
# cDC2                  2501
# dnT                    356
# gdT                   3649
# pDC                    861
# dtype: int64

# %%
cm_proportion = cm.div(row_sum, axis=0)
cm_proportion *= 100
plt.figure(figsize=(20, 20))
sns.heatmap(cm_proportion, fmt=".1f", annot=True, cmap='Blues')
plt.title('LR Prediction Confusion Matrix (Proportion %)')
plt.savefig('cm_plot.png', dpi=300)
plt.show()

# %% [markdown]
# ## Calculate accuracy

# %%
accuracy = sum(np.diag(cm)) / cm.values.sum()
accuracy
# Out:
# 0.9352361634308896

# %%
cm.values.sum()
# Out:
# 158746
