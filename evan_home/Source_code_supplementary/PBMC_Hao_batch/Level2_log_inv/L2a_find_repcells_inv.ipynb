# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import sklearn
from scipy.sparse import csr_matrix
import copy

# %%
adata = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Batch_corrected\Hao_PBMC_Harmony_unscaled.h5ad")
adata.shape  # row is cells, column is gene
# Out:
# (161764, 33538)

# %%
type(adata.X)
# Out:
# scipy.sparse._csc.csc_matrix

# %%
# view adata.X
rows, cols = adata.X[:5,:].nonzero()
i = 0
for row, col in zip(rows, cols):
    if i == 20: break
    print(f'Row {row}, Column {col}, Value {adata.X[row, col]}')
    i += 1
# Out:
# Row 0, Column 12, Value 0.4895154535770416
# Row 0, Column 43, Value 0.8167138695716858
# Row 0, Column 48, Value 0.8167138695716858
# Row 0, Column 53, Value 0.8167138695716858
# Row 0, Column 55, Value 1.424944519996643
# Row 0, Column 66, Value 0.4895154535770416
# Row 0, Column 77, Value 0.8167138695716858
# Row 0, Column 78, Value 1.424944519996643
# Row 0, Column 89, Value 0.8167138695716858
# Row 0, Column 93, Value 1.0628387928009033
# Row 0, Column 102, Value 0.8167138695716858
# Row 0, Column 154, Value 2.4626553058624268
# Row 0, Column 178, Value 0.8167138695716858
# Row 0, Column 185, Value 0.4895154535770416
# Row 0, Column 190, Value 0.4895154535770416
# Row 0, Column 201, Value 1.8004224300384521
# Row 0, Column 224, Value 0.8167138695716858
# Row 0, Column 240, Value 0.4895154535770416
# Row 0, Column 259, Value 0.4895154535770416
# Row 0, Column 261, Value 1.566353440284729

# %%
# assuming data.X is your sparse CSR matrix
num_nonzero = adata.X.getnnz(axis=1)  # number of nonzeros for each row
num_nonzero[:10]
# Out:
# array([2915, 1617, 1381, 1890, 1621, 1633, 2672, 1122, 1375, 1200],
#       dtype=int64)

# %%
# All level 1 celltypes
adata.obs['celltype.l1'] = adata.obs['celltype.l1'].str.replace(" ", "_")
adata.obs['celltype.l2'] = adata.obs['celltype.l2'].str.replace(" ", "_")
adata.obs['celltype.l3'] = adata.obs['celltype.l3'].str.replace(" ", "_")
types = np.unique(adata.obs['celltype.l2']).tolist()
print(types)
# cell count in each celltype
adata.obs['celltype.l2'].value_counts()
# Out:
# ['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC']
# celltype.l2
# CD14_Mono            42690
# CD4_Naive            17479
# NK                   17173
# CD4_TCM              14889
# CD8_TEM              11727
# CD8_Naive            10768
# B_naive               7718
# CD16_Mono             6320
# CD4_TEM               4282
# gdT                   3649
# B_memory              3285
# CD8_TCM               2883
# MAIT                  2784
# Treg                  2507
# cDC2                  2501
# B_intermediate        2431
# Platelet              2293
# CD4_CTL               1736
# NK_CD56bright          943
# pDC                    861
# Doublet                605
# NK_Proliferating       548
# Plasmablast            366
# dnT                    356
# HSPC                   329
# cDC1                   151
# ILC                    132
# CD4_Proliferating      108
# CD8_Proliferating       91
# Eryth                   83
# ASDC                    76
# Name: count, dtype: int64

# %%
adata.obs.head()
# Out:
#                     celltype.l1 celltype.l2 celltype.l3   Batch donor  time  \
# L1_AAACCCAAGAAACTCA        Mono   CD14_Mono   CD14_Mono  Batch1    P2     7
# L1_AAACCCAAGACATACA       CD4_T     CD4_TCM   CD4_TCM_1  Batch1    P1     7
# L1_AAACCCACAACTGGTT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     2
# L1_AAACCCACACGTACTA          NK          NK        NK_2  Batch1    P3     7
# L1_AAACCCACAGCATACT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     7
#
#                     lane Phase  nCount_ADT  nFeature_ADT  nCount_RNA  \
# L1_AAACCCAAGAAACTCA   L1    G1        7535           217       10823
# L1_AAACCCAAGACATACA   L1    G1        6013           209        5864
# L1_AAACCCACAACTGGTT   L1     S        6620           213        5067
# L1_AAACCCACACGTACTA   L1    G1        3567           202        4786
# L1_AAACCCACAGCATACT   L1    G1        6402           215        6505
#
#                      nFeature_RNA leiden
# L1_AAACCCAAGAAACTCA          2915      4
# L1_AAACCCAAGACATACA          1617      2
# L1_AAACCCACAACTGGTT          1381      5
# L1_AAACCCACACGTACTA          1890      3
# L1_AAACCCACAGCATACT          1621      5

# %% [markdown]
# ## UMAP with stored embedding in Hao_PBMC_scaled_Harmony.h5ad

# %%
sc.pl.umap(adata, color=['leiden', 'Batch'], legend_loc="on data")
sc.pl.umap(adata, color=['celltype.l1', 'celltype.l2'], legend_loc="right margin")
# Out:
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## Representative cells
# Select top clustering coefficient cells in each cell type <br>
# According to the inverse relationshiop between "celltype cell count" and "Percentage" <br>
# Detailed in Excel file <br>

# %%
umap_adja_matrix = adata.obsp['connectivities']
umap_adja_matrix
# Out:
# <161764x161764 sparse matrix of type '<class 'numpy.float32'>'
# 	with 3703860 stored elements in Compressed Sparse Row format>

# %%
# Clustering coefficient
import networkx as nx

G = nx.from_scipy_sparse_array(umap_adja_matrix)
print(G)

clustering_coeff = nx.clustering(G)
print(len(clustering_coeff))
# Out:
# Graph with 161764 nodes and 1851930 edges
# 161764

# %%
# Get the first 10 keys and values of the dictionary
first_10_items = list(clustering_coeff.items())[:10]

# Print the first 10 keys and values
for key, value in first_10_items:
    print(f"Key: {key}, Value: {value}")

# Keys are cell index, values are the corresponding clustering coefficient
# Out:
# Key: 0, Value: 0.11904761904761904
# Key: 1, Value: 0.1323529411764706
# Key: 2, Value: 0.17582417582417584
# Key: 3, Value: 0.12087912087912088
# Key: 4, Value: 0.10526315789473684
# Key: 5, Value: 0.17647058823529413
# Key: 6, Value: 0.13333333333333333
# Key: 7, Value: 0.13333333333333333
# Key: 8, Value: 0.13071895424836602
# Key: 9, Value: 0.10476190476190476

# %%
# Plot the distribution of clustering coefficients
import matplotlib.pyplot as plt
coefs = list(clustering_coeff.values())
plt.hist(coefs, bins=50)
plt.show()

# %%
# selection criteria
inv_percentage = pd.read_csv('L2_log(count)_inv_percentage.csv', index_col=0)
inv_percentage
# Out:
#                    Original count  log10(count)  Percentage  Selected count
# CD14_Mono                   42690      4.630326    0.200000            8538
# CD4_Naive                   17479      4.242517    0.312837            5469
# NK                          17173      4.234846    0.315069            5411
# CD4_TCM                     14889      4.172866    0.333103            4960
# CD8_TEM                     11727      4.069187    0.363269            4261
# CD8_Naive                   10768      4.032135    0.374050            4028
# B_naive                      7718      3.887505    0.416132            3212
# CD16_Mono                    6320      3.800717    0.441384            2790
# CD4_TEM                      4282      3.631647    0.490576            2101
# gdT                          3649      3.562174    0.510790            1864
# B_memory                     3285      3.516535    0.524069            1722
# CD8_TCM                      2883      3.459845    0.540564            1559
# MAIT                         2784      3.444669    0.544980            1518
# Treg                         2507      3.399154    0.558223            1400
# cDC2                         2501      3.398114    0.558525            1397
# B_intermediate               2431      3.385785    0.562113            1367
# Platelet                     2293      3.360404    0.569497            1306
# CD4_CTL                      1736      3.239550    0.604661            1050
# NK_CD56bright                 943      2.974512    0.681777             643
# pDC                           861      2.935003    0.693272             597
# Doublet                       605      2.781755    0.737861             447
# NK_Proliferating              548      2.738781    0.750365             412
# Plasmablast                   366      2.563481    0.801371             294
# dnT                           356      2.551450    0.804871             287
# HSPC                          329      2.517196    0.814838             269
# cDC1                          151      2.178977    0.913246             138
# ILC                           132      2.120574    0.930239             123
# CD4_Proliferating             108      2.033424    0.955596             104
# CD8_Proliferating              91      1.959041    0.977239              89
# Eryth                          83      1.919078    0.988867              83
# ASDC                           76      1.880814    1.000000              76

# %%
import math
# Select top 20% clustering coefficient cells in each cell type
alltype_selected = dict()

for celltype in types:
    print('====================')
    print(celltype)
    # get percentage
    percentage = inv_percentage.loc[celltype, 'Percentage']
    print(celltype, percentage)

    # select cells from one celltype
    celltype_idx = np.where(adata.obs['celltype.l2'] == celltype)[0]
    celltype_coeff = {node_idx: clustering_coeff[node_idx] for node_idx in celltype_idx}
    
    top_count = math.ceil(len(celltype_coeff) * percentage)
    print('top count', top_count)
    top_indices = sorted(celltype_coeff, key=celltype_coeff.get, reverse=True)[:top_count]  # sort celltype_coeff by value (descending)
    # print(top_indices)
    celltype_selected = {node_idx: celltype_coeff[node_idx] for node_idx in top_indices}
    # print(celltype_selected)
    alltype_selected.update(celltype_selected)
    print(celltype, len(celltype_selected))
# Out:
# ====================
# ASDC
# ASDC 1.0
# top count 76
# ASDC 76
# ====================
# B_intermediate
# B_intermediate 0.562112532
# top count 1367
# B_intermediate 1367
# ====================
# B_memory
# B_memory 0.524069305
# top count 1722
# B_memory 1722
# ====================
# B_naive
# B_naive 0.416131802
# top count 3212
# B_naive 3212
# ====================
# CD14_Mono
# CD14_Mono 0.2
# top count 8538
# CD14_Mono 8538
# ====================
# CD16_Mono
# CD16_Mono 0.441383608
# top count 2790
# CD16_Mono 2790
# ====================
# CD4_CTL
# CD4_CTL 0.604661234
# top count 1050
# CD4_CTL 1050
# ====================
# CD4_Naive
# CD4_Naive 0.312837331
# top count 5469
# CD4_Naive 5469
# ====================
# CD4_Proliferating
# CD4_Proliferating 0.955596446
# top count 104
# CD4_Proliferating 104
# ====================
# CD4_TCM
# CD4_TCM 0.333103047
# top count 4960
# CD4_TCM 4960
# ====================
# CD4_TEM
# CD4_TEM 0.490576448
# top count 2101
# CD4_TEM 2101
# ====================
# CD8_Naive
# CD8_Naive 0.374050082
# top count 4028
# CD8_Naive 4028
# ====================
# CD8_Proliferating
# CD8_Proliferating 0.977238787
# top count 89
# CD8_Proliferating 89
# ====================
# CD8_TCM
# CD8_TCM 0.540564078
# top count 1559
# CD8_TCM 1559
# ====================
# CD8_TEM
# CD8_TEM 0.363269443
# top count 4261
# CD8_TEM 4261
# ====================
# Doublet
# Doublet 0.737861381
# top count 447
# Doublet 447
# ====================
# Eryth
# Eryth 0.988866536
# top count 83
# Eryth 83
# ====================
# HSPC
# HSPC 0.814837782
# top count 269
# HSPC 269
# ====================
# ILC
# ILC 0.930239173
# top count 123
# ILC 123
# ====================
# MAIT
# MAIT 0.544979525
# top count 1518
# MAIT 1518
# ====================
# NK
# NK 0.315069119
# top count 5411
# NK 5411
# ====================
# NK_CD56bright
# NK_CD56bright 0.681776875
# top count 643
# NK_CD56bright 643
# ====================
# NK_Proliferating
# NK_Proliferating 0.750365362
# top count 412
# NK_Proliferating 412
# ====================
# Plasmablast
# Plasmablast 0.801370613
# top count 294
# Plasmablast 294
# ====================
# Platelet
# Platelet 0.569497377
# top count 1306
# Platelet 1306
# ====================
# Treg
# Treg 0.55822257
# top count 1400
# Treg 1400
# ====================
# cDC1
# cDC1 0.913246192
# top count 138
# cDC1 138
# ====================
# cDC2
# cDC2 0.558525356
# top count 1397
# cDC2 1397
# ====================
# dnT
# dnT 0.804871186
# top count 287
# dnT 287
# ====================
# gdT
# gdT 0.5107903
# top count 1864
# gdT 1864
# ====================
# pDC
# pDC 0.693272306
# top count 597
# pDC 597

# %%
len(alltype_selected)
# Out:
# 57515

# %%
# add column to adata.obs
is_representative = ['Yes' if cell in alltype_selected.keys() else 'No' for cell in clustering_coeff.keys()]
is_representative = np.array(is_representative)

# Add is_representative (Yes or No) to data.obs
adata.obs['is_representative'] = is_representative
adata.obs.head()
# Out:
#                     celltype.l1 celltype.l2 celltype.l3   Batch donor  time  \
# L1_AAACCCAAGAAACTCA        Mono   CD14_Mono   CD14_Mono  Batch1    P2     7
# L1_AAACCCAAGACATACA       CD4_T     CD4_TCM   CD4_TCM_1  Batch1    P1     7
# L1_AAACCCACAACTGGTT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     2
# L1_AAACCCACACGTACTA          NK          NK        NK_2  Batch1    P3     7
# L1_AAACCCACAGCATACT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     7
#
#                     lane Phase  nCount_ADT  nFeature_ADT  nCount_RNA  \
# L1_AAACCCAAGAAACTCA   L1    G1        7535           217       10823
# L1_AAACCCAAGACATACA   L1    G1        6013           209        5864
# L1_AAACCCACAACTGGTT   L1     S        6620           213        5067
# L1_AAACCCACACGTACTA   L1    G1        3567           202        4786
# L1_AAACCCACAGCATACT   L1    G1        6402           215        6505
#
#                      nFeature_RNA leiden is_representative
# L1_AAACCCAAGAAACTCA          2915      4                No
# L1_AAACCCAAGACATACA          1617      2                No
# L1_AAACCCACAACTGGTT          1381      5               Yes
# L1_AAACCCACACGTACTA          1890      3                No
# L1_AAACCCACAGCATACT          1621      5                No

# %%
sum(adata.obs['is_representative'] == 'Yes')
# Out:
# 57515

# %%
# Add a column: Cluster_representative
# 在 representative cell 中，加上 cluster
clus_rep = []
for i in range(adata.shape[0]):
    if adata.obs['is_representative'][i] == 'Yes':
        # Yes_cluster_name
        clus_rep.append(adata.obs['is_representative'][i] + '_' + adata.obs['celltype.l2'][i])
    else:
        # No
        clus_rep.append(adata.obs['is_representative'][i])

adata.obs['cluster_representative'] = clus_rep
# Out:
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_26340\2774745940.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if adata.obs['is_representative'][i] == 'Yes':
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_26340\2774745940.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   clus_rep.append(adata.obs['is_representative'][i])
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_26340\2774745940.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   clus_rep.append(adata.obs['is_representative'][i] + '_' + adata.obs['celltype.l2'][i])

# %%
adata.obs.head()
# Out:
#                     celltype.l1 celltype.l2 celltype.l3   Batch donor  time  \
# L1_AAACCCAAGAAACTCA        Mono   CD14_Mono   CD14_Mono  Batch1    P2     7
# L1_AAACCCAAGACATACA       CD4_T     CD4_TCM   CD4_TCM_1  Batch1    P1     7
# L1_AAACCCACAACTGGTT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     2
# L1_AAACCCACACGTACTA          NK          NK        NK_2  Batch1    P3     7
# L1_AAACCCACAGCATACT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     7
#
#                     lane Phase  nCount_ADT  nFeature_ADT  nCount_RNA  \
# L1_AAACCCAAGAAACTCA   L1    G1        7535           217       10823
# L1_AAACCCAAGACATACA   L1    G1        6013           209        5864
# L1_AAACCCACAACTGGTT   L1     S        6620           213        5067
# L1_AAACCCACACGTACTA   L1    G1        3567           202        4786
# L1_AAACCCACAGCATACT   L1    G1        6402           215        6505
#
#                      nFeature_RNA leiden is_representative  \
# L1_AAACCCAAGAAACTCA          2915      4                No
# L1_AAACCCAAGACATACA          1617      2                No
# L1_AAACCCACAACTGGTT          1381      5               Yes
# L1_AAACCCACACGTACTA          1890      3                No
# L1_AAACCCACAGCATACT          1621      5                No
#
#                     cluster_representative
# L1_AAACCCAAGAAACTCA                     No
# L1_AAACCCAAGACATACA                     No
# L1_AAACCCACAACTGGTT          Yes_CD8_Naive
# L1_AAACCCACACGTACTA                     No
# L1_AAACCCACAGCATACT                     No

# %% [markdown]
# ## Plot representative cell UMAP

# %%
### Get palette
# Get cell counts for each cell type
l1_cell_counts = adata.obs['celltype.l1'].value_counts()  # in value order 
l2_cell_counts = adata.obs['celltype.l2'].value_counts()

# Get colors from sc.pl.umap() plot
l1_colors = adata.uns['celltype.l1_colors']  # in celltype alphabet order
l2_colors = adata.uns['celltype.l2_colors']
# map cell type names to colors
l1_cmap = dict(zip(l1_cell_counts.index.sort_values(), l1_colors))  # in alphabet order
l2_cmap = dict(zip(l2_cell_counts.index.sort_values(), l2_colors))

# %%
# Plot Yes/No representative cells
sc.pl.umap(adata, color='is_representative', title='Level2 Representative cells', palette=['#dcdcdc', 'red'])
# Out:
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# Also differentiating representative cells from different cell types
sc.pl.umap(adata, color='cluster_representative', title='Level2 Representative cells', palette=['#dcdcdc']+l2_colors.tolist())
# Out:
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# c:\Users\evanlee\AppData\Local\Programs\Python\Python39\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## Export representative cells adata

# %%
os.chdir(r'C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Batch_corrected')

# %%
adata_rep_cells = adata[adata.obs['is_representative'] == 'Yes']
adata_rep_cells.shape
# Out:
# (57515, 33538)

# %%
adata_rep_cells.obs.head()
# Out:
#                     celltype.l1 celltype.l2 celltype.l3   Batch donor  time  \
# L1_AAACCCACAACTGGTT       CD8_T   CD8_Naive   CD8_Naive  Batch1    P4     2
# L1_AAACCCACATCAGTCA       CD8_T     CD8_TEM   CD8_TEM_1  Batch1    P3     2
# L1_AAACGAACAATGAGCG       CD4_T     CD4_TCM   CD4_TCM_2  Batch1    P1     7
# L1_AAACGAACAGCTACTA          NK          NK        NK_2  Batch1    P4     7
# L1_AAACGAAGTATTCTCT       CD4_T     CD4_TCM   CD4_TCM_3  Batch1    P3     0
#
#                     lane Phase  nCount_ADT  nFeature_ADT  nCount_RNA  \
# L1_AAACCCACAACTGGTT   L1     S        6620           213        5067
# L1_AAACCCACATCAGTCA   L1    G1        5297           212        4332
# L1_AAACGAACAATGAGCG   L1    G1        5465           211        7379
# L1_AAACGAACAGCTACTA   L1    G1        3161           211        1538
# L1_AAACGAAGTATTCTCT   L1     S        5236           210        4747
#
#                      nFeature_RNA leiden is_representative  \
# L1_AAACCCACAACTGGTT          1381      5               Yes
# L1_AAACCCACATCAGTCA          1633      6               Yes
# L1_AAACGAACAATGAGCG          2315     17               Yes
# L1_AAACGAACAGCTACTA           822     12               Yes
# L1_AAACGAAGTATTCTCT          1397      2               Yes
#
#                     cluster_representative
# L1_AAACCCACAACTGGTT          Yes_CD8_Naive
# L1_AAACCCACATCAGTCA            Yes_CD8_TEM
# L1_AAACGAACAATGAGCG            Yes_CD4_TCM
# L1_AAACGAACAGCTACTA                 Yes_NK
# L1_AAACGAAGTATTCTCT            Yes_CD4_TCM

# %%
adata_rep_cells.write_h5ad('Hao_L2_rep_cells_loginv_Harmony.h5ad')

# %%
np.unique(adata_rep_cells.obs['celltype.l2']).tolist()
# Out:
# ['ASDC',
#  'B_intermediate',
#  'B_memory',
#  'B_naive',
#  'CD14_Mono',
#  'CD16_Mono',
#  'CD4_CTL',
#  'CD4_Naive',
#  'CD4_Proliferating',
#  'CD4_TCM',
#  'CD4_TEM',
#  'CD8_Naive',
#  'CD8_Proliferating',
#  'CD8_TCM',
#  'CD8_TEM',
#  'Doublet',
#  'Eryth',
#  'HSPC',
#  'ILC',
#  'MAIT',
#  'NK',
#  'NK_CD56bright',
#  'NK_Proliferating',
#  'Plasmablast',
#  'Platelet',
#  'Treg',
#  'cDC1',
#  'cDC2',
#  'dnT',
#  'gdT',
#  'pDC']
