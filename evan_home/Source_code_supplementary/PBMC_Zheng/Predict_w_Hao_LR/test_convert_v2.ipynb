# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mygene
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Read Hao dataset
adata = sc.read_h5ad('/Users/evanli/Documents/Research_datasets/PBMC_Hao/GSE164378_Hao/batch_corrected/Hao_PBMC_Harmony_unscaled.h5ad')
print('Original adata:', adata.shape)
adata.obs['celltype.l1'] = adata.obs['celltype.l1'].str.replace(' ', '_')
label = adata.obs['celltype.l1'].tolist()
types = np.unique(label).tolist()
print('all cell types:', types)
# Out:
# Original adata: (161764, 33538)
# all cell types: ['B', 'CD4_T', 'CD8_T', 'DC', 'Mono', 'NK', 'other', 'other_T']

# %%
adata.var.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3]

# %%
gene_symbols = adata.var_names.tolist()

# Initialize the mygene query object
mg = mygene.MyGeneInfo()

# Query the gene symbols to get Ensembl IDs
result = mg.querymany(gene_symbols, scopes=['symbol', 'alias', 'refseq'], fields=['ensembl.gene', 'entrezgene', 'symbol', 'name'], species='human', as_dataframe=True)
result.head(30)
# Out:
# 2505 input query terms found dup hits:	[('MIR1302-2HG', 2), ('OR4F5', 2), ('LINC00115', 2), ('LINC01786', 2), ('DVL1', 2), ('LINC01770', 2)
# 10182 input query terms found no hit:	['AL627309.1', 'AL627309.3', 'AL627309.2', 'AL627309.4', 'AL732372.1', 'AC114498.1', 'AL669831.2', '
#                          _id     _score  \
# query
# MIR1302-2HG  ENSG00000243485  26.271759
# MIR1302-2HG        107985730  26.271759
# FAM138A               645520  27.063152
# OR4F5                  79501  25.752413
# OR4F5                  81099  24.230534
# AL627309.1               NaN        NaN
# AL627309.3               NaN        NaN
# AL627309.2               NaN        NaN
# AL627309.4               NaN        NaN
# AL732372.1               NaN        NaN
# OR4F29                729759  25.746635
# AC114498.1               NaN        NaN
# OR4F16                 81399  26.272050
# AL669831.2               NaN        NaN
# AL669831.5               NaN        NaN
# FAM87B                400728  27.063547
# LINC00115    ENSG00000225880  26.271315
# LINC00115              79854  26.271315
# FAM41C                284593  27.059961
# AL645608.7               NaN        NaN
# AL645608.3               NaN        NaN
# AL645608.5               NaN        NaN
# AL645608.1               NaN        NaN
# SAMD11                148398  17.594423
# NOC2L                  26155  17.558527
# KLHL17                339451  17.563420
# PLEKHN1                84069  17.641476
# PERM1                  84808  17.985003
# AL645608.8               NaN        NaN
# HES4                   57801  18.679907
#
#                                                           name       symbol  \
# query
# MIR1302-2HG                                MIR1302-2 host gene  MIR1302-2HG
# MIR1302-2HG                                MIR1302-2 host gene  MIR1302-2HG
# FAM138A           family with sequence similarity 138 member A      FAM138A
# OR4F5         olfactory receptor family 4 subfamily F member 5        OR4F5
# OR4F5        olfactory receptor family 4 subfamily F member 17       OR4F17
# AL627309.1                                                 NaN          NaN
# AL627309.3                                                 NaN          NaN
# AL627309.2                                                 NaN          NaN
# AL627309.4                                                 NaN          NaN
# AL732372.1                                                 NaN          NaN
# OR4F29       olfactory receptor family 4 subfamily F member 29       OR4F29
# AC114498.1                                                 NaN          NaN
# OR4F16       olfactory receptor family 4 subfamily F member 16       OR4F16
# AL669831.2                                                 NaN          NaN
# AL669831.5                                                 NaN          NaN
# FAM87B             family with sequence similarity 87 member B       FAM87B
# LINC00115           long intergenic non-protein coding RNA 115    LINC00115
# LINC00115           long intergenic non-protein coding RNA 115    LINC00115
# FAM41C             family with sequence similarity 41 member C       FAM41C
# AL645608.7                                                 NaN          NaN
# AL645608.3                                                 NaN          NaN
# AL645608.5                                                 NaN          NaN
# AL645608.1                                                 NaN          NaN
# SAMD11                sterile alpha motif domain containing 11       SAMD11
# NOC2L        NOC2 like nucleolar associated transcriptional...        NOC2L
# KLHL17                             kelch like family member 17       KLHL17
# PLEKHN1               pleckstrin homology domain containing N1      PLEKHN1
# PERM1             PPARGC1 and ESRR induced regulator, muscle 1        PERM1
# AL645608.8                                                 NaN          NaN
# HES4                    hes family bHLH transcription factor 4         HES4
#
#                 ensembl.gene entrezgene notfound ensembl
# query
# MIR1302-2HG  ENSG00000243485        NaN      NaN     NaN
# MIR1302-2HG              NaN  107985730      NaN     NaN
# FAM138A      ENSG00000237613     645520      NaN     NaN
# OR4F5        ENSG00000186092      79501      NaN     NaN
# OR4F5        ENSG00000176695      81099      NaN     NaN
# AL627309.1               NaN        NaN     True     NaN
# AL627309.3               NaN        NaN     True     NaN
# AL627309.2               NaN        NaN     True     NaN
# AL627309.4               NaN        NaN     True     NaN
# AL732372.1               NaN        NaN     True     NaN
# OR4F29       ENSG00000284733     729759      NaN     NaN
# AC114498.1               NaN        NaN     True     NaN
# OR4F16       ENSG00000284662      81399      NaN     NaN
# AL669831.2               NaN        NaN     True     NaN
# AL669831.5               NaN        NaN     True     NaN
# FAM87B       ENSG00000177757     400728      NaN     NaN
# LINC00115    ENSG00000225880        NaN      NaN     NaN
# LINC00115                NaN      79854      NaN     NaN
# FAM41C       ENSG00000230368     284593      NaN     NaN
# AL645608.7               NaN        NaN     True     NaN
# AL645608.3               NaN        NaN     True     NaN
# AL645608.5               NaN        NaN     True     NaN
# AL645608.1               NaN        NaN     True     NaN
# SAMD11       ENSG00000187634     148398      NaN     NaN
# NOC2L        ENSG00000188976      26155      NaN     NaN
# KLHL17       ENSG00000187961     339451      NaN     NaN
# PLEKHN1      ENSG00000187583      84069      NaN     NaN
# PERM1        ENSG00000187642      84808      NaN     NaN
# AL645608.8               NaN        NaN     True     NaN
# HES4         ENSG00000188290      57801      NaN     NaN

# %%
print(result.shape)
result.to_csv('mygene_result_raw_v3.csv')
# Out:
# (36434, 8)

# %%
# result = pd.read_csv('mygene_result_raw_v3.csv', index_col=0)
# result.shape

# %%
# Fill all NaN with None
result = result.fillna('None')
# Fill all None in "notfound" with False
result['notfound'] = result['notfound'].replace('None', False)
result.head()
# Out:
#                          _id     _score  \
# query
# MIR1302-2HG  ENSG00000243485  26.271759
# MIR1302-2HG        107985730  26.271759
# FAM138A               645520  27.063152
# OR4F5                  79501  25.752413
# OR4F5                  81099  24.230534
#
#                                                           name       symbol  \
# query
# MIR1302-2HG                                MIR1302-2 host gene  MIR1302-2HG
# MIR1302-2HG                                MIR1302-2 host gene  MIR1302-2HG
# FAM138A           family with sequence similarity 138 member A      FAM138A
# OR4F5         olfactory receptor family 4 subfamily F member 5        OR4F5
# OR4F5        olfactory receptor family 4 subfamily F member 17       OR4F17
#
#                 ensembl.gene entrezgene  notfound ensembl
# query
# MIR1302-2HG  ENSG00000243485       None     False    None
# MIR1302-2HG             None  107985730     False    None
# FAM138A      ENSG00000237613     645520     False    None
# OR4F5        ENSG00000186092      79501     False    None
# OR4F5        ENSG00000176695      81099     False    None

# %%
import ast
row = result[result['ensembl'] != 'None'].iloc[0]
# ast.literal_eval(row['ensembl'])[0]['gene']
row['ensembl'][0]['gene']
# Out:
# 'ENSG00000149527'

# %%
import ast
from tqdm import tqdm

count = 0
for i, row in tqdm(result.iterrows(), total=result.shape[0]):
    if row['ensembl'] != 'None':
        # result.at[i, 'ensembl.gene'] = ast.literal_eval(row['ensembl'])[0]['gene']
        result.at[i, 'ensembl.gene'] = row['ensembl'][0]['gene']
        count += 1
    else:
        pass
# Out:
# 100%|██████████| 36434/36434 [00:02<00:00, 16943.32it/s]

# %%
count
# Out:
# 1694

# %%
# Create a mask for duplicated rows
duplicated_mask = result.index.duplicated(keep='first')

# Create a mask for rows where "ensembl.gene" is not None
not_none_mask = result['ensembl.gene'] != 'None'

# Use the masks to select the desired rows
# result = result[(not_none_mask & ~duplicated_mask) | (not_none_mask & duplicated_mask)]
result = result[(~duplicated_mask) | (not_none_mask & duplicated_mask)]
print(result.shape)
result.head(30)
# Out:
# (35331, 8)
#                          _id     _score  \
# query
# MIR1302-2HG  ENSG00000243485  26.271759
# FAM138A               645520  27.063152
# OR4F5                  79501  25.752413
# OR4F5                  81099  24.230534
# AL627309.1              None       None
# AL627309.3              None       None
# AL627309.2              None       None
# AL627309.4              None       None
# AL732372.1              None       None
# OR4F29                729759  25.746635
# AC114498.1              None       None
# OR4F16                 81399   26.27205
# AL669831.2              None       None
# AL669831.5              None       None
# FAM87B                400728  27.063547
# LINC00115    ENSG00000225880  26.271315
# FAM41C                284593  27.059961
# AL645608.7              None       None
# AL645608.3              None       None
# AL645608.5              None       None
# AL645608.1              None       None
# SAMD11                148398  17.594423
# NOC2L                  26155  17.558527
# KLHL17                339451   17.56342
# PLEKHN1                84069  17.641476
# PERM1                  84808  17.985003
# AL645608.8              None       None
# HES4                   57801  18.679907
# ISG15                   9636  18.324299
# AL645608.2              None       None
#
#                                                           name       symbol  \
# query
# MIR1302-2HG                                MIR1302-2 host gene  MIR1302-2HG
# FAM138A           family with sequence similarity 138 member A      FAM138A
# OR4F5         olfactory receptor family 4 subfamily F member 5        OR4F5
# OR4F5        olfactory receptor family 4 subfamily F member 17       OR4F17
# AL627309.1                                                None         None
# AL627309.3                                                None         None
# AL627309.2                                                None         None
# AL627309.4                                                None         None
# AL732372.1                                                None         None
# OR4F29       olfactory receptor family 4 subfamily F member 29       OR4F29
# AC114498.1                                                None         None
# OR4F16       olfactory receptor family 4 subfamily F member 16       OR4F16
# AL669831.2                                                None         None
# AL669831.5                                                None         None
# FAM87B             family with sequence similarity 87 member B       FAM87B
# LINC00115           long intergenic non-protein coding RNA 115    LINC00115
# FAM41C             family with sequence similarity 41 member C       FAM41C
# AL645608.7                                                None         None
# AL645608.3                                                None         None
# AL645608.5                                                None         None
# AL645608.1                                                None         None
# SAMD11                sterile alpha motif domain containing 11       SAMD11
# NOC2L        NOC2 like nucleolar associated transcriptional...        NOC2L
# KLHL17                             kelch like family member 17       KLHL17
# PLEKHN1               pleckstrin homology domain containing N1      PLEKHN1
# PERM1             PPARGC1 and ESRR induced regulator, muscle 1        PERM1
# AL645608.8                                                None         None
# HES4                    hes family bHLH transcription factor 4         HES4
# ISG15                            ISG15 ubiquitin like modifier        ISG15
# AL645608.2                                                None         None
#
#                 ensembl.gene entrezgene  notfound ensembl
# query
# MIR1302-2HG  ENSG00000243485       None     False    None
# FAM138A      ENSG00000237613     645520     False    None
# OR4F5        ENSG00000186092      79501     False    None
# OR4F5        ENSG00000176695      81099     False    None
# AL627309.1              None       None      True    None
# AL627309.3              None       None      True    None
# AL627309.2              None       None      True    None
# AL627309.4              None       None      True    None
# AL732372.1              None       None      True    None
# OR4F29       ENSG00000284733     729759     False    None
# AC114498.1              None       None      True    None
# OR4F16       ENSG00000284662      81399     False    None
# AL669831.2              None       None      True    None
# AL669831.5              None       None      True    None
# FAM87B       ENSG00000177757     400728     False    None
# LINC00115    ENSG00000225880       None     False    None
# FAM41C       ENSG00000230368     284593     False    None
# AL645608.7              None       None      True    None
# AL645608.3              None       None      True    None
# AL645608.5              None       None      True    None
# AL645608.1              None       None      True    None
# SAMD11       ENSG00000187634     148398     False    None
# NOC2L        ENSG00000188976      26155     False    None
# KLHL17       ENSG00000187961     339451     False    None
# PLEKHN1      ENSG00000187583      84069     False    None
# PERM1        ENSG00000187642      84808     False    None
# AL645608.8              None       None      True    None
# HES4         ENSG00000188290      57801     False    None
# ISG15        ENSG00000187608       9636     False    None
# AL645608.2              None       None      True    None

# %%
# check for further duplicates and keep first instance
dup2 = result.index.duplicated(keep='first')
result = result[~dup2]
result.shape
# Out:
# (33538, 8)

# %% [markdown]
# ## Check the genes in results

# %%
# check whether the index of result in corporates most of the gene symbols in Hao
gene_symbols = adata.var_names.tolist()
result_symbols = result.index.tolist()
print(len(gene_symbols), len(result_symbols))
print(len(set(gene_symbols) & set(result_symbols)))
# Out:
# 33538 33538
# 33538

# %%
set(gene_symbols) == set(result_symbols)
# Out:
# True

# %%
gene_symbols == result_symbols
# Out:
# True

# %%
# Manually modify two genes
result.loc['PBK', 'ensembl.gene'] = 'ENSG00000168078'
result.loc['ZNF573', 'ensembl.gene'] = 'ENSG00000189144'

# %%
result.to_csv('mygene_result_v3.csv')

# %%
# How many genes are matched with ensembl ID
# sum(result['ensembl.gene'] != 'None')
sum([g.startswith('ENSG') for g in result['ensembl.gene']])
# Out:
# 23192

# %%
# How many genes are found
sum(result['notfound'] == False)
# Out:
# 23356

# %%
df = result[(result['notfound'] == False) & (result['ensembl.gene'] == 'None')]
df.shape
# Out:
# (164, 8)

# %%
df
# Out:
#                     _id     _score  \
# query
# LINC00337        148645  25.039667
# NPPA-AS1      100379251  27.063152
# NBL1          100532736  20.138813
# MINOS1-NBL1   100532736  25.044989
# TRNP1              7207   22.07316
# ...                 ...        ...
# PCAT14        101978785  27.065735
# IGLVIVOR22-2      84087   8.730177
# ISX-AS1       101926957   24.21738
# LINC02246     107987295  25.044989
# LINC00319        284836  27.062708
#
#                                                            name        symbol  \
# query
# LINC00337                             ICMT divergent transcript       ICMT-DT
# NPPA-AS1                                   NPPA antisense RNA 1      NPPA-AS1
# NBL1                                   MICOS10-NBL1 readthrough  MICOS10-NBL1
# MINOS1-NBL1                            MICOS10-NBL1 readthrough  MICOS10-NBL1
# TRNP1                              tRNA-Leu (anticodon AAG) 2-3    TRL-AAG2-3
# ...                                                         ...           ...
# PCAT14                 prostate cancer associated transcript 14        PCAT14
# IGLVIVOR22-2  immunoglobulin lambda variable (IV)/OR22-2 (ps...  IGLVIVOR22-2
# ISX-AS1             long intergenic non-protein coding RNA 2885     LINC02885
# LINC02246       adipocyte associated metabolic related lncRNA 1        ASMER1
# LINC00319            long intergenic non-protein coding RNA 319     LINC00319
#
#              ensembl.gene entrezgene  notfound ensembl
# query
# LINC00337            None     148645     False    None
# NPPA-AS1             None  100379251     False    None
# NBL1                 None  100532736     False    None
# MINOS1-NBL1          None  100532736     False    None
# TRNP1                None       7207     False    None
# ...                   ...        ...       ...     ...
# PCAT14               None  101978785     False    None
# IGLVIVOR22-2         None      84087     False    None
# ISX-AS1              None  101926957     False    None
# LINC02246            None  107987295     False    None
# LINC00319            None     284836     False    None
#
# [164 rows x 8 columns]

# %% [markdown]
# ## Entrez as query for the remaining 164 genes (failed)

# %%
entrez = df['entrezgene'].tolist()

# %%
# Initialize the mygene query object
mg = mygene.MyGeneInfo()

# Query the gene symbols to get Ensembl IDs
new_result = mg.querymany(entrez, scopes=['entrezgene'], fields=['ensembl.gene', 'symbol', 'name'], species='human', as_dataframe=True)
# Out:
# 2 input query terms found dup hits:	[('100532736', 2), ('100302652', 2)]

# %%
new_result
# Out:
#                  _id     _score  \
# query
# 148645        148645  26.992018
# 100379251  100379251  26.988840
# 100532736  100532736  26.989302
# 100532736  100532736  26.989254
# 7207            7207  26.989716
# ...              ...        ...
# 101978785  101978785  26.985958
# 84087          84087   8.705148
# 101926957  101926957  26.197802
# 107987295  107987295  26.989582
# 284836        284836  26.989716
#
#                                                         name        symbol
# query
# 148645                             ICMT divergent transcript       ICMT-DT
# 100379251                               NPPA antisense RNA 1      NPPA-AS1
# 100532736                           MICOS10-NBL1 readthrough  MICOS10-NBL1
# 100532736                           MICOS10-NBL1 readthrough  MICOS10-NBL1
# 7207                            tRNA-Leu (anticodon AAG) 2-3    TRL-AAG2-3
# ...                                                      ...           ...
# 101978785           prostate cancer associated transcript 14        PCAT14
# 84087      immunoglobulin lambda variable (IV)/OR22-2 (ps...  IGLVIVOR22-2
# 101926957        long intergenic non-protein coding RNA 2885     LINC02885
# 107987295    adipocyte associated metabolic related lncRNA 1        ASMER1
# 284836            long intergenic non-protein coding RNA 319     LINC00319
#
# [164 rows x 4 columns]
