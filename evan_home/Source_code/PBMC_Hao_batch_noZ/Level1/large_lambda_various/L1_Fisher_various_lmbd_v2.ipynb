# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import json
import os
import re
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# %%
### Read representative cells
# types = ['B', 'CD4_T', 'CD8_T', 'DC', 'Mono', 'NK', 'other', 'other_T']
# adata_all = sc.read_h5ad('/Users/evanli/Documents/Research_datasets/PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')  # rep cells
# adata_all = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Harmony_noZ\Hao_Harmony_test_no_scale.h5ad")
adata_all = sc.read_h5ad(dataset_dir / 'PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')

print('Original adata:', adata_all.shape)
label = adata_all.obs['celltype.l1'].tolist()
types = np.unique(label).tolist()
print('all cell types:', types)
# Out:
# Original adata: (161764, 33538)
# all cell types: ['B', 'CD4 T', 'CD8 T', 'DC', 'Mono', 'NK', 'other', 'other T']

# %%
Hao_genes = adata_all.var_names.tolist()
len(Hao_genes)
# Out:
# 33538

# %% [markdown]
# ## Fisher exact test

# %%
import scipy.stats as stats

def perform_fisher_test(PreLect_genes, ACT_genes, Hao_genes):
    """
    Performs Fisher's exact test on the provided gene sets.

    Parameters:
    - PreLect_genes: Set of genes in PreLect_genes.
    - ACT_genes: Set of genes in ACT_genes.
    - Hao_genes: Set of all genes in Hao_genes (background population).

    Returns:
    - oddsratio: The odds ratio calculated from the contingency table.
    - p_value: The p-value from Fisher's exact test.
    """
    # Ensure the inputs are sets
    PreLect_genes = set(PreLect_genes)
    ACT_genes = set(ACT_genes)
    Hao_genes = set(Hao_genes)

    # Calculate the counts for the contingency table
    a = len(PreLect_genes & ACT_genes)                   # Genes in both PreLect_genes and ACT_genes
    b = len(PreLect_genes - ACT_genes)                   # Genes in PreLect_genes but not in ACT_genes
    c = len(ACT_genes - PreLect_genes)                   # Genes in ACT_genes but not in PreLect_genes
    d = len(Hao_genes - (PreLect_genes | ACT_genes))     # Genes in neither gene set

    # Construct the contingency table
    contingency_table = [[a, b],
                         [c, d]]

    # Perform Fisher's exact test
    oddsratio, p_value = stats.fisher_exact(contingency_table)

    # Output the results
    print("Contingency Table:")
    print(f"                   In ACT_genes    Not in ACT_genes")
    print(f"In PreLect_genes       {a}               {b}")
    print(f"Not in PreLect_genes   {c}            {d}")
    print(f"\nOdds Ratio: {oddsratio}")
    print(f"P-value: {p_value}")

    return oddsratio, p_value

# OR > 1: 
#   Indicates a positive association between being in PreLect_genes and being in ACT_genes
#   Genes in PreLect_genes are more likely to be in ACT_genes compared to genes not in PreLect_genes
#   The higher the OR, the stronger the positive association between PreLect_genes and ACT_genes

# %% [markdown]
# ## Read ACT markers

# %%
# marker_df = pd.read_csv('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level1/ACT_annotation/Human_blood_marker_processed.csv')
# marker_df = pd.read_csv(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level1\ACT_annotation\Human_blood_marker_processed.csv")
marker_df = pd.read_csv(source_code_dir / 'PBMC_Hao_batch_noZ/Level1/ACT_annotation/Human_blood_marker_processed.csv')
print(marker_df.shape)
marker_df.head()
# Out:
# (147, 6)
#   Species Tissue super_type  \
# 0   Human  Blood          B
# 1   Human  Blood      T_CD4
# 2   Human  Blood      T_CD4
# 3   Human  Blood        NaN
# 4   Human  Blood          T
#
#                                             CellType  \
# 0                                   Activated B cell
# 1          Activated CD4-positive, alpha-beta T cell
# 2  Activated CD4-positive, CD25-positive, CCR4-po...
# 3                  Adult endothelial progenitor cell
# 4                                  Alpha-beta T cell
#
#                                               Marker  \
# 0                              CD5, MIR155HG, TAGLN2
# 1  CD4, CCR6, CD14, CD19, CD38, CD3D, CD3G, CD69,...
# 2                       CD3D, CD3E, CD3G, CD4, FOXP3
# 3              KDR, PROM1, CD34, PTPRC, PECAM1, CD14
# 4                             CD3D, CD3E, CD3G, IL7R
#
#                                             Resource
# 0                        35025971, 28910360, 2474446
# 1  35381424, 32783921, 35831277, 34529726, 103413...
# 2                                           30977974
# 3  27561827, 29391882, 24641802, 29147957, 267700...
# 4                                 34284174, 28777444

# %%
def get_celltype_marker(name, marker_df):
    string = marker_df[marker_df['CellType'] == name]['Marker'].tolist()[0]
    marker_set = set(string.split(', '))
    return marker_set

# %%
ACT_name = ['B cell', 'CD4-positive, alpha-beta T cell', 'CD8-positive, alpha-beta T cell', 'Dendritic cell', 'Monocyte', 'Natural killer cell']
queue = ['B', 'CD4_T', 'CD8_T', 'DC', 'Mono', 'NK']
cluster_2_ACT_name = dict(zip(queue, ACT_name))
cluster_2_ACT_name
# Out:
# {'B': 'B cell',
#  'CD4_T': 'CD4-positive, alpha-beta T cell',
#  'CD8_T': 'CD8-positive, alpha-beta T cell',
#  'DC': 'Dendritic cell',
#  'Mono': 'Monocyte',
#  'NK': 'Natural killer cell'}

# %% [markdown]
# ## B: Read PreLect features at various lambdas

# %%
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level1/large_lambda_various/at_various_number/features_at_various_no')
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level1\large_lambda_various\at_various_number\features_at_various_no")
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level1/large_lambda_various/at_various_number/features_at_various_no')

celltype = 'B'
# Define the regular expression pattern using the celltype variable
pattern = re.compile(r'^{}_([0-9\.eE+-]+)_features\.txt$'.format(celltype))
# start with B_, followed by a number (which can include digits, decimal points, signs, and exponential notation), and end with _features.txt

# Get files with matching pattern
filenames = os.listdir()
matching_files = [filename for filename in filenames if pattern.match(filename)]
print(f'Data points for {celltype}:', len(matching_files))
matching_files
# Out:
# Data points for B: 7
# ['B_0.00031622776601683783_features.txt',
#  'B_0.0006812920690579617_features.txt',
#  'B_0.0014677992676220694_features.txt',
#  'B_0.003162277660168382_features.txt',
#  'B_0.006812920690579613_features.txt',
#  'B_0.014677992676220709_features.txt',
#  'B_0.0316227766016838_features.txt']

# %%
ACT_genes_celltype = get_celltype_marker(cluster_2_ACT_name[celltype], marker_df)
print(len(ACT_genes_celltype))
# ACT_genes: remove any that are not part of Hao_genes
ACT_genes_celltype = set(ACT_genes_celltype).intersection(set(Hao_genes))
print(len(ACT_genes_celltype))

# %%
profile_B = pd.DataFrame(columns=['Lambda', 'Odds_ratio', 'P-value'])

for file in matching_files:
    print('=====')
    lmbd = float(file.split('_')[1])
    print(lmbd)
    # feature_dict_at_lmbd = {}
    try:
        feature_df = pd.read_csv(file, names=['Gene', 'Weight', 'Tendency'], sep='\t')
        PreLect_genes_at_lmbd = feature_df['Gene'].tolist()
    except:
        print('skipping:', file)
        continue
    print(PreLect_genes_at_lmbd)
    print(len(PreLect_genes_at_lmbd))
    OR, p_v = perform_fisher_test(PreLect_genes_at_lmbd, ACT_genes_celltype, Hao_genes)
    profile_B = pd.concat([profile_B, pd.DataFrame({'Lambda': [lmbd], 'Odds_ratio': [OR], 'P-value': [p_v]})])
# Out:
# =====
# 0.006812920690579613
# ['S100A4', 'PTPRC', 'IGKC', 'BANK1', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'MALAT1', 'IGHM', 'B2M', 'CD79A', 'IGLC2']
# 14
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       7               7
# Not in PreLect_genes   51            33473
#
# Odds Ratio: 656.3333333333334
# P-value: 1.0802816498943125e-16
# =====
# 0.003162277660168382
# ['S100A4', 'RALGPS2', 'PTPRC', 'IGKC', 'BANK1', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'FTH1', 'MALAT1', 'ITM2B', 'IGHM', 'B2M', 'CD79B', 'MYL12A', 'CD79A', 'IGLC2']
# 19
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       8               11
# Not in PreLect_genes   50            33469
#
# Odds Ratio: 486.8218181818182
# P-value: 3.599511810301891e-18
# =====
# 0.0006812920690579617
# ['SH3BGRL3', 'S100A6', 'S100A4', 'RALGPS2', 'PTPRC', 'IGKC', 'JCHAIN', 'PLAC8', 'BANK1', 'MEF2C', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'FTH1', 'MALAT1', 'MYL6', 'TPT1', 'ITM2B', 'IGHA1', 'IGHM', 'B2M', 'ISG20', 'CD79B', 'MYL12A', 'KLF2', 'CD79A', 'IGLC2', 'IGLC3', 'TNFRSF13C']
# 31
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               22
# Not in PreLect_genes   49            33458
#
# Odds Ratio: 279.3339517625232
# P-value: 1.411281774467852e-18
# =====
# 0.0014677992676220694
# ['SH3BGRL3', 'S100A6', 'S100A4', 'RALGPS2', 'PTPRC', 'IGKC', 'BANK1', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'FTH1', 'MALAT1', 'ITM2B', 'IGHM', 'B2M', 'CD79B', 'MYL12A', 'CD79A', 'IGLC2', 'IGLC3']
# 22
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       8               14
# Not in PreLect_genes   50            33466
#
# Odds Ratio: 382.4685714285714
# P-value: 1.5168219111570417e-17
# =====
# 0.0316227766016838
# ['S100A4', 'IGKC', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'MALAT1', 'B2M', 'CD79A']
# 10
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               5
# Not in PreLect_genes   53            33475
#
# Odds Ratio: 631.6037735849056
# P-value: 3.245111912344803e-12
# =====
# 0.014677992676220709
# ['S100A4', 'IGKC', 'CD74', 'HLA-DRA', 'ACTB', 'TMSB4X', 'MS4A1', 'MALAT1', 'B2M', 'CD79A']
# 10
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               5
# Not in PreLect_genes   53            33475
#
# Odds Ratio: 631.6037735849056
# P-value: 3.245111912344803e-12
# =====
# 0.00031622776601683783
# ['SH3BGRL3', 'JUN', 'TXNIP', 'S100A6', 'S100A4', 'TPM3', 'RALGPS2', 'ARPC5', 'PTPRC', 'ZFP36L2', 'IGKC', 'JCHAIN', 'PLAC8', 'BANK1', 'SUB1', 'MEF2C', 'CD74', 'HLA-DRA', 'HLA-DQB1', 'EZR', 'ACTB', 'TMSB4X', 'TSC22D3', 'SARAF', 'PABPC1', 'RPL8', 'SWAP70', 'MS4A1', 'FTH1', 'MALAT1', 'MYL6', 'LYZ', 'TPT1', 'ITM2B', 'IGHA1', 'IGHM', 'B2M', 'LINC00926', 'ISG20', 'CD79B', 'MYL12A', 'MYL12B', 'KLF2', 'CD79A', 'CD37', 'RPS5', 'IGLC2', 'IGLC3', 'TNFRSF13C']
# 49
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               39
# Not in PreLect_genes   48            33441
#
# Odds Ratio: 178.63782051282053
# P-value: 8.225560498035137e-19

# %%
profile_B
# Out:
#      Lambda  Odds_ratio       P-value
# 0  0.006813  656.333333  1.080282e-16
# 0  0.003162  486.821818  3.599512e-18
# 0  0.000681  279.333952  1.411282e-18
# 0  0.001468  382.468571  1.516822e-17
# 0  0.031623  631.603774  3.245112e-12
# 0  0.014678  631.603774  3.245112e-12
# 0  0.000316  178.637821  8.225560e-19

# %% [markdown]
# ## For all types

# %%
def various_lmbd_PreLect_vs_ACT_fisher(celltype, ACT_genes, Hao_genes):
    # Define the regular expression pattern using the celltype variable
    pattern = re.compile(r'^{}_([0-9\.eE+-]+)_features\.txt$'.format(celltype))
    # start with B_, followed by a number (which can include digits, decimal points, signs, and exponential notation), and end with _features.txt

    # Get files with matching pattern
    filenames = os.listdir()
    matching_files = [filename for filename in filenames if pattern.match(filename)]
    print(f'Data points for {celltype}:', len(matching_files))

    fisher_result = pd.DataFrame(columns=['Lambda', 'Feature_no', 'Odds_ratio', 'P-value'])
    
    for file in matching_files:
        print('=====')
        lmbd = float(file.split('_')[-2])
        print(lmbd)
        try:
            feature_df = pd.read_csv(file, names=['Gene', 'Weight', 'Tendency'], sep='\t')
            PreLect_genes_at_lmbd = feature_df['Gene'].tolist()
        except:
            print('skipping:', file)
            continue
        print('PreLect feature no:', len(PreLect_genes_at_lmbd))
        OR, p_v = perform_fisher_test(PreLect_genes_at_lmbd, ACT_genes, Hao_genes)
        fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd], 
                                                                'Feature_no': [len(PreLect_genes_at_lmbd)], 
                                                                'Odds_ratio': [OR], 
                                                                'P-value': [p_v]})])
    
    return fisher_result

# %%
# output_path = '/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level1/large_lambda_various/L1_Fisher_result'
# output_path = r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level1\large_lambda_various\L1_Fisher_result_v2"
output_path = source_code_dir / 'PBMC_Hao_batch_noZ/Level1/large_lambda_various/L1_Fisher_result_v2'

for clus, name in cluster_2_ACT_name.items():
    ACT_genes_celltype = get_celltype_marker(name, marker_df)
    # ACT_genes: remove any that are not part of Hao_genes
    ACT_genes_celltype = set(ACT_genes_celltype).intersection(set(Hao_genes))
    print('==========')
    print(f'{clus}, ACT markers no:', len(ACT_genes_celltype))

    fisher_result = various_lmbd_PreLect_vs_ACT_fisher(clus, ACT_genes_celltype, Hao_genes)
    fisher_result = fisher_result.sort_values('Feature_no')
    print(fisher_result)
    fisher_result.to_csv(os.path.join(output_path, f'{clus}_fisher_result.csv'))
# Out:
# ==========
# B, ACT markers no: 58
# Data points for B: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 49
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               39
# Not in PreLect_genes   48            33441
#
# Odds Ratio: 178.63782051282053
# P-value: 8.225560497870962e-19
# =====
# 0.0006812920690579617
# PreLect feature no: 31
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               22
# Not in PreLect_genes   49            33458
#
# Odds Ratio: 279.3339517625232
# P-value: 1.4112817744210334e-18
# =====
# 0.0014677992676220694
# PreLect feature no: 22
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       8               14
# Not in PreLect_genes   50            33466
#
# Odds Ratio: 382.4685714285714
# P-value: 1.516821911228135e-17
# =====
# 0.003162277660168382
# PreLect feature no: 19
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       8               11
# Not in PreLect_genes   50            33469
#
# Odds Ratio: 486.8218181818182
# P-value: 3.59951181024466e-18
# =====
# 0.006812920690579613
# PreLect feature no: 14
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       7               7
# Not in PreLect_genes   51            33473
#
# Odds Ratio: 656.3333333333334
# P-value: 1.0802816498713282e-16
# =====
# 0.014677992676220709
# PreLect feature no: 10
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               5
# Not in PreLect_genes   53            33475
#
# Odds Ratio: 631.6037735849056
# P-value: 3.2451119123823735e-12
# =====
# 0.0316227766016838
# PreLect feature no: 10
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               5
# Not in PreLect_genes   53            33475
#
# Odds Ratio: 631.6037735849056
# P-value: 3.2451119123823735e-12
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.014678         10  631.603774  3.245112e-12
# 0  0.031623         10  631.603774  3.245112e-12
# 0  0.006813         14  656.333333  1.080282e-16
# 0  0.003162         19  486.821818  3.599512e-18
# 0  0.001468         22  382.468571  1.516822e-17
# 0  0.000681         31  279.333952  1.411282e-18
# 0  0.000316         49  178.637821  8.225560e-19
# ==========
# CD4_T, ACT markers no: 41
# Data points for CD4_T: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 575
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       19               556
# Not in PreLect_genes   22            32941
#
# Odds Ratio: 51.16734793982995
# P-value: 3.605463982267786e-23
# =====
# 0.0006812920690579617
# PreLect feature no: 404
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       16               388
# Not in PreLect_genes   25            33109
#
# Odds Ratio: 54.61278350515464
# P-value: 1.144549345940522e-20
# =====
# 0.0014677992676220694
# PreLect feature no: 201
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       13               188
# Not in PreLect_genes   28            33309
#
# Odds Ratio: 82.26006838905775
# P-value: 1.3211683217388098e-19
# =====
# 0.003162277660168382
# PreLect feature no: 105
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               95
# Not in PreLect_genes   31            33402
#
# Odds Ratio: 113.41935483870968
# P-value: 6.02579008500014e-17
# =====
# 0.006812920690579613
# PreLect feature no: 50
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               41
# Not in PreLect_genes   32            33456
#
# Odds Ratio: 229.5
# P-value: 5.73409634063056e-18
# =====
# 0.014677992676220709
# PreLect feature no: 24
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       7               17
# Not in PreLect_genes   34            33480
#
# Odds Ratio: 405.46712802768167
# P-value: 8.098950107815748e-16
# =====
# 0.0316227766016838
# PreLect feature no: 14
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       6               8
# Not in PreLect_genes   35            33489
#
# Odds Ratio: 717.6214285714286
# P-value: 6.785987111239233e-15
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.031623         14  717.621429  6.785987e-15
# 0  0.014678         24  405.467128  8.098950e-16
# 0  0.006813         50  229.500000  5.734096e-18
# 0  0.003162        105  113.419355  6.025790e-17
# 0  0.001468        201   82.260068  1.321168e-19
# 0  0.000681        404   54.612784  1.144549e-20
# 0  0.000316        575   51.167348  3.605464e-23
# ==========
# CD8_T, ACT markers no: 26
# Data points for CD8_T: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 480
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       16               464
# Not in PreLect_genes   10            33048
#
# Odds Ratio: 113.95862068965518
# P-value: 1.1255107800246744e-23
# =====
# 0.0006812920690579617
# PreLect feature no: 187
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       12               175
# Not in PreLect_genes   14            33337
#
# Odds Ratio: 163.28326530612244
# P-value: 5.694986680817211e-21
# =====
# 0.0014677992676220694
# PreLect feature no: 79
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       11               68
# Not in PreLect_genes   15            33444
#
# Odds Ratio: 360.67058823529413
# P-value: 4.495965353849145e-23
# =====
# 0.003162277660168382
# PreLect feature no: 39
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               30
# Not in PreLect_genes   17            33482
#
# Odds Ratio: 590.8588235294118
# P-value: 4.419728770134295e-21
# =====
# 0.006812920690579613
# PreLect feature no: 23
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       8               15
# Not in PreLect_genes   18            33497
#
# Odds Ratio: 992.5037037037036
# P-value: 1.917378483377757e-20
# =====
# 0.014677992676220709
# PreLect feature no: 19
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               14
# Not in PreLect_genes   21            33498
#
# Odds Ratio: 569.6938775510204
# P-value: 2.1480764305752363e-12
# =====
# 0.0316227766016838
# PreLect feature no: 13
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       4               9
# Not in PreLect_genes   22            33503
#
# Odds Ratio: 676.8282828282828
# P-value: 2.0185315997869293e-10
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.031623         13  676.828283  2.018532e-10
# 0  0.014678         19  569.693878  2.148076e-12
# 0  0.006813         23  992.503704  1.917378e-20
# 0  0.003162         39  590.858824  4.419729e-21
# 0  0.001468         79  360.670588  4.495965e-23
# 0  0.000681        187  163.283265  5.694987e-21
# 0  0.000316        480  113.958621  1.125511e-23
# ==========
# DC, ACT markers no: 47
# Data points for DC: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 102
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       13               89
# Not in PreLect_genes   34            33402
#
# Odds Ratio: 143.49834765366822
# P-value: 1.1118027188316774e-22
# =====
# 0.0006812920690579617
# PreLect feature no: 54
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               45
# Not in PreLect_genes   38            33446
#
# Odds Ratio: 176.03157894736842
# P-value: 4.683495217238577e-17
# =====
# 0.0014677992676220694
# PreLect feature no: 44
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               35
# Not in PreLect_genes   38            33456
#
# Odds Ratio: 226.39398496240602
# P-value: 6.3076222312411594e-18
# =====
# 0.003162277660168382
# PreLect feature no: 35
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       7               28
# Not in PreLect_genes   40            33463
#
# Odds Ratio: 209.14375
# P-value: 4.34004556895372e-14
# =====
# 0.006812920690579613
# PreLect feature no: 25
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       6               19
# Not in PreLect_genes   41            33472
#
# Odds Ratio: 257.80744544287546
# P-value: 9.435732412159444e-13
# =====
# 0.014677992676220709
# PreLect feature no: 21
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       6               15
# Not in PreLect_genes   41            33476
#
# Odds Ratio: 326.59512195121954
# P-value: 2.9032910189594827e-13
# =====
# 0.0316227766016838
# PreLect feature no: 11
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       5               6
# Not in PreLect_genes   42            33485
#
# Odds Ratio: 664.3849206349206
# P-value: 1.992295955060962e-12
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.031623         11  664.384921  1.992296e-12
# 0  0.014678         21  326.595122  2.903291e-13
# 0  0.006813         25  257.807445  9.435732e-13
# 0  0.003162         35  209.143750  4.340046e-14
# 0  0.001468         44  226.393985  6.307622e-18
# 0  0.000681         54  176.031579  4.683495e-17
# 0  0.000316        102  143.498348  1.111803e-22
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],
# ==========
# Mono, ACT markers no: 104
# Data points for Mono: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 497
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       31               466
# Not in PreLect_genes   73            32968
#
# Odds Ratio: 30.043153624551707
# P-value: 8.010964327353874e-32
# =====
# 0.0006812920690579617
# PreLect feature no: 214
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       25               189
# Not in PreLect_genes   79            33245
#
# Odds Ratio: 55.66438952514902
# P-value: 1.5001064438678283e-32
# =====
# 0.0014677992676220694
# PreLect feature no: 106
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       18               88
# Not in PreLect_genes   86            33346
#
# Odds Ratio: 79.31131078224101
# P-value: 1.1544124154209174e-26
# =====
# 0.003162277660168382
# PreLect feature no: 50
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       11               39
# Not in PreLect_genes   93            33395
#
# Odds Ratio: 101.28067273228564
# P-value: 4.995227567949122e-18
# =====
# 0.006812920690579613
# PreLect feature no: 29
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               19
# Not in PreLect_genes   94            33415
#
# Odds Ratio: 187.09406494960805
# P-value: 1.0052012937740821e-18
# =====
# 0.014677992676220709
# PreLect feature no: 19
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               10
# Not in PreLect_genes   95            33424
#
# Odds Ratio: 316.6484210526316
# P-value: 1.6742018674851282e-18
# =====
# 0.0316227766016838
# PreLect feature no: 15
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       9               6
# Not in PreLect_genes   95            33428
#
# Odds Ratio: 527.8105263157895
# P-value: 9.163869705504109e-20
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.031623         15  527.810526  9.163870e-20
# 0  0.014678         19  316.648421  1.674202e-18
# 0  0.006813         29  187.094065  1.005201e-18
# 0  0.003162         50  101.280673  4.995228e-18
# 0  0.001468        106   79.311311  1.154412e-26
# 0  0.000681        214   55.664390  1.500106e-32
# 0  0.000316        497   30.043154  8.010964e-32
# ==========
# NK, ACT markers no: 73
# Data points for NK: 7
# =====
# 0.00031622776601683783
# PreLect feature no: 159
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       33               126
# Not in PreLect_genes   40            33339
#
# Odds Ratio: 218.29107142857143
# P-value: 3.1241761033789087e-58
# =====
# 0.0006812920690579617
# PreLect feature no: 112
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       28               84
# Not in PreLect_genes   45            33381
#
# Odds Ratio: 247.26666666666668
# P-value: 1.2761800217023471e-51
# =====
# 0.0014677992676220694
# PreLect feature no: 72
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       20               52
# Not in PreLect_genes   53            33413
#
# Odds Ratio: 242.4746008708273
# P-value: 9.360055307754827e-38
# =====
# 0.003162277660168382
# PreLect feature no: 40
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       14               26
# Not in PreLect_genes   59            33439
#
# Odds Ratio: 305.1799217731421
# P-value: 3.155029124836954e-28
# =====
# 0.006812920690579613
# PreLect feature no: 33
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               23
# Not in PreLect_genes   63            33442
#
# Odds Ratio: 230.79365079365078
# P-value: 1.1159411427006616e-19
# =====
# 0.014677992676220709
# PreLect feature no: 24
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       10               14
# Not in PreLect_genes   63            33451
#
# Odds Ratio: 379.26303854875283
# P-value: 2.4012169917862836e-21
# =====
# 0.0316227766016838
# PreLect feature no: 16
# Contingency Table:
#                    In ACT_genes    Not in ACT_genes
# In PreLect_genes       7               9
# Not in PreLect_genes   66            33456
#
# Odds Ratio: 394.26262626262627
# P-value: 1.939299163988182e-15
#      Lambda Feature_no  Odds_ratio       P-value
# 0  0.031623         16  394.262626  1.939299e-15
# 0  0.014678         24  379.263039  2.401217e-21
# 0  0.006813         33  230.793651  1.115941e-19
# 0  0.003162         40  305.179922  3.155029e-28
# 0  0.001468         72  242.474601  9.360055e-38
# 0  0.000681        112  247.266667  1.276180e-51
# 0  0.000316        159  218.291071  3.124176e-58
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],
# C:\Users\evanlee\AppData\Local\Temp\ipykernel_20740\2721737929.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fisher_result = pd.concat([fisher_result, pd.DataFrame({'Lambda': [lmbd],

# %%
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level1/large_lambda_various/L1_Fisher_result_v2')
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level1\large_lambda_various\L1_Fisher_result_v2")
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level1/large_lambda_various/L1_Fisher_result_v2')

# %%
queue = ['B', 'CD4_T', 'CD8_T', 'DC', 'Mono', 'NK']

# %%
plt.figure(figsize=(8, 6))
for celltype in queue:
    try:
        fisher_result = pd.read_csv(f'{celltype}_fisher_result.csv', index_col=0)
    except:
        print('Skipping', celltype)
        continue
    
    plt.plot(fisher_result['Feature_no'], fisher_result['Odds_ratio'], marker='o', label=celltype)

plt.xlabel('Feature Number', fontsize=14)
plt.ylabel('Odds Ratio', fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.title('Fisher Test Odds Ratio by PreLect Feature Number', fontsize=16)
plt.legend(title='Cell Types')
plt.show()

# %%
plt.figure(figsize=(8, 6))
for celltype in queue:
    try:
        fisher_result = pd.read_csv(f'{celltype}_fisher_result.csv', index_col=0)
        fisher_result = fisher_result.sort_values(by='Lambda', ascending=True)
    except:
        print('Skipping', celltype)
        continue
    
    plt.plot(fisher_result['Lambda'], fisher_result['Odds_ratio'], marker='o', label=celltype)

plt.xlabel('Lambda', fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Odds Ratio', fontsize=14)
plt.title('Fisher Test Odds Ratio by PreLect Lambda', fontsize=16)
plt.legend(title='Cell Types', loc='lower right')
plt.show()
