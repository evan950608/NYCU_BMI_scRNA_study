# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import pickle
import xgboost as xgb

# %%
import scanpy as sc

# adata = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\PBMC_Hao\GSE164378_Hao\Harmony_noZ\Hao_Harmony_test_no_scale.h5ad")
# adata = sc.read_h5ad('/Users/evanli/Documents/Research_datasets/PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')
adata = sc.read_h5ad(dataset_dir / 'PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')
print('Original adata:', adata.shape)
adata.obs['celltype.l2'] = adata.obs['celltype.l2'].str.replace(' ', '_')
label = adata.obs['celltype.l2'].tolist()
types = np.unique(label).tolist()
print('all cell types:', types)
print('====================')
# del adata
# Out:
# Original adata: (161764, 33538)
# all cell types: ['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC']
# ====================

# %%
adata.obs.head()
# Out:
#                     celltype.l1 celltype.l2 celltype.l3   Batch donor  time  \
# L1_AAACCCAAGAAACTCA        Mono   CD14_Mono   CD14 Mono  Batch1    P2     7
# L1_AAACCCAAGACATACA       CD4 T     CD4_TCM   CD4 TCM_1  Batch1    P1     7
# L1_AAACCCACAACTGGTT       CD8 T   CD8_Naive   CD8 Naive  Batch1    P4     2
# L1_AAACCCACACGTACTA          NK          NK        NK_2  Batch1    P3     7
# L1_AAACCCACAGCATACT       CD8 T   CD8_Naive   CD8 Naive  Batch1    P4     7
#
#                     lane Phase  nCount_ADT  nFeature_ADT  nCount_RNA  \
# L1_AAACCCAAGAAACTCA   L1    G1        7535           217       10823
# L1_AAACCCAAGACATACA   L1    G1        6013           209        5864
# L1_AAACCCACAACTGGTT   L1     S        6620           213        5067
# L1_AAACCCACACGTACTA   L1    G1        3567           202        4786
# L1_AAACCCACAGCATACT   L1    G1        6402           215        6505
#
#                      nFeature_RNA leiden
# L1_AAACCCAAGAAACTCA          2915      4
# L1_AAACCCAAGACATACA          1617      2
# L1_AAACCCACAACTGGTT          1381      5
# L1_AAACCCACACGTACTA          1890      3
# L1_AAACCCACAGCATACT          1621      5

# %% [markdown]
# ## Read features

# %%
import os
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level2\feature_selection_k3")
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level1/feature_selection_k3')
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/feature_selection_k3')

features_dict = {}
# Read features for each celltype
for celltype in types:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        features_dict[celltype] = feature_df
    except:
        print('skipping:', celltype)
        continue

# %%
features_dict.keys()
# Out:
# dict_keys(['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC'])

# %%
count_df = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df = features_dict[celltype]
    feature_count = feature_df.shape[0]
    positive_count = feature_df[feature_df['Tendency'] == 1].shape[0]
    count_df.loc[celltype] = [feature_count, positive_count]
count_df
# Out:
#                    Feature_count  Positive_feature_count
# ASDC                          47                      25
# B_intermediate                96                      49
# B_memory                     170                      90
# B_naive                        9                       6
# CD14_Mono                     29                      16
# CD16_Mono                     37                      17
# CD4_CTL                      122                      45
# CD4_Naive                    730                     393
# CD4_Proliferating             70                      35
# CD4_TCM                      247                     133
# CD4_TEM                      214                     112
# CD8_Naive                    271                     169
# CD8_Proliferating             94                      37
# CD8_TCM                      313                     120
# CD8_TEM                      108                      41
# Doublet                       28                      13
# Eryth                          6                       2
# HSPC                          20                      12
# ILC                           76                      30
# MAIT                          88                      44
# NK                            30                      15
# NK_CD56bright                100                      59
# NK_Proliferating              59                      28
# Plasmablast                   15                       7
# Platelet                       4                       3
# Treg                         168                      78
# cDC1                          37                      17
# cDC2                          12                       9
# dnT                           45                      15
# gdT                           22                      10
# pDC                           18                       8

# %%
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level2\DEG_L2\L2_DEG_table")
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/DEG_L2/L2_DEG_table')
deg_dict = {}
for celltype in types:
    DEG_table = pd.read_csv(celltype + '_DEG1000.csv', index_col=0)
    n_features = count_df.loc[celltype, 'Feature_count']
    DEGn = DEG_table['names'][:n_features].tolist()

    deg_dict[celltype] = DEGn

# %%
isinstance(deg_dict['ASDC'], list)
# Out:
# True

# %% [markdown]
# ## LR

# %%
import os
import sys
import importlib
# sys.path.append('/Users/evanli/Documents/EvanPys/Progress')
# sys.path.append('/home/jovyan/work/GitHub/EvanPys/Progress')
# sys.path.append(r'C:\Users\evanlee\Documents\GitHub\EvanPys\Progress')
sys.path.append(str(source_code_dir))
from evan_library import evan_models as emd
importlib.reload(emd)
# Out:
# <module 'evan_library.evan_models' from 'c:\\Users\\evanlee\\Documents\\Bmi_NAS_evan\\evan_home\\Source_code\\evan_library\\evan_models.py'>

# %%
# initialize
evan_lr = emd.EvanModels(adata, deg_dict, level='l2')

# %%
all_metrics_df, cv_results_dict, likelihood_dict = evan_lr.run_LR_kfold_for_types()
# Out:
# ====================
# K-fold CV for: ASDC
# is a list
# Cross-validation...
# likelihood > 0.5: 73
# [0.9999149994379939, 0.9651515151515152, 0.8525641025641025, 0.9033126293995858, 0.9999568850168, 0.9563201689378161, 0.906034710103637]
# ====================
# K-fold CV for: B_intermediate
# is a list
# Cross-validation...
# likelihood > 0.5: 2070
# [0.9928290477573432, 0.8066174907815151, 0.6889460154241646, 0.7427921690127367, 0.995710373633832, 0.8245279543319054, 0.7417276308778651]
# ====================
# K-fold CV for: B_memory
# is a list
# Cross-validation...
# likelihood > 0.5: 3275
# [0.9959354313625142, 0.9035345898467473, 0.895737823646569, 0.8995437242300968, 0.9986635720665014, 0.9603992953598042, 0.8975177212775962]
# ====================
# K-fold CV for: B_naive
# is a list
# Cross-validation...
# likelihood > 0.5: 7745
# [0.9941581466399372, 0.9390835074176291, 0.9384493336570451, 0.9387537796220192, 0.998935289738168, 0.9731981865947666, 0.9356935587530619]
# ====================
# K-fold CV for: CD14_Mono
# is a list
# Cross-validation...
# likelihood > 0.5: 43138
# [0.9899622182471971, 0.975767596315001, 0.9864722682508665, 0.9810867783838619, 0.9987236712827535, 0.9942361235198728, 0.974285802046029]
# ====================
# K-fold CV for: CD16_Mono
# is a list
# Cross-validation...
# likelihood > 0.5: 6446
# [0.9937099676666115, 0.9094284354893899, 0.9319610763811511, 0.9205155734958504, 0.9984621153159041, 0.947125028392556, 0.9173384910900892]
# ====================
# K-fold CV for: CD4_CTL
# is a list
# Cross-validation...
# likelihood > 0.5: 1248
# [0.9923344961560048, 0.7036022718943168, 0.49674051372620315, 0.5818230176187051, 0.9912116821990768, 0.6602554639778463, 0.5872728486817497]
# ====================
# K-fold CV for: CD4_Naive
# is a list
# Cross-validation...
# likelihood > 0.5: 17316
# [0.9754348420585031, 0.8901082146844068, 0.8815693086246608, 0.8857877797306992, 0.9932550802667672, 0.9492558497368833, 0.8720574258207974]
# ====================
# K-fold CV for: CD4_Proliferating
# is a list
# Cross-validation...
# likelihood > 0.5: 99
# [0.999644544189976, 0.7999134199134199, 0.6418300653594772, 0.700832918171628, 0.9990115847872753, 0.7421794204114927, 0.7105369625995129]
# ====================
# K-fold CV for: CD4_TCM
# is a list
# Cross-validation...
# likelihood > 0.5: 13921
# [0.9604747556845498, 0.8047346285687318, 0.7533361309274024, 0.7781712193612391, 0.9835529244787315, 0.8540806354943363, 0.757008162111689]
# ====================
# K-fold CV for: CD4_TEM
# is a list
# Cross-validation...
# likelihood > 0.5: 2123
# [0.9778303247914373, 0.6619419304765021, 0.33274627056244815, 0.4425538247366882, 0.9704880258128312, 0.537927887327626, 0.4595178059346803]
# ====================
# K-fold CV for: CD8_Naive
# is a list
# Cross-validation...
# likelihood > 0.5: 10489
# [0.9925972308925799, 0.9565440335552371, 0.9311580765256288, 0.9436505952691098, 0.9972478360931969, 0.9813640777883942, 0.9398041389998829]
# ====================
# K-fold CV for: CD8_Proliferating
# is a list
# Cross-validation...
# likelihood > 0.5: 68
# [0.9995286335184665, 0.6236324786324786, 0.46571428571428575, 0.5245281385281386, 0.9979476405954786, 0.5588764759425658, 0.5342238074179831]
# ====================
# K-fold CV for: CD8_TCM
# is a list
# Cross-validation...
# likelihood > 0.5: 1903
# [0.987922201474998, 0.7450297831177491, 0.49088843188626274, 0.59155629433353, 0.9798932279721175, 0.6609007766240288, 0.5989985736667488]
# ====================
# K-fold CV for: CD8_TEM
# is a list
# Cross-validation...
# likelihood > 0.5: 11257
# [0.983053997755612, 0.8989982231070044, 0.8632476176087369, 0.8807325106986321, 0.9943824268517941, 0.9465391089688096, 0.8718396278387439]
# ====================
# K-fold CV for: Doublet
# is a list
# Cross-validation...
# likelihood > 0.5: 61
# [0.9965072513709528, 0.8118181818181819, 0.08054123711340207, 0.14615004610467816, 0.901742792666157, 0.3542986869959515, 0.2539219512762986]
# ====================
# K-fold CV for: Eryth
# is a list
# Cross-validation...
# likelihood > 0.5: 88
# [0.9998763628460411, 0.8890476190476191, 0.8780219780219779, 0.8772752512632573, 0.9902308716062629, 0.9371349885008667, 0.8803371105780599]
# ====================
# K-fold CV for: HSPC
# is a list
# Cross-validation...
# likelihood > 0.5: 322
# [0.9999072723584437, 0.9883861236802414, 0.9657474600870828, 0.9768110530246453, 0.9999481997444957, 0.9921500779194676, 0.9768929632126188]
# ====================
# K-fold CV for: ILC
# is a list
# Cross-validation...
# likelihood > 0.5: 118
# [0.9996831813790292, 0.8554841649578492, 0.7458874458874458, 0.7833604829778874, 0.9977529720579099, 0.8398337167454807, 0.7915963490253386]
# ====================
# K-fold CV for: MAIT
# is a list
# Cross-validation...
# likelihood > 0.5: 2738
# [0.9962522472965321, 0.9006152974984012, 0.8792079407467124, 0.8897516042659588, 0.9990556546043254, 0.9530594776853343, 0.8879282877564355]
# ====================
# K-fold CV for: NK
# is a list
# Cross-validation...
# likelihood > 0.5: 17434
# [0.9841976371753887, 0.9188777796880393, 0.9336148366697771, 0.926161176837722, 0.9973110409149817, 0.9748347917443123, 0.917367023056811]
# ====================
# K-fold CV for: NK_CD56bright
# is a list
# Cross-validation...
# likelihood > 0.5: 923
# [0.9984390818642399, 0.8845756565075714, 0.8461015452538632, 0.8635039092245524, 0.9994956578494772, 0.9437889944750362, 0.8636454021205182]
# ====================
# K-fold CV for: NK_Proliferating
# is a list
# Cross-validation...
# likelihood > 0.5: 510
# [0.9989568105245248, 0.881875900038985, 0.7989550679205851, 0.837947395457249, 0.9994363523649319, 0.9252596850352452, 0.8386654494919984]
# ====================
# K-fold CV for: Plasmablast
# is a list
# Cross-validation...
# likelihood > 0.5: 355
# [0.9998918173036921, 0.9895946763460376, 0.962478082992402, 0.9757721139430284, 0.9999715013904446, 0.9918564745596303, 0.9758506165329444]
# ====================
# K-fold CV for: Platelet
# is a list
# Cross-validation...
# likelihood > 0.5: 2197
# [0.9985627163312459, 0.9686927902471101, 0.9285656854424443, 0.9481999841896617, 0.9779829136695174, 0.9559912374815649, 0.9476920815518206]
# ====================
# K-fold CV for: Treg
# is a list
# Cross-validation...
# likelihood > 0.5: 2017
# [0.9935786046273037, 0.8610867501514707, 0.6984206151288446, 0.7712072137240065, 0.9908843076951103, 0.8396917537557137, 0.7723516193398681]
# ====================
# K-fold CV for: cDC1
# is a list
# Cross-validation...
# likelihood > 0.5: 150
# [0.999961363109497, 0.9836666666666666, 0.975, 0.9788893818396923, 0.9989838734627581, 0.9910491032370953, 0.9790923390749076]
# ====================
# K-fold CV for: cDC2
# is a list
# Cross-validation...
# likelihood > 0.5: 2372
# [0.9974731655726703, 0.9421239817681377, 0.8915523690773067, 0.9160395491106513, 0.9992080181874018, 0.9674707549607231, 0.915168752541852]
# ====================
# K-fold CV for: dnT
# is a list
# Cross-validation...
# likelihood > 0.5: 179
# [0.9986245368488025, 0.8857347670250896, 0.4350877192982455, 0.5820025376921928, 0.9684775405408548, 0.5986315693295412, 0.6193168702751937]
# ====================
# K-fold CV for: gdT
# is a list
# Cross-validation...
# likelihood > 0.5: 3167
# [0.9929063206426985, 0.8937738921045673, 0.778007002044221, 0.8318737786496488, 0.9877726670039022, 0.8749661339886636, 0.8303523531181728]
# ====================
# K-fold CV for: pDC
# is a list
# Cross-validation...
# likelihood > 0.5: 869
# [0.9998377268511891, 0.9799562592948998, 0.9898550724637681, 0.9848526608414003, 0.999990429063222, 0.9980346151707657, 0.9847978793171253]

# %%
all_metrics_df
# Out:
#                    Accuracy  Precision    Recall  F1-score   ROC-AUC  \
# ASDC               0.999915   0.965152  0.852564  0.903313  0.999957
# B_intermediate     0.992829   0.806617  0.688946  0.742792  0.995710
# B_memory           0.995935   0.903535  0.895738  0.899544  0.998664
# B_naive            0.994158   0.939084  0.938449  0.938754  0.998935
# CD14_Mono          0.989962   0.975768  0.986472  0.981087  0.998724
# CD16_Mono          0.993710   0.909428  0.931961  0.920516  0.998462
# CD4_CTL            0.992334   0.703602  0.496741  0.581823  0.991212
# CD4_Naive          0.975435   0.890108  0.881569  0.885788  0.993255
# CD4_Proliferating  0.999645   0.799913  0.641830  0.700833  0.999012
# CD4_TCM            0.960475   0.804735  0.753336  0.778171  0.983553
# CD4_TEM            0.977830   0.661942  0.332746  0.442554  0.970488
# CD8_Naive          0.992597   0.956544  0.931158  0.943651  0.997248
# CD8_Proliferating  0.999529   0.623632  0.465714  0.524528  0.997948
# CD8_TCM            0.987922   0.745030  0.490888  0.591556  0.979893
# CD8_TEM            0.983054   0.898998  0.863248  0.880733  0.994382
# Doublet            0.996507   0.811818  0.080541  0.146150  0.901743
# Eryth              0.999876   0.889048  0.878022  0.877275  0.990231
# HSPC               0.999907   0.988386  0.965747  0.976811  0.999948
# ILC                0.999683   0.855484  0.745887  0.783360  0.997753
# MAIT               0.996252   0.900615  0.879208  0.889752  0.999056
# NK                 0.984198   0.918878  0.933615  0.926161  0.997311
# NK_CD56bright      0.998439   0.884576  0.846102  0.863504  0.999496
# NK_Proliferating   0.998957   0.881876  0.798955  0.837947  0.999436
# Plasmablast        0.999892   0.989595  0.962478  0.975772  0.999972
# Platelet           0.998563   0.968693  0.928566  0.948200  0.977983
# Treg               0.993579   0.861087  0.698421  0.771207  0.990884
# cDC1               0.999961   0.983667  0.975000  0.978889  0.998984
# cDC2               0.997473   0.942124  0.891552  0.916040  0.999208
# dnT                0.998625   0.885735  0.435088  0.582003  0.968478
# gdT                0.992906   0.893774  0.778007  0.831874  0.987773
# pDC                0.999838   0.979956  0.989855  0.984853  0.999990
#
#                      PR-AUC       MCC
# ASDC               0.956320  0.906035
# B_intermediate     0.824528  0.741728
# B_memory           0.960399  0.897518
# B_naive            0.973198  0.935694
# CD14_Mono          0.994236  0.974286
# CD16_Mono          0.947125  0.917338
# CD4_CTL            0.660255  0.587273
# CD4_Naive          0.949256  0.872057
# CD4_Proliferating  0.742179  0.710537
# CD4_TCM            0.854081  0.757008
# CD4_TEM            0.537928  0.459518
# CD8_Naive          0.981364  0.939804
# CD8_Proliferating  0.558876  0.534224
# CD8_TCM            0.660901  0.598999
# CD8_TEM            0.946539  0.871840
# Doublet            0.354299  0.253922
# Eryth              0.937135  0.880337
# HSPC               0.992150  0.976893
# ILC                0.839834  0.791596
# MAIT               0.953059  0.887928
# NK                 0.974835  0.917367
# NK_CD56bright      0.943789  0.863645
# NK_Proliferating   0.925260  0.838665
# Plasmablast        0.991856  0.975851
# Platelet           0.955991  0.947692
# Treg               0.839692  0.772352
# cDC1               0.991049  0.979092
# cDC2               0.967471  0.915169
# dnT                0.598632  0.619317
# gdT                0.874966  0.830352
# pDC                0.998035  0.984798

# %%
# !cd
# Out:
# C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level2\DEG_L2\L2_DEG_table

# %%
all_metrics_df.to_csv('LR_DEG_metrics_l2.csv')
