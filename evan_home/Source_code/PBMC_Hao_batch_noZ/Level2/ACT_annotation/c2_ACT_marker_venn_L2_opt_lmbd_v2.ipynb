# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
import os
from matplotlib_venn import venn2

# %%
marker_df = pd.read_csv('Human_blood_marker_processed.csv')
print(marker_df.shape)
marker_df.head()
# Out:
# (147, 6)
#   Species Tissue super_type  \
# 0   Human  Blood          B
# 1   Human  Blood      T_CD4
# 2   Human  Blood      T_CD4
# 3   Human  Blood        NaN
# 4   Human  Blood          T
#
#                                             CellType  \
# 0                                   Activated B cell
# 1          Activated CD4-positive, alpha-beta T cell
# 2  Activated CD4-positive, CD25-positive, CCR4-po...
# 3                  Adult endothelial progenitor cell
# 4                                  Alpha-beta T cell
#
#                                               Marker  \
# 0                              CD5, MIR155HG, TAGLN2
# 1  CD4, CCR6, CD14, CD19, CD38, CD3D, CD3G, CD69,...
# 2                       CD3D, CD3E, CD3G, CD4, FOXP3
# 3              KDR, PROM1, CD34, PTPRC, PECAM1, CD14
# 4                             CD3D, CD3E, CD3G, IL7R
#
#                                             Resource
# 0                        35025971, 28910360, 2474446
# 1  35381424, 32783921, 35831277, 34529726, 103413...
# 2                                           30977974
# 3  27561827, 29391882, 24641802, 29147957, 267700...
# 4                                 34284174, 28777444

# %%
marker_df['super_type'].unique()
# Out:
# array(['B', 'T_CD4', nan, 'T', 'Monocyte', 'DC', 'NK', 'T_CD4_cytotoxic',
#        'T_CD4_memory', 'T_CD8_cytotoxic', 'T_CD8_memory', 'T_CD8',
#        'T_CD4_Tcm', 'T_CD8_Tcm', 'T_cm', 'B_memory', 'T_CD4_Tem', 'T_em',
#        'T_CD8_Tem', 'Erythrocyte', 'T_helper', 'T_reg', 'T_memory',
#        'B_naive', 'Platelet'], dtype=object)

# %%
marker_df['CellType'].unique()
# Out:
# array(['Activated B cell', 'Activated CD4-positive, alpha-beta T cell',
#        'Activated CD4-positive, CD25-positive, CCR4-positive, alpha-beta regulatory T cell, human',
#        'Adult endothelial progenitor cell', 'Alpha-beta T cell',
#        'Alternatively activated macrophage', 'Atypical B cell', 'B cell',
#        'Basophil', 'Cardiac muscle cell',
#        'CD14-low, CD16-positive monocyte', 'CD14-positive monocyte',
#        'CD14-positive, CD16-negative classical monocyte',
#        'CD14-positive, CD16-positive monocyte',
#        'CD141-positive, CLEC9A-positive dendritic cell',
#        'CD16-negative natural killer cell',
#        'CD16-negative, CD56-bright natural killer cell, human',
#        'CD16-positive myeloid dendritic cell',
#        'CD16-positive natural killer cell',
#        'CD16-positive, CD56-dim natural killer cell, human',
#        'CD1c-positive myeloid dendritic cell', 'CD38-positive B cell',
#        'CD4-intermediate, CD8-positive double-positive thymocyte',
#        'CD4-positive helper T cell',
#        'CD4-positive, alpha-beta cytotoxic T cell',
#        'CD4-positive, alpha-beta memory T cell',
#        'CD4-positive, alpha-beta T cell',
#        'CD4-positive, CD25-positive, alpha-beta regulatory T cell',
#        'CD4-positive, CD25-positive, CD127-high, alpha-beta regulatory T cell',
#        'CD56-positive natural killer cell',
#        'CD8-positive, alpha-beta cytotoxic T cell',
#        'CD8-positive, alpha-beta memory T cell',
#        'CD8-positive, alpha-beta regulatory T cell',
#        'CD8-positive, alpha-beta T cell',
#        'Central memory CD4-positive, alpha-beta T cell',
#        'Central memory CD8-positive, alpha-beta T cell',
#        'Central memory T cell', 'Circulating angiogenic cell',
#        'Circulating hematopoietic progenitor cell',
#        'Circulating natural killer cell', 'Circulating progenitor cell',
#        'Class switched memory B cell', 'Classical monocyte',
#        'Common dendritic progenitor', 'Common lymphoid progenitor',
#        'Common myeloid progenitor', 'Conventional dendritic cell',
#        'Cytokine-induced killer cell', 'Decidual cell', 'Dendritic cell',
#        'Dendritic cell, human', 'Double negative memory B cell',
#        'Double-positive, alpha-beta thymocyte', 'Early endothelial cell',
#        'Early lymphoid progenitor',
#        'Effector CD4-positive, alpha-beta T cell',
#        'Effector CD8-positive, alpha-beta T cell',
#        'Effector memory CD4-positive, alpha-beta T cell',
#        'Effector memory CD45RA-positive, alpha-beta T cell, terminally differentiated',
#        'Effector memory CD8-positive, alpha-beta T cell',
#        'Effector memory CD8-positive, alpha-beta T cell, terminally differentiated',
#        'Effector memory T cell', 'Effector T cell', 'Endothelial cell',
#        'Endothelial cell of lymphatic vessel', 'Eosinophil',
#        'Epithelial cell', 'Erythroblast', 'Erythrocyte', 'Fat cell',
#        'Fibroblast', 'Gamma-delta T cell', 'Granulocyte',
#        'Granulocyte monocyte progenitor cell', 'Helper T cell',
#        'Hematopoietic stem cell', 'Immature B cell',
#        'Immature conventional dendritic cell',
#        'Immature transitional B cell', 'Induced T-regulatory cell',
#        'Inflammatory macrophage', 'Intermediate monocyte',
#        'Langerhans cell', 'Late erythrocyte', 'Macrophage',
#        'Mature endothelial cell', 'Mature NK T cell', 'Megakaryocyte',
#        'Megakaryocyte progenitor cell',
#        'Megakaryocyte-erythroid progenitor cell', 'Memory B cell',
#        'Memory T cell', 'Mesenchymal cell', 'Mesenchymal stem cell',
#        'Monocyte', 'Monocyte-derived dendritic cell',
#        'Mononuclear phagocyte', 'Mucosal invariant T cell', 'Myelocyte',
#        'Myeloid dendritic cell', 'Myeloid suppressor cell',
#        'Naive B cell', 'Naive regulatory T cell', 'Naive T cell',
#        'Naive thymus-derived CD4-positive, alpha-beta T cell',
#        'Naive thymus-derived CD8-positive, alpha-beta T cell',
#        'Natural killer cell', 'Natural T-regulatory cell', 'Neuron',
#        'Neutrophil', 'Neutrophil progenitor cell',
#        'Non-classical monocyte', 'Plasma cell', 'Plasmablast',
#        'Plasmacytoid dendritic cell',
#        'Plasmacytoid dendritic cell, human', 'Platelet',
#        'Pre-natural killer cell', 'Preadipocyte', 'Pro-B cell',
#        'Progenitor cell', 'Proliferating CD4-positive, alpha-beta T cell',
#        'Regulatory B cell', 'Regulatory T cell', 'Stem cell',
#        'Stromal cell', 'Suppressor macrophage', 'T cell',
#        'T follicular helper cell', 'T-helper 1 cell', 'T-helper 17 cell',
#        'T-helper 2 cell', 'Thyroid follicular cell',
#        'Transitional stage B cell', 'Type 1 conventional dendritic cell',
#        'Type 2 conventional dendritic cell', 'Unswitched memory B cell',
#        'Erythroid progenitor cell', 'Mature B cell', 'Precursor B cell'],
#       dtype=object)

# %% [markdown]
# ## Read PreLect features

# %%
types = ['ASDC', 'B_intermediate', 'B_memory', 'B_naive', 'CD14_Mono', 'CD16_Mono', 'CD4_CTL', 'CD4_Naive', 'CD4_Proliferating', 'CD4_TCM', 'CD4_TEM', 'CD8_Naive', 'CD8_Proliferating', 'CD8_TCM', 'CD8_TEM', 'Doublet', 'Eryth', 'HSPC', 'ILC', 'MAIT', 'NK', 'NK_CD56bright', 'NK_Proliferating', 'Plasmablast', 'Platelet', 'Treg', 'cDC1', 'cDC2', 'dnT', 'gdT', 'pDC']

# %%
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level2/feature_selection_k3')
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level2\feature_selection_k3")
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/feature_selection_k3')

features_dict = {}
# Read features for each celltype
for celltype in types:
    try:
        feature_df_k3 = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        features_dict[celltype] = feature_df_k3
    except:
        print('skipping:', celltype)
        continue

count_df_k3 = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df_k3 = features_dict[celltype]
    feature_count = feature_df_k3.shape[0]
    positive_count = feature_df_k3[feature_df_k3['Tendency'] == 1].shape[0]
    count_df_k3.loc[celltype] = [feature_count, positive_count]
count_df_k3
# Out:
#                    Feature_count  Positive_feature_count
# ASDC                          47                      25
# B_intermediate                96                      49
# B_memory                     170                      90
# B_naive                        9                       6
# CD14_Mono                     29                      16
# CD16_Mono                     37                      17
# CD4_CTL                      122                      45
# CD4_Naive                    730                     393
# CD4_Proliferating             70                      35
# CD4_TCM                      247                     133
# CD4_TEM                      214                     112
# CD8_Naive                    271                     169
# CD8_Proliferating             94                      37
# CD8_TCM                      313                     120
# CD8_TEM                      108                      41
# Doublet                       28                      13
# Eryth                          6                       2
# HSPC                          20                      12
# ILC                           76                      30
# MAIT                          88                      44
# NK                            30                      15
# NK_CD56bright                100                      59
# NK_Proliferating              59                      28
# Plasmablast                   15                       7
# Platelet                       4                       3
# Treg                         168                      78
# cDC1                          37                      17
# cDC2                          12                       9
# dnT                           45                      15
# gdT                           22                      10
# pDC                           18                       8

# %%
# Do two comparisons:
#   1. All_PreLect vs. Marker in database
#   2. Positive_PreLect vs. Marker in database
def compare_PreLect_w_marker(celltype, PreLect_dict, marker_genes, name=''):
    if name == '':
        name = celltype
    # Extracting the features and marker genes
    feature_df = PreLect_dict[celltype]
    features = feature_df['Gene'].tolist()
    positve_features = feature_df[feature_df['Tendency'] == 1]['Gene'].tolist()
    # marker_genes = marker_df['official gene symbol'].tolist()

    ### All features
    # Finding common elements
    common_all = list(set(features) & set(marker_genes))
    print(celltype, 'All features common with markers:', len(common_all))
    # Preparing sets for Venn diagram
    features_set = set(features)
    marker_genes_set = set(marker_genes)
    # Plotting Venn diagram
    plt.figure(figsize=(8, 5))
    v = venn2([features_set, marker_genes_set], set_labels=('PreLect all', f'{name} Marker'))
    for idx in ('10', '01', '11'):  # Each region in a 2-set Venn diagram
        if v.get_label_by_id(idx) and int(v.get_label_by_id(idx).get_text()) == 0:
            v.get_label_by_id(idx).set_text('')
    plt.title(name, fontsize=16)
    for text in v.set_labels:
        text.set_fontsize(14)
    for text in v.subset_labels:
        text.set_fontsize(16)
    plt.savefig(f"{name}_PreLect_all_vs_marker.png")
    plt.close()
    # plt.show()

    ### Positive features
    # Finding common elements
    common_positive = list(set(positve_features) & set(marker_genes))
    print(celltype, 'Positive features common with markers:', len(common_positive))
    # Preparing sets for Venn diagram
    positive_features_set = set(positve_features)
    marker_genes_set = set(marker_genes)
    # Plotting Venn diagram
    plt.figure(figsize=(8, 5))
    v = venn2([positive_features_set, marker_genes_set], set_labels=('PreLect positive', f'{name} Marker'), set_colors=('blue', 'green'))
    for idx in ('10', '01', '11'):  # Each region in a 2-set Venn diagram
        if v.get_label_by_id(idx) and int(v.get_label_by_id(idx).get_text()) == 0:
            v.get_label_by_id(idx).set_text('')
    plt.title(name, fontsize=16)
    for text in v.set_labels:
        print(text)
        text.set_fontsize(14)
    for text in v.subset_labels:
        text.set_fontsize(16)
    plt.savefig(f"{name}_PreLect_positive_vs_marker.png")
    plt.close()
    # plt.show()

    return common_all, common_positive

# %%
def get_celltype_marker(name, marker_df):
    string = marker_df[marker_df['CellType'] == name]['Marker'].tolist()[0]
    marker_list = string.split(', ')
    return marker_list

# %% [markdown]
# ## Function for running comparison

# %%
def run_compare(clus_name, act_name, features_dict, marker_df, marker_list=None):
    if marker_list:
        common, common_p = compare_PreLect_w_marker(clus_name, features_dict, marker_list, name=clus_name)
    else:
        common, common_p = compare_PreLect_w_marker(clus_name, features_dict, get_celltype_marker(act_name, marker_df), name=clus_name)
    print(f'{clus_name}_common:', common)
    print(f'{clus_name}_common_p:', common_p)

    return common, common_p

# %%
clus_ACT_name_dict = {
    # 20 types
    'B_memory': 'Memory B cell',
    'B_naive': 'Naive B cell',
    'CD14_Mono': 'Classical monocyte',
    'CD16_Mono': 'Non-classical monocyte',
    'CD4_Proliferating': 'Proliferating CD4-positive, alpha-beta T cell',
    'CD4_TCM': 'Central memory CD4-positive, alpha-beta T cell',
    'CD4_TEM': 'Effector memory CD4-positive, alpha-beta T cell',
    'CD8_Naive': 'Naive thymus-derived CD8-positive, alpha-beta T cell',
    'CD8_TEM': 'Effector memory CD8-positive, alpha-beta T cell',
    'cDC1': 'Type 1 conventional dendritic cell',
    'cDC2': 'Type 2 conventional dendritic cell',
    'gdT': 'Gamma-delta T cell',
    'HSPC': 'Hematopoietic stem cell',
    'MAIT': 'Mucosal invariant T cell',
    'pDC': 'Plasmacytoid dendritic cell',
    'Treg': 'Regulatory T cell',
    'CD4_CTL': 'CD4-positive, alpha-beta cytotoxic T cell',
    'CD4_Naive': 'Naive thymus-derived CD4-positive, alpha-beta T cell',
    'CD8_TCM': 'Central memory CD8-positive, alpha-beta T cell',
    'Plasmablast': 'Plasmablast',
    # added
    'NK': 'Natural killer cell', 
    'NK_CD56bright': 'CD16-negative, CD56-bright natural killer cell, human'
}

# %% [markdown]
# ## Run

# %%
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level2/ACT_annotation/venn_plot')
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/ACT_annotation/venn_plot')
overlapped_dict = {}
for clus, name in clus_ACT_name_dict.items():
    common, common_positive = run_compare(clus, name, features_dict, marker_df)
    overlapped_dict[clus] = common
# Out:
# B_memory All features common with markers: 5
# B_memory Positive features common with markers: 4
# Text(-0.09736495539698528, -0.5652145942620618, 'PreLect positive')
# Text(0.5154615285722748, -0.26703827784280404, 'B_memory Marker')
# B_memory_common: ['IGHG3', 'IGHM', 'MS4A1', 'IGHG1', 'AIM2']
# B_memory_common_p: ['IGHG1', 'IGHG3', 'MS4A1', 'AIM2']
# B_naive All features common with markers: 4
# B_naive Positive features common with markers: 4
# Text(-0.3084798873361627, -0.359583030112296, 'PreLect positive')
# Text(0.1088752543539398, -0.5762057736504398, 'B_naive Marker')
# B_naive_common: ['IGHM', 'TCL1A', 'MS4A1', 'IGHD']
# B_naive_common_p: ['IGHM', 'TCL1A', 'MS4A1', 'IGHD']
# CD14_Mono All features common with markers: 9
# CD14_Mono Positive features common with markers: 9
# Text(-0.4541203771241833, -0.23935136658660686, 'PreLect positive')
# Text(0.06157564435582141, -0.585665459563262, 'CD14_Mono Marker')
# CD14_Mono_common: ['S100A8', 'MS4A6A', 'NEAT1', 'CD14', 'VCAN', 'FCN1', 'LYZ', 'S100A9', 'CEBPD']
# CD14_Mono_common_p: ['MS4A6A', 'S100A8', 'CD14', 'CEBPD', 'VCAN', 'FCN1', 'LYZ', 'S100A9', 'NEAT1']
# CD16_Mono All features common with markers: 7
# CD16_Mono Positive features common with markers: 7
# Text(-0.3966592409788664, -0.3385269350403358, 'PreLect positive')
# Text(0.13221974699295547, -0.5565617426148295, 'CD16_Mono Marker')
# CD16_Mono_common: ['FCER1G', 'LST1', 'CDKN1C', 'FCGR3A', 'AIF1', 'TCF7L2', 'CST3']
# CD16_Mono_common_p: ['FCER1G', 'LST1', 'CDKN1C', 'FCGR3A', 'AIF1', 'TCF7L2', 'CST3']
# CD4_Proliferating All features common with markers: 3
# CD4_Proliferating Positive features common with markers: 3
# Text(-0.031508825275692556, -0.60065795256126, 'PreLect positive')
# Text(0.36760296154974637, -0.20164616573582106, 'CD4_Proliferating Marker')
# CD4_Proliferating_common: ['MKI67', 'STMN1', 'TUBA1B']
# CD4_Proliferating_common_p: ['MKI67', 'STMN1', 'TUBA1B']
# CD4_TCM All features common with markers: 18
# CD4_TCM Positive features common with markers: 17
# Text(-0.07674077278326397, -0.5853894148357324, 'PreLect positive')
# Text(0.392558568468235, -0.2807885690263421, 'CD4_TCM Marker')
# CD4_TCM_common: ['LTB', 'IL32', 'TMSB10', 'IL7R', 'ANXA1', 'MAL', 'CD69', 'LDHB', 'CD3E', 'CD4', 'ITGB1', 'AQP3', 'ZFP36L2', 'CD3D', 'TRAC', 'KLF2', 'SELL', 'CD3G']
# CD4_TCM_common_p: ['LTB', 'IL32', 'TMSB10', 'IL7R', 'ANXA1', 'MAL', 'CD69', 'LDHB', 'CD3E', 'CD4', 'ITGB1', 'AQP3', 'ZFP36L2', 'CD3D', 'TRAC', 'KLF2', 'CD3G']
# CD4_TEM All features common with markers: 10
# CD4_TEM Positive features common with markers: 7
# Text(-0.09122612677247455, -0.5700356642110503, 'PreLect positive')
# Text(0.4865393427865311, -0.268442056656697, 'CD4_TEM Marker')
# CD4_TEM_common: ['KLRB1', 'IL7R', 'GZMK', 'ITGB1', 'CD4', 'GNLY', 'CCL5', 'GZMA', 'CD3G', 'PTPRC']
# CD4_TEM_common_p: ['KLRB1', 'IL7R', 'GZMK', 'CD4', 'CCL5', 'GZMA', 'CD3G']
# CD8_Naive All features common with markers: 9
# CD8_Naive Positive features common with markers: 8
# Text(-0.03065703935503992, -0.5943439686473703, 'PreLect positive')
# Text(0.47100360463652247, -0.17777434267077102, 'CD8_Naive Marker')
# CD8_Naive_common: ['CD27', 'IL7R', 'CD3E', 'CD8A', 'CD8B', 'CCR7', 'CD3D', 'SELL', 'LEF1']
# CD8_Naive_common_p: ['CD27', 'CD3E', 'CD8A', 'CD8B', 'CCR7', 'CD3D', 'SELL', 'LEF1']
# CD8_TEM All features common with markers: 15
# CD8_TEM Positive features common with markers: 12
# Text(-0.2225833191991106, -0.49862243871003065, 'PreLect positive')
# Text(0.26840929668128044, -0.4579517384402561, 'CD8_TEM Marker')
# CD8_TEM_common: ['CST7', 'GZMK', 'PRF1', 'CD8A', 'KLRD1', 'GNLY', 'CCL5', 'GZMA', 'GZMH', 'CD8B', 'CD3D', 'TRAC', 'NKG7', 'CD3G', 'TRGC2']
# CD8_TEM_common_p: ['CST7', 'GZMK', 'CD8A', 'KLRD1', 'CCL5', 'GZMH', 'CD8B', 'CD3D', 'TRAC', 'NKG7', 'CD3G', 'TRGC2']
# cDC1 All features common with markers: 3
# cDC1 Positive features common with markers: 3
# Text(-0.2625067344805467, -0.48154074489497317, 'PreLect positive')
# Text(0.31875817758352093, -0.44087004351078535, 'cDC1 Marker')
# cDC1_common: ['CLEC9A', 'BATF3', 'HLA-DPA1']
# cDC1_common_p: ['CLEC9A', 'BATF3', 'HLA-DPA1']
# cDC2 All features common with markers: 2
# cDC2 Positive features common with markers: 2
# Text(-0.23569876816838006, -0.49492304165510626, 'PreLect positive')
# Text(0.3030412733593457, -0.4415072957374584, 'cDC2 Marker')
# cDC2_common: ['FCER1A', 'CLEC10A']
# cDC2_common_p: ['FCER1A', 'CLEC10A']
# gdT All features common with markers: 5
# gdT Positive features common with markers: 5
# Text(-0.1675699429277364, -0.523286489675295, 'PreLect positive')
# Text(0.1861888254752627, -0.4988172889854794, 'gdT Marker')
# gdT_common: ['CD3E', 'TRGC1', 'CD3D', 'TRDC', 'TRGC2']
# gdT_common_p: ['CD3E', 'TRGC1', 'CD3D', 'TRDC', 'TRGC2']
# HSPC All features common with markers: 2
# HSPC Positive features common with markers: 2
# Text(-0.5014762712543358, -0.30729103125140494, 'PreLect positive')
# Text(0.13994686639655884, -0.5470165970871642, 'HSPC Marker')
# HSPC_common: ['SOX4', 'SPINK2']
# HSPC_common_p: ['SOX4', 'SPINK2']
# MAIT All features common with markers: 6
# MAIT Positive features common with markers: 6
# Text(-0.088610670984228, -0.5800547279966065, 'PreLect positive')
# Text(0.3898869523306033, -0.29740046147635174, 'MAIT Marker')
# MAIT_common: ['KLRB1', 'SLC4A10', 'CD8A', 'CD3D', 'CXCR4', 'MAF']
# MAIT_common_p: ['KLRB1', 'SLC4A10', 'CD8A', 'CD3D', 'CXCR4', 'MAF']
# pDC All features common with markers: 4
# pDC Positive features common with markers: 4
# Text(-0.43023681916126955, -0.2823855247475264, 'PreLect positive')
# Text(0.08825370649461939, -0.5763408079306674, 'pDC Marker')
# pDC_common: ['GZMB', 'JCHAIN', 'IRF8', 'IRF7']
# pDC_common_p: ['GZMB', 'JCHAIN', 'IRF8', 'IRF7']
# Treg All features common with markers: 11
# Treg Positive features common with markers: 8
# Text(-0.1953196176605028, -0.522377842813038, 'PreLect positive')
# Text(0.4117548696626815, -0.3724412451178172, 'Treg Marker')
# Treg_common: ['CD27', 'IL7R', 'CD3G', 'IKZF2', 'ISG20', 'CD52', 'RTKN2', 'ITGA4', 'FOXP3', 'TIGIT', 'IL2RA']
# Treg_common_p: ['CD27', 'IKZF2', 'ISG20', 'RTKN2', 'CD3G', 'FOXP3', 'TIGIT', 'IL2RA']
# CD4_CTL All features common with markers: 3
# CD4_CTL Positive features common with markers: 3
# Text(-0.026163528716800777, -0.5996827189290913, 'PreLect positive')
# Text(0.39245293075201165, -0.18116625946027887, 'CD4_CTL Marker')
# CD4_CTL_common: ['GNLY', 'NKG7', 'GZMH']
# CD4_CTL_common_p: ['GNLY', 'NKG7', 'GZMH']
# CD4_Naive All features common with markers: 12
# CD4_Naive Positive features common with markers: 11
# Text(-0.01454097589202695, -0.5965698974312191, 'PreLect positive')
# Text(0.4762169604638826, -0.1315585011413191, 'CD4_Naive Marker')
# CD4_Naive_common: ['CD27', 'TCF7', 'ITGA6', 'CD3E', 'CD4', 'CCR7', 'CD3D', 'KLF2', 'ATM', 'SELL', 'LEF1', 'PTPRC']
# CD4_Naive_common_p: ['ITGA6', 'TCF7', 'CD3E', 'CD4', 'CCR7', 'CD3D', 'KLF2', 'ATM', 'SELL', 'LEF1', 'PTPRC']
# CD8_TCM All features common with markers: 6
# CD8_TCM Positive features common with markers: 4
# Text(-0.05306528303100968, -0.582225279797625, 'PreLect positive')
# Text(0.5306528303100968, -0.2086981392372531, 'CD8_TCM Marker')
# CD8_TCM_common: ['IL7R', 'GPR183', 'CD8A', 'CD8B', 'CD3G', 'PTPRC']
# CD8_TCM_common_p: ['CD8A', 'IL7R', 'GPR183', 'CD8B']
# Plasmablast All features common with markers: 3
# Plasmablast Positive features common with markers: 3
# Text(-0.3410385149071476, -0.3846373732573431, 'PreLect positive')
# Text(0.15915130695666885, -0.5434828844270232, 'Plasmablast Marker')
# Plasmablast_common: ['JCHAIN', 'IGHA1', 'MZB1']
# Plasmablast_common_p: ['JCHAIN', 'IGHA1', 'MZB1']
# NK All features common with markers: 11
# NK Positive features common with markers: 11
# Text(-0.3652359792840705, -0.28726081447855006, 'PreLect positive')
# Text(0.07403432012514943, -0.5893801187889702, 'NK Marker')
# NK_common: ['CST7', 'KLRB1', 'PRF1', 'CD247', 'KLRD1', 'GNLY', 'FCGR3A', 'KLRF1', 'GZMB', 'NKG7', 'SPON2']
# NK_common_p: ['CST7', 'KLRB1', 'PRF1', 'CD247', 'KLRD1', 'GNLY', 'FCGR3A', 'KLRF1', 'GZMB', 'NKG7', 'SPON2']
# NK_CD56bright All features common with markers: 2
# NK_CD56bright Positive features common with markers: 2
# Text(-0.03482825677991127, -0.5898303756227349, 'PreLect positive')
# Text(0.5137167875036912, -0.1794410300104238, 'NK_CD56bright Marker')
# NK_CD56bright_common: ['NCAM1', 'GNLY']
# NK_CD56bright_common_p: ['NCAM1', 'GNLY']

# %% [markdown]
# ## Export overlapped marker dict

# %%
overlapped_dict
# Out:
# {'B_memory': ['IGHG1', 'IGHG3', 'IGHM', 'AIM2', 'MS4A1'],
#  'B_naive': ['IGHM', 'IGHD', 'MS4A1', 'TCL1A'],
#  'CD14_Mono': ['LYZ',
#   'NEAT1',
#   'VCAN',
#   'S100A8',
#   'MS4A6A',
#   'CD14',
#   'S100A9',
#   'CEBPD',
#   'FCN1'],
#  'CD16_Mono': ['CST3', 'AIF1', 'LST1', 'CDKN1C', 'FCER1G', 'TCF7L2', 'FCGR3A'],
#  'CD4_Proliferating': ['MKI67', 'STMN1', 'TUBA1B'],
#  'CD4_TCM': ['MAL',
#   'CD69',
#   'TRAC',
#   'IL32',
#   'TMSB10',
#   'AQP3',
#   'SELL',
#   'CD3D',
#   'LDHB',
#   'LTB',
#   'CD3G',
#   'ITGB1',
#   'ZFP36L2',
#   'CD4',
#   'KLF2',
#   'CD3E',
#   'ANXA1',
#   'IL7R'],
#  'CD4_TEM': ['GZMA',
#   'KLRB1',
#   'GNLY',
#   'CD3G',
#   'ITGB1',
#   'CD4',
#   'PTPRC',
#   'GZMK',
#   'IL7R',
#   'CCL5'],
#  'CD8_Naive': ['CD8A',
#   'CCR7',
#   'SELL',
#   'CD8B',
#   'CD27',
#   'CD3E',
#   'CD3D',
#   'IL7R',
#   'LEF1'],
#  'CD8_TEM': ['NKG7',
#   'TRAC',
#   'TRGC2',
#   'CD8A',
#   'GZMA',
#   'KLRD1',
#   'GNLY',
#   'CST7',
#   'CD8B',
#   'CD3G',
#   'GZMH',
#   'CD3D',
#   'PRF1',
#   'GZMK',
#   'CCL5'],
#  'cDC1': ['BATF3', 'HLA-DPA1', 'CLEC9A'],
#  'cDC2': ['CLEC10A', 'FCER1A'],
#  'gdT': ['TRGC2', 'TRGC1', 'TRDC', 'CD3E', 'CD3D'],
#  'HSPC': ['SOX4', 'SPINK2'],
#  'MAIT': ['CXCR4', 'CD8A', 'SLC4A10', 'KLRB1', 'MAF', 'CD3D'],
#  'pDC': ['JCHAIN', 'GZMB', 'IRF7', 'IRF8'],
#  'Treg': ['RTKN2',
#   'FOXP3',
#   'CD52',
#   'IL2RA',
#   'IKZF2',
#   'ISG20',
#   'CD27',
#   'CD3G',
#   'TIGIT',
#   'ITGA4',
#   'IL7R'],
#  'CD4_CTL': ['GNLY', 'NKG7', 'GZMH'],
#  'CD4_Naive': ['CCR7',
#   'SELL',
#   'CD3D',
#   'ATM',
#   'TCF7',
#   'CD27',
#   'KLF2',
#   'CD4',
#   'CD3E',
#   'ITGA6',
#   'PTPRC',
#   'LEF1'],
#  'CD8_TCM': ['GPR183', 'CD8A', 'CD8B', 'CD3G', 'PTPRC', 'IL7R'],
#  'Plasmablast': ['JCHAIN', 'IGHA1', 'MZB1'],
#  'NK': ['CD247',
#   'NKG7',
#   'GZMB',
#   'KLRF1',
#   'KLRB1',
#   'KLRD1',
#   'GNLY',
#   'CST7',
#   'SPON2',
#   'PRF1',
#   'FCGR3A'],
#  'NK_CD56bright': ['GNLY', 'NCAM1']}

# %%
for k, v in overlapped_dict.items():
    print(k, len(v))
# Out:
# B_memory 5
# B_naive 4
# CD14_Mono 9
# CD16_Mono 7
# CD4_Proliferating 3
# CD4_TCM 18
# CD4_TEM 10
# CD8_Naive 9
# CD8_TEM 15
# cDC1 3
# cDC2 2
# gdT 5
# HSPC 2
# MAIT 6
# pDC 4
# Treg 11
# CD4_CTL 3
# CD4_Naive 12
# CD8_TCM 6
# Plasmablast 3
# NK 11
# NK_CD56bright 2

# %%
import json

# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\PBMC_Hao_batch_noZ\Level2\ACT_annotation")
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/ACT_annotation')
with open('L2_PreLect_ACT_overlap.json', 'w') as f:
    json.dump(overlapped_dict, f)
