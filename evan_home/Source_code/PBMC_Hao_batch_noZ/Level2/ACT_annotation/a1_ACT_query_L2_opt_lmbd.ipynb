# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc
import os

# %%
# adata = sc.read_h5ad('/Users/evanli/Documents/Research_datasets/PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')
adata = sc.read_h5ad(dataset_dir / 'PBMC_Hao/GSE164378_Hao/Harmony_noZ/Hao_Harmony_test_no_scale.h5ad')
adata.obs['celltype.l2'] = adata.obs['celltype.l2'].str.replace(' ', '_')
labels = adata.obs['celltype.l2']
types = np.unique(labels).tolist()
types
# Out:
# ['ASDC',
#  'B_intermediate',
#  'B_memory',
#  'B_naive',
#  'CD14_Mono',
#  'CD16_Mono',
#  'CD4_CTL',
#  'CD4_Naive',
#  'CD4_Proliferating',
#  'CD4_TCM',
#  'CD4_TEM',
#  'CD8_Naive',
#  'CD8_Proliferating',
#  'CD8_TCM',
#  'CD8_TEM',
#  'Doublet',
#  'Eryth',
#  'HSPC',
#  'ILC',
#  'MAIT',
#  'NK',
#  'NK_CD56bright',
#  'NK_Proliferating',
#  'Plasmablast',
#  'Platelet',
#  'Treg',
#  'cDC1',
#  'cDC2',
#  'dnT',
#  'gdT',
#  'pDC']

# %% [markdown]
# ## Read PreLect features

# %%
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/PBMC_Hao_batch_noZ/Level2/feature_selection_k3')
os.chdir(source_code_dir / 'PBMC_Hao_batch_noZ/Level2/feature_selection_k3')

features_dict = {}
# Read features for each celltype
for celltype in types:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        feature_df['abs_weight'] = feature_df['Weight'].abs()
        feature_df = feature_df.sort_values(by=['Tendency', 'abs_weight'], ascending=[False, False])
        feature_df.drop(columns=['abs_weight'], inplace=True)
        features_dict[celltype] = feature_df
    except:
        print('skipping:', celltype)
        continue
    # print(celltype, 'Feature count:', feature_df.shape[0])
    # print(celltype, 'Positive feature count:', feature_df[feature_df['Tendency'] == 1].shape[0])
    # print('------------------')

count_df = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df = features_dict[celltype]
    feature_count = feature_df.shape[0]
    positive_count = feature_df[feature_df['Tendency'] == 1].shape[0]
    count_df.loc[celltype] = [feature_count, positive_count]
count_df
# Out:
#                    Feature_count  Positive_feature_count
# ASDC                          47                      25
# B_intermediate                96                      49
# B_memory                     170                      90
# B_naive                        9                       6
# CD14_Mono                     29                      16
# CD16_Mono                     37                      17
# CD4_CTL                      122                      45
# CD4_Naive                    730                     393
# CD4_Proliferating             70                      35
# CD4_TCM                      247                     133
# CD4_TEM                      214                     112
# CD8_Naive                    271                     169
# CD8_Proliferating             94                      37
# CD8_TCM                      313                     120
# CD8_TEM                      108                      41
# Doublet                       28                      13
# Eryth                          6                       2
# HSPC                          20                      12
# ILC                           76                      30
# MAIT                          88                      44
# NK                            30                      15
# NK_CD56bright                100                      59
# NK_Proliferating              59                      28
# Plasmablast                   15                       7
# Platelet                       4                       3
# Treg                         168                      78
# cDC1                          37                      17
# cDC2                          12                       9
# dnT                           45                      15
# gdT                           22                      10
# pDC                           18                       8

# %%
# write to query for ACT
text = ''
for celltype in types:
    features = features_dict[celltype]['Gene'].tolist()
    features = ', '.join(features)
    # print(features)
    text_celltype = f'Clus_{celltype}: {features}\n'
    text += text_celltype

# %%
print(text)
# Out:
# Clus_ASDC: PPP1R14A, S100A10, PLAC8, SOX4, TCF4, CST3, SAMHD1, APP, ANXA2, AXL, C12orf75, CTSH, FCGRT, IRF8, LILRA4, DAB2, TXN, ALOX5AP, PLP2, PLA2G16, CCDC50, RAC1, PLD4, RAB11FIP1, HLA-DPA1, MALAT1, TMSB4X, S100A9, CD52, FTL, B2M, SAT1, MT-ND2, RPLP1, RPS28, PTPRC, RPS12, MT-CO2, MT-CO1, MT-ATP6, MT-CO3, RPL13, BTG1, RPL34, RPL32, TPT1, MT-ND1
# Clus_B_intermediate: LINC01857, IGHM, RALGPS2, MS4A1, ARHGAP24, JUND, BANK1, GPR183, TNFRSF13B, FCRL2, CD79A, POU2F2, FCRL3, COTL1, PTPN1, TCF4, CCDC50, ZBTB20, DDX21, PLAC8, HLA-DPA1, EMP3, RGS2, JUNB, CLECL1, CXXC5, CIB1, HLA-DPB1, HLA-DRA, EZR, IFT57, UBC, TSC22D3, HERPUD1, CD82, SAT1, TNFRSF13C, HLA-DQB1, DDX24, SEPT6, PLEKHO1, ANKRD12, SYK, ZFAS1, HSP90AB1, TOMM7, RAC2, TMA7, CD48, TMSB10, TXNIP, CXCR4, MEF2C, IGHD, TCL1A, TMSB4X, SELL, ACTB, H1FX, MT-CO3, NFKBIA, TPT1, MT-CO2, HMGB1, IGKC, FTL, TAGLN2, HVCN1, NAP1L1, MALAT1, SMAP2, OAZ1, MT-CYB, LYZ, ITM2B, LTB, PLPP5, ACTG1, MT-CO1, GABPB1-AS1, MDM4, HNRNPA1, S100A9, SSR4, MT-ATP6, SARAF, SUB1, S100A10, RPLP1, EVI2B, S100A4, TMBIM6, BIRC3, MIS18BP1, JAK1, HLA-DMB
# Clus_B_memory: LINC01781, LTB, AIM2, HLA-DRA, BLK, BANK1, TNFRSF13C, CD74, SSPN, IGHA1, ITGB1, MARCKS, TXNIP, MS4A1, ARID5B, COCH, ATP2B1, JCHAIN, S100A10, IGHG1, DAAM1, NAP1L1, RPS20, TMEM154, HLA-DPB1, EZR, FAM107B, SCIMP, PLP2, UBE2I, VPREB3, IGHG3, RPS12, TSC22D3, EVI2B, CHCHD10, CAPG, LYPLAL1, MBD4, TP53INP1, RPL14, ZFAS1, EEF1B2, CD82, RPL21, IGHA2, TOMM7, UBE2J1, CPNE5, SMAP2, RPS14, RPL27A, EIF3K, GNG7, ACTG1, SEL1L3, HSPA8, CD53, GAPDH, RPSA, PRKCB, IGKC, LY86, SLC25A6, MARCKSL1, RPLP1, UQCRH, TEX9, MIS18BP1, CD79A, RPS28, AHNAK, CLIC1, RPS29, RPS10, NPM1, RPS16, RPLP2, RAN, POU2AF1, RPS21, RPL13A, RPL4, GPR183, EEF1A1, RPS4X, RPS15A, PPDPF, RPL3, RPL39, IGHM, PTPRC, TMSB4X, ITM2B, SARAF, MALAT1, FOXP1, B2M, TMSB10, BTG1, CLEC2D, MYL6, SERF2, CTSS, FTH1, STX7, PSAP, ZEB2, GNAS, NCL, CYBA, MT-CO1, HSP90B1, DDX5, SSR4, SRGN, EIF1, LYZ, PPIB, RPS19, H3F3B, PLAC8, STK4, SEC62, JUNB, GSTP1, SEC61B, JUND, PRRC2C, DDX17, CD69, ARL4C, BTG2, MT-ND2, POU2F2, MT-ND5, MT-ATP6, PARP14, ANKRD11, CD164, C12orf57, CD47, PLEKHO1, RAC1, RPS24, NCF1, HLA-A, NEAT1, H3F3A, ERP29, LBH, N4BP2L2, SON, GRB2, STK17B, EEF1D, MT-ND4, RPL26, MT-ND3, ARGLU1, RPL18A, HLA-DRB5, SEPT6, PABPC1, RPL15, SH3BGRL3, RNASET2, TRIR, MT-ND1, JUN
# Clus_B_naive: IGHM, TCL1A, IGHD, CXCR4, MS4A1, HLA-DRA, B2M, MALAT1, VIM
# Clus_CD14_Mono: CD14, LYZ, NEAT1, S100A8, FCN1, VCAN, S100A9, MS4A6A, CYBB, CTSS, FOS, CCL3, NFKBIA, TNFAIP2, MARCKS, CEBPD, RPS19, MALAT1, MYL12A, NAP1L1, B2M, MT-ATP6, TMSB4X, MT-CO2, IFITM2, RPS27, MT-CO3, RPS5, ACTG1
# Clus_CD16_Mono: FCGR3A, LST1, AIF1, MS4A7, COTL1, TCF7L2, CFD, PSAP, CEBPB, HLA-DPA1, SERPINA1, SAT1, CST3, FCER1G, LILRB2, CDKN1C, MARCKS, MALAT1, B2M, NRGN, TAGLN2, TMSB4X, S100A9, S100A8, HLA-A, OST4, PTMA, RPLP1, MT-CYB, RPL41, RPS15A, RPS27, RPL30, MT-ATP6, RPL32, RPL35A, TMSB10
# Clus_CD4_CTL: GZMH, CD4, NKG7, FGFBP2, IL7R, S100A4, TRBC1, HOPX, ITGB1, GNLY, CD6, CD52, IL32, MAF, CD2, MYBL1, RORA, EFHD2, ID2, CD320, CD3G, TSC22D3, GZMA, YWHAQ, CCL5, RPS26, RPLP0, TOMM7, SH3BGRL3, RASGRP1, RPS10, MSN, S100A10, CXCR4, COMMD6, ZFP36L2, C12orf57, PLAC8, ANXA1, RPS28, CALM1, RPL27, LGALS1, DSTN, MT-ND5, KLRD1, CTSW, GZMB, CD7, CYBA, LTB, MT-ND3, HLA-C, JUNB, HLA-A, PTMA, TMSB4X, RPL28, H3F3A, PRF1, GIMAP4, RPS8, LDHB, LIMD2, B2M, FTL, RPLP1, MALAT1, SRGN, PABPC1, PTPRC, RPS4Y1, MT-CO3, RPS3A, DDX17, GNAS, HSP90B1, CLIC1, MT-ND1, MT-CO2, NAP1L1, NDUFB7, HLA-E, CD63, DDX5, RPS24, TYROBP, SET, SRSF5, MT-ND2, EIF3G, RARRES3, RPL10, NCL, HLA-B, TRAF3IP3, YWHAZ, H3F3B, MT-ATP6, ATM, ITM2B, CD74, MT-CO1, SERBP1, HNRNPU, OAZ1, TRBC2, FYB1, NEAT1, LY6E, PRRC2C, CDC42SE1, KLRB1, RAC2, COX7C, MBP, PSMB9, SLFN5, UQCRB, GMFG, RPL15, ACTR3
# Clus_CD4_Naive: FHIT, TSHZ2, TOMM7, CD4, IL6ST, TRAT1, NOSIP, ADTRP, NDUFA12, RFLNB, GIMAP7, RGS10, TMSB10, CHRM3-AS2, IKZF1, TRABD2A, MAL, ITM2A, CD7, RNASET2, ADD3, CCR7, RBMS1, SATB1, LTB, BCL11B, TCF7, CD40LG, RPS27, CD247, C1orf162, LINC00861, SARAF, NOP53, AK5, CHD3, TMIGD2, MARCKSL1, CD3G, ITGA6, MBNL1, SOCS3, LAMTOR4, LDHB, TRBC1, GPR183, CSGALNACT1, RPS25, CAMK4, AES, NSA2, PSIP1, LYZ, CALM3, BTG1, GMFG, EIF2S3, PDE7A, SEC62, ZFP36L2, IFITM2, RCAN3, TMC8, NDFIP1, RPL24, MAML2, ANP32B, CORO1B, PRMT2, HIST1H4C, MALAT1, TC2N, RPS14, ST13, TBC1D10C, RPL30, SKP1, FOXP1, H1FX, NDUFS5, SELL, FYB1, TPT1, DGKA, CYLD, TNFAIP8, PPIG, EPHX2, DAD1, RPL23, ATP5MC2, SERP1, PPA1, H3F3B, AAK1, COX6C, SUSD3, EPB41L4A-AS1, CNN2, ABLIM1, ETS1, ARL4C, HIST1H1D, COX4I1, RPS23, ZRANB2, INPP4B, MINOS1, STMN1, SMDT1, SEPT9, NFKBIZ, TRBC2, CORO1A, RSL24D1, CYTIP, EIF4B, TCF25, LSM14A, OCIAD2, GPSM3, FUS, PTPRC, JAK3, UQCRB, PKM, RPS20, EIF3E, PRKCA, TNFSF10, XRCC5, CD6, ATF7IP2, APRT, TGOLN2, STK17B, LINC01550, NDUFA1, ERP29, DDIT4, RPL31, RPL9, CWF19L2, IL7R, CD3E, HNRNPDL, PIK3IP1, LSM5, RPS13, PPP1R2, RPL38, MYL12A, SRP14, C6orf48, SON, GYPC, SRSF5, CHMP3, NACA, C12orf57, CD3D, SSBP1, RBL2, EIF5B, XRCC6, UBALD2, TRAF3IP3, SPTBN1, HMGN2, LEF1, C1orf56, ATP5MG, IL16, SIGIRR, S100A9, RPL11, RBM3, FOXN3, HNRNPM, RPL22, PNRC1, CDC42, LIMD2, RPS27A, LAT, RPS15A, DUT, SRRM1, KLF3, LUC7L3, U2SURP, EEF1D, HNRNPA0, RPS3A, XAF1, BDP1, CYTH1, PEBP1, SMIM26, RPL17, CMPK1, SELENOH, HNRNPH3, RPL5, RPL21, C8orf59, RPS24, ARHGAP45, RPL35A, FAU, ATP5PD, RPL34, CALR, RPS29, ATP5MD, SAMHD1, TESPA1, USP15, RAD21, RIPOR2, EEF1B2, XRN2, RPL29, EIF3F, CD48, RPL14, ANXA1, MIER1, MT-ND3, STMN3, UBA52, THOC2, EIF2S2, FTH1, GIMAP2, RPL19, TSPO, FXYD5, ITM2B, RPL39, MPHOSPH8, PFN1, RPL13, RPL37, RPL18, RPLP2, OXNAD1, RPL32, RPL10, RPL7A, RPL23A, RPS16, RPL27A, RPS9, PTMA, RPL7, RPS21, KLF2, RPSA, RPL6, RPL35, HNRNPA1, HLA-E, PABPC1, COX7C, DDX5, HMGB1, EIF3K, EIF4A2, RPL36AL, N4BP2L2, HNRNPA2B1, TRAC, SSR4, MYL12B, STK4, GNAS, EIF3G, PTP4A2, ATP5MPL, ATP5IF1, HNRNPA3, HNRNPC, GSTK1, OST4, PPDPF, GPX4, CD37, ATP6V1G1, TMA7, NUCKS1, SUMO2, COX8A, HMGN1, COMMD6, SUB1, CBX3, LDHA, RPS17, CUTA, NDUFA4, PTGES3, CLEC2D, SRSF2, SAP18, NEDD8, HP1BP3, YWHAB, ITGB2, SNHG7, HNRNPK, RBMX, HADHA, MT-ND4L, DEK, ANAPC16, SNHG8, ARPC5, EID1, DDX24, UQCRH, JUND, STAG2, TUBA1B, TTC3, NUCB2, MED10, MSN, RBM39, SNRPD2, ACAP1, C19orf53, CNBP, SMCHD1, RFC1, VAMP2, ICAM3, TPM3, NDUFB2, URI1, IK, MRPS21, TNRC6B, ATRX, NDUFB4, MDM4, KTN1, KANSL1, PIM1, C4orf3, ATXN7L3B, NCL, SSR2, CSNK1A1, AKAP9, ATP5PO, EIF3D, COX6B1, ARID1B, NSD3, ATP5PF, HNRNPH1, UXT, TOMM20, ATM, EIF1AX, CCDC66, SENP7, EIF3M, MTDH, BCLAF1, HNRNPR, HNRNPD, TKT, FKBP5, SNRPE, SEPT6, GIMAP1, ISCU, MZT2B, EMP3, RASGRP1, UBE2D3, MYH9, DDX18, DDX17, PSME2, EEA1, CACYBP, PET100, SP100, CHURC1, VDAC2, CD8B, ITGB1, S100A4, SH3BGRL3, S100A10, AHNAK, CXCR4, PASK, IL32, KLRB1, HLA-A, ISG20, B2M, ARPC1B, PRKCB, MT-ND4, IKZF3, MT-CO1, GUK1, CLIC1, RORA, PPP2R5C, KLF6, RPL12, EZR, SRGN, ITGA4, IL10RA, PAXX, PDE3B, KIAA1551, PIP4K2A, TBCA, HSP90AA1, CYBA, SLC38A1, CD96, GTF3A, PRDX6, MT2A, BIRC3, EIF3A, MT-ND2, FAM107B, RPS4Y1, SYNE2, RPL36A, NELL2, PDCD4, UBTF, PAG1, LIMS1, NEAT1, TAGLN2, TSC22D3, YBX1, MT-CO2, HLA-DPB1, HCST, FTL, HSP90AB1, ARPC3, PSMB9, UBB, ELF1, RNF213, COTL1, ARPC2, RAC2, EEF2, MBP, NAP1L4, RABAC1, H3F3A, ZFAS1, HLA-F, IFI16, MT-CO3, BTN3A2, TOB1, TTC39C, TXNIP, PPIB, CNOT6L, RCSD1, CALM2, SPOCK2, PPP1CC, PIK3R1, DDT, UBE2I, RBM25, ACP1, WIPF1, TRADD, DHRS7, UBL5, EMB, PARK7, CD27, CD99, SYF2, PLP2, H2AFV, ATP6V0E1, BZW1, KLF13, SF3B1, FAM133B, RAN, RPLP1, TCEA1, JUN, HSPE1, RARRES3, LSM7, CCDC85B, HLA-DRA, CD74, ARL6IP4, TAF7, FGFR1OP2, SLC25A3, DUSP1, HLA-C, SCAND1, NKTR, RPS18, EVI2B, BAX, CCDC88C, S100A11, RPS26, TAX1BP1, ATP2B1, HCLS1, SNRK, CDV3, MRPL33, AQP3, ANKRD11, CDKN1B, GPR155, CCSER2, RPS2, KIF2A, RACK1, GZMM, HNRNPF, TRAM1, RUNX3, NAP1L1, HIGD2A, SLC25A6, ANKRD12, KMT2E, SRSF7, PPIA, ARID4B, PCM1, TMBI ...
# Clus_CD4_Proliferating: DUT, STMN1, HMGB2, TOP2A, CD3D, LIMS1, TRAC, IL32, MKI67, TUBB, COTL1, PCLAF, CNN2, TUBA1B, ANP32E, PTTG1, TRBC2, CORO1B, RPA3, MCM3, HMGN2, TYMS, TMPO, NUSAP1, SLC25A5, SMC2, MRPL51, JPT1, CDC25B, SPOCK2, CD3G, CBX5, NEAT1, ACTG1, ISG15, MALAT1, NKG7, FTL, TXNIP, CCL5, GNLY, B2M, HLA-E, HLA-B, RPS27, PNRC1, RPL21, SERF2, RPL34, FAU, RPL6, HLA-C, UBB, RPL30, RPL39, MT-ND3, H3F3B, RPL32, PFDN5, SRSF5, RPS19, RPS29, RPL13, RPL10, RPS12, HCST, TPT1, RPLP1, RPL35A, RPS27A
# Clus_CD4_TCM: ITGB1, LTB, LIMS1, IL7R, GPR183, MAF, CD2, AQP3, AP3M2, USP10, CD52, ANXA1, CD4, S100A11, CORO1B, FYB1, RNASET2, TRADD, CD69, JUNB, VIM, S100A4, ITM2A, OPTN, GSTK1, RORA, IL32, FXYD5, INPP4B, RPL36A, CD6, HINT1, MAL, TRAC, PPP2R5C, TTC39C, JUND, TRAT1, NEAT1, TCF7, TNFRSF4, RPL27A, KLRB1, CD3D, ARHGAP15, COTL1, TOMM7, CDKN1B, RPL36, MINOS1, SH3BP5, SEPT9, RPL39, PIK3R1, ARID5B, SPOCK2, MDFIC, TOB1, GAPDH, TMEM123, CD40LG, TIMP1, LDHB, AHNAK, SH3BGRL3, TNFAIP8, GPRIN3, RPS29, RPL31, SLC2A3, PDE4D, TMSB10, ZFAS1, EML4, ANKRD12, NOSIP, RPS11, RPS15A, TMA7, EMP3, MYH9, KLF2, CD3E, MZT2B, ACAP1, LAT, LEPROTL1, KLF6, SOD1, MYCBP2, TRBC1, RPL36AL, RPL37, CD3G, HIGD2A, RPL38, CSTB, NSD3, ACTB, COX6C, SEC61B, RPSA, RPL6, ZFP36L2, TNFRSF25, TRBC2, COX6A1, RPL13A, JUN, PSME1, SMCHD1, H1FX, ISG15, RPS4X, BCL2, BCL11B, COX7C, RPLP0, GPSM3, RPL14, FTH1, STK17B, RPS8, TPT1, RPS20, RPS18, PNRC1, PFN1, CALM1, RPS25, ARPC1B, EIF1, GIMAP4, CCL5, FTL, MALAT1, HCST, DUSP2, RPL21, CD74, NKG7, ID2, HLA-C, MT-CO1, HLA-B, RPS24, MT-ND4, PTMA, H3F3A, RAP1B, RPS5, NUCB2, MT-CO2, AIF1, PRMT2, HNRNPA2B1, SELL, HSP90AB1, RPS10, RPS4Y1, OAZ1, B2M, ACTR2, TXNIP, IER2, SERBP1, CYBA, RPL8, TAGLN2, HLA-DPB1, HNRNPU, JAK1, RPS27, S100A10, SNHG8, GYPC, CD7, TUBA1B, RPS13, CALM2, KLF13, DDX5, XRCC5, EEF1D, PAIP2, MT-ATP6, HNRNPA3, RIPOR2, UBB, LYZ, HLA-E, MTPN, MT-ND3, UCP2, COX4I1, LUC7L3, LSP1, MT-CO3, SMAP2, C12orf57, UQCRH, MCL1, HNRNPH3, DUSP1, CIRBP, YBX1, PNISR, GIMAP1, GSTP1, TTC3, TSC22D3, EIF3M, CTSS, LITAF, RPL26, HNRNPK, HMGN2, SRRM1, MT-ND1, HNRNPC, SATB1, BCLAF1, SAT1, HLA-A, RPS26, PTP4A2, DDX17, RPL15, EIF3G, RPS3A, BTG1, CLIC1, TRAF3IP3, GCC2, CALR, RACK1, EIF3K, LIMD2, LEF1, S100A9, SLC25A5, UXT, RPL10A, NPM1, UBE2D2, PNN, ATP5MG
# Clus_CD4_TEM: GZMK, IL7R, CD4, IL32, KLRB1, SYNE2, CD2, CCL5, GZMA, TNFAIP3, ITGA4, ANXA1, KLF2, LYAR, ZFP36L2, LTB, ITM2A, CAST, S100A4, S100A11, KLF6, TRAC, S100A10, AHNAK, CD69, EMB, FYB1, TRBC1, TOMM7, CXCR4, ARL4C, EMP3, CALM1, RPLP0, RPS29, UBC, PFN1, GPR183, RPL3, GAPDH, CD52, CD6, RPS26, CD40LG, C12orf57, GIMAP7, RARRES3, RNASET2, RPL36A, LDHB, ARAP2, RPS19, CIB1, SH3BGRL3, TIMP1, EEF1B2, CD3G, TXNIP, PIK3R1, RPLP1, ANKRD12, TXN, RPL38, TSC22D3, RPS25, GSTK1, RPS3, TAGAP, RPS28, COMMD6, RPS6, RPS14, KIAA1551, RPL23A, TRBC2, RPL36, TPT1, APRT, ARL6IP5, LPIN2, EML4, RPL9, RPS27, RPL10, RPL27A, RPL35A, RPS20, RPS15A, RPS18, RPL13A, RPL30, RPL34, RPS27A, RPL37, RPLP2, RPS2, RPS8, RPL7A, MT-ND2, RPS21, RPL39, RPSA, RPL35, RPL12, RPL10A, OST4, RPL11, RPL41, SMCHD1, HINT1, RPL4, RPS4X, NKG7, MALAT1, ITGB1, CTSW, GYPC, TOB1, SELL, S100A6, CD7, TMSB4X, TMSB10, GNLY, DDX5, ATM, HLA-A, FTL, ZFAS1, H3F3A, MT-CO2, MT-CO1, B2M, PTMA, GLRX, UCP2, SERF2, OAZ1, UBB, SRSF5, RPL28, RPL37A, HMGB1, ARGLU1, EIF1, RPL21, MYL12A, C6orf48, HCST, MT-ND3, HLA-C, SON, GNAS, DDIT4, EIF4A2, PABPC1, MT-CO3, LITAF, PPP2R5C, RPS11, PTPRC, MT2A, CYBA, NEAT1, SEC62, ACTB, DUSP1, CD74, BZW1, SRSF11, PNISR, HNRNPA2B1, MT-ND4, SRRM2, CCNI, SLC25A3, ANKRD11, TCF7, NAP1L1, RSRP1, ZFP36, PNN, SARAF, NPM1, EIF3E, H3F3B, NACA, DUSP2, RPL15, FLNA, SRGN, HNRNPU, ARHGDIB, MYCBP2, DDX17, ATP5MC2, RBM39, LAPTM5, CIRBP, YWHAZ, SYF2, ATP5MG, ARPC5, ST13, NCL, RPS13, HLA-B, AKAP9, PPIA, FUS, SMAP2, ID2, MORF4L1, SPOCK2
# Clus_CD8_Naive: CD8B, CD8A, LINC02446, NELL2, S100B, RGS10, PDE3B, PASK, MT-CO2, PRMT2, LEF1, THEMIS, RPS26, NUCB2, OXNAD1, LEPROTL1, TOB1, HCST, MT-CO3, TMSB10, GPR155, AIF1, NOSIP, LRRN3, UQCRB, CARS, ATM, ACTN1, GYPC, LBH, MT-ND4, SNHG8, CD3D, NDFIP1, ACTG1, CD96, CCR7, SLC25A3, TRABD2A, RPS5, A1BG, SELENOH, NPM1, PIK3IP1, GZMM, CD55, CD7, RPL12, LCK, RPS24, MT2A, EIF3H, RPS4Y1, STK17A, ABLIM1, PRDX6, CD3E, FBL, RAC2, TGFBR2, RPL28, TBCA, HSP90AB1, RPL24, ACTB, RPS21, ARHGDIB, RPS15, SATB1, RPL36A, SELL, GABPB1-AS1, SARAF, RPLP0, C6orf48, COX4I1, BTF3, RPS19, RPL31, LDLRAP1, SLFN5, CD27, NAP1L4, ANKRD11, FAM107B, SNRPD2, HIGD2A, TRAF3IP3, COX6C, DDX17, CORO1A, NAP1L1, RNF213, EEF1B2, AAK1, RPL4, COX7C, UQCRH, ARMH1, EVL, RPS13, RPL13, RPLP1, UXT, ATP5MG, NDUFB8, RPL22, C19orf53, CLEC2D, RPSA, RARRES3, COMMD6, RPS28, LIMD2, RPL32, CDC42SE2, RPL18, RPS11, RPS23, RCAN3, RPS3A, RPL10A, PSMA3-AS1, CCDC85B, RPS15A, RPLP2, MT-CO1, RPL37, RPS12, RPL19, RPS8, RPL14, RPS6, RPL9, RPS18, RPL36, RPS9, RPL34, RPL7A, RPL35A, RPL29, RPS16, MT-ND3, RPS25, MT-ATP6, RPL38, RPS2, RPS14, RPL23A, RPL37A, MT-ND1, RPL15, RPS4X, RPL10, RACK1, NACA, RPL7, RPL27A, MT-CYB, PNISR, HNRNPA1, C12orf57, NDUFS5, TMA7, SLC25A6, EIF3G, EIF3E, FOXP1, SEPT6, CCL5, TMSB4X, FTH1, B2M, MALAT1, ARL4C, H3F3B, ZFP36L2, ANXA1, EMP3, KLF6, PTMA, TOMM7, PTPRC, EIF1, LTB, JUNB, NSD3, RNASET2, S100A11, PIK3R1, S100A4, JUND, HMGB1, PPP2R5C, CD99, FTL, HLA-B, HSP90B1, OAZ1, KLF2, ARL6IP5, RPL36AL, DDX5, CD247, TUBA1B, IL7R, LAMTOR4, ADD3, UBC, FXYD5, CD69, SRGN, CIRBP, VIM, CD52, HLA-E, FYN, CNBP, EID1, SRSF7, RPS27, SUMO2, CYLD, H1FX, AHNAK, PTGES3, MYL12B, SYNE2, HNRNPA2B1, CALM1, SON, PTP4A2, CLIC1, SMCHD1, PNRC1, GSTK1, CDC42, MYL6, H3F3A, PPIB, GIMAP7, ANKRD12, DEK, CFLAR, CD74, KMT2A, CAST, IER2, MBNL1, MBP, S100A6, CYBA, CD37, TNFAIP8, HLA-C, ITM2B, CELF2, PEBP1, KMT2E, CCNI, ANP32B, CHCHD2, CALM2, RPL41, RPS27A, TXNIP, RPL11, RPL8, EEF2, SKP1, FUS
# Clus_CD8_Proliferating: STMN1, CD3D, CD8A, HELLS, GZMH, CD8B, CCL5, CD3G, IL32, CD52, NKG7, DUT, DEK, LGALS1, MCM5, TRBC2, EIF5B, MCM4, PCNA, MCM6, HSP90AB1, SMC1A, ATP5MF, PRDX2, NASP, LINC01871, S100A4, CALR, ANXA6, TRAC, NUCKS1, LSM7, GNLY, DCTPP1, HNRNPD, HNRNPDL, ZEB2, MALAT1, TXNIP, B2M, HIST1H4C, HLA-E, H3F3B, HMGB1, RPL36AL, CD48, KLRD1, FTH1, KLF2, BTG1, EIF1, MACF1, HINT1, RPL10, MYL12A, RPLP1, H1FX, ITM2B, TMSB10, FTL, NEAT1, TMSB4X, RPL41, RPS3A, RPS27A, UBA52, RPS14, RPL21, SRSF5, RPL18, RPS15A, RPS23, OAZ1, CDKN2D, RPS24, RPL39, RPL5, EEF2, RPL36, CD247, H3F3A, RPL30, RPS26, CIRBP, RPS28, RPL37, DYNLL1, TPT1, NPM1, TYMS, ZFP36L2, RPL11, EEF1A1, MT-CO2
# Clus_CD8_TCM: CD8B, CCL5, CD8A, IL7R, GATA3, ANXA1, YBX3, LTB, ZFP36L2, ITGB1, COTL1, LDHB, KLF2, PLP2, LINC01871, IL32, ARHGAP15, RPL36A, CLDND1, VIM, FXYD5, LEPROTL1, PPIB, GSTK1, S100A10, GPR155, SEC61B, RPS17, GPR183, NSD3, RPL13A, RPL39, RPS19, RPL4, TRAC, GLIPR1, PTGER2, RPS18, PAG1, DDX21, ZFAS1, RCAN3, SORL1, RPLP0, S100A6, SESN3, CHCHD2, ITGA4, GCC2, TSC22D3, TCF7, CD96, RPS8, JUNB, SEMA4D, HCST, SLC25A6, PIK3R1, CDKN1B, RPS12, SSR4, SNHG8, JUND, SERINC5, S100A4, RPL12, MGAT4A, EVL, CD52, EMP3, ID2, RPLP2, RPS26, GUK1, RPS4X, SCML4, CXCR4, CYLD, C9orf78, CD48, AHNAK, RPL27, SMDT1, EEF2, RPL36, RPS6, RPS4Y1, CASP8, RPL27A, C12orf57, IL10RA, TTC3, TXNIP, SARAF, STK4, CUTA, RPS20, RPL13, CDV3, RPL8, CD99, TPT1, ISG20, RPL38, PFDN5, DDX17, DDX24, KLF6, RPL32, MT-CYB, RPLP1, FAM107B, STT3B, RPL37, CYBA, HLA-A, TMA7, ANKRD12, RPL3, RPL10A, MALAT1, GZMA, TMSB10, GZMK, NKG7, KLRB1, B2M, CST7, GNLY, NUCB2, TMSB4X, MT-CO3, RAP1B, BTG1, HLA-E, PLAC8, DUSP2, OAZ1, ARL4C, PTPRC, MT-CO1, MT-CO2, RPS24, RGS10, ZFP36L1, TNFAIP8, RIPOR2, RPS27, FTL, KLF3, ATP5MC2, MT-ATP6, ETS1, LINC00861, GAPDH, NFKBIA, IER2, GIMAP7, RPL10, ARHGDIB, S100A9, H3F3B, SERF2, UQCRH, H3F3A, MYL6, PRMT2, CORO1A, HMGN2, UCP2, RPL21, CD74, SPOCK2, RHOA, LYZ, HLA-B, CTSS, STK17A, TOMM7, GZMM, YWHAZ, ITGB2, HIGD2A, SEPT6, CDC42, EIF1, RORA, ATP5F1E, RPL24, LBH, NACA, PPIA, PTMA, FTH1, RPS13, GPX4, TRBC1, AKAP13, COX6C, MSN, SMAP2, PNRC1, PRPF38B, SRSF5, DDIT4, SLC25A3, GPSM3, PFN1, NUCKS1, SRGN, CELF2, CD3G, TLN1, SATB1, LIMS1, SEPT7, MT-ND1, COX4I1, ACTB, UQCRB, OST4, NEAT1, SRP14, JAK1, CCNI, EML4, RNF213, ARPC2, YPEL3, LAPTM5, CD37, HSPA8, ITM2B, CD247, UBB, COMMD6, NCL, RPL31, SH3BGRL, RPL41, TPM3, SYNE1, RPS10, HNRNPA1, RPSA, ATM, RPS16, HMGB1, GMFG, RPS14, ANAPC16, EEF1A1, RPS27A, RPS23, RPL11, RPL19, RPL28, RPS28, RPS15A, RPL35A, RPL26, RPS9, RPL15, RPS15, RPL18, RPS21, RPS5, RPL7, EEF1B2, RACK1, RPL7A, NPM1, PABPC1, RPS11, BTF3, EIF3E, MT-ND3, ACTG1, RPL34, AES, RPS3, CFL1, RPS29, RPS3A, MT-ND2, RPS2, RPL18A, EIF3K, RPL23A, RPL9, RPL29, RPL37A, RPL14, RPL23, UBA52, SUB1, RPL17, RPL22, SET, EEF1D, CALM1, CCND3, RPS7, HLA-F, TOMM20, SH3BGRL3, RPS25, RPL5, FOXP1, ELOB, FAU, CD44, HP1BP3
# Clus_CD8_TEM: CD8A, CD8B, TRAC, DUSP2, NKG7, CCL5, KLRD1, GZMK, CD3G, TRGC2, CD3D, TRBC2, GZMH, IL32, CST7, PIK3R1, PPP2R5C, CTSW, MBP, LYAR, KLF2, EZR, JUNB, TXNIP, HLA-DPB1, CMC1, KLF6, HCST, ARID5B, FCRL6, LITAF, RPS27, PTPRC, CD84, GZMM, ZFP36L2, GUK1, KIAA1551, PPDPF, PFDN5, DDX5, KLRB1, RPLP1, MT-CO3, ACTB, RORA, PRF1, PTMA, CD247, RPLP0, NAP1L1, NPM1, TPT1, ID2, MT-CO2, LAPTM5, IL7R, LTB, NEAT1, ANP32B, ITM2B, IFITM2, HNRNPA1, HOPX, HNRNPA2B1, GNLY, LCP1, EEF2, ACTG1, GZMB, TYROBP, AAK1, SERBP1, RPL18, MSN, RPL23, MT-CO1, RPS11, LDHB, SYNE2, H3F3A, HNRNPC, RPL12, RPL31, RPS3A, HMGB1, LEPROTL1, HLA-E, ARHGDIB, COX6B1, CYBA, RPL28, HNRNPK, HMGN2, HMGB2, VIM, SARAF, RACK1, FTH1, PPIB, EMP3, IL2RG, GZMA, ARPC2, B2M, HLA-A, MT-ND3, SRSF5
# Clus_Doublet: PPBP, LST1, FCGR3A, AIF1, FCN1, MS4A7, CDKN1C, TNFRSF1B, FOS, S100A11, CTSS, NRGN, TYROBP, B2M, TMSB4X, MALAT1, H3F3A, TPT1, MT-ATP6, FTH1, MT-CO3, RPS27, ACTB, MT-CO2, RPS18, RPS29, OAZ1, HLA-E
# Clus_Eryth: HBB, HBA1, MALAT1, TMSB4X, B2M, MT-CO1
# Clus_HSPC: CDK6, SOX4, SPINK2, ZFAS1, SERPINB1, STMN1, ANKRD28, AC084033.3, SNHG7, NPM1, PRSS57, AIF1, TMSB4X, HLA-B, BTG1, B2M, S100A6, TMSB10, HLA-C, MALAT1
# Clus_ILC: KLRB1, GATA3, TRDC, TNFRSF18, FXYD5, RRBP1, DDIT4, TNFRSF4, ANXA1, ITGB1, IFITM2, AREG, CD7, DUSP1, TSC22D3, IL7R, JUND, IL32, LTB, CD63, CTSW, KLF2, IER2, SELL, IRF1, EMP3, NFKBIA, CALM2, IKZF1, AES, NKG7, FYB1, GNLY, MALAT1, RNF213, TMSB4X, MT-CO1, RPS12, CYBA, RPS26, RPLP1, MT-ND3, MT-CO3, GAPDH, B2M, RPS2, CCL5, PTPRC, CORO1A, TRAC, TRBC2, FTH1, LAPTM5, TMSB10, ATP5F1E, S100A9, HLA-E, RPL36A, DUSP2, HCST, RPL39, RPL23, RPS18, RPL12, MT-CO2, MT-ND2, OAZ1, GMFG, RPL30, RPL28, RPS27, CALM1, RPS15A, RPL37, FTL, ARL4C
# Clus_MAIT: KLRB1, NCR3, IL7R, GZMK, SLC4A10, CD8A, DUSP2, S100A6, NKG7, TRBC2, PHACTR2, CXCR4, S100A4, LTB, RPS26, ID2, KLRG1, HSP90AB1, ARL4C, SPOCK2, DUSP1, LINC01871, CTSW, TOB1, AQP3, RORA, GZMA, CCL5, NRIP1, CD69, ZFP36L2, ERN1, CEBPD, DDIT4, JUNB, PRDM1, CD3D, HCST, ODF2L, MAF, TRGC2, RPL17, GPR65, BTG1, TMSB10, TMSB4X, MALAT1, FYB1, KLF2, B2M, RPS27, TXNIP, NEAT1, KLRD1, FTH1, AES, PFN1, MT-CO1, TRBC1, PTPRC, ARPC2, DDX5, ARL6IP5, GAPDH, RPLP1, RPS11, S100A10, MT-ATP6, RPL13A, SARAF, SRGN, JUND, GNLY, TSC22D3, HLA-A, IFITM2, RPL23, CD247, MYL6, RPL21, CD74, ARHGDIB, RPL41, ITGB1, PLAC8, MT-CO3, STK4, RARRES3
# Clus_NK: KLRF1, CD247, TYROBP, CLIC3, PRF1, NKG7, SPON2, GNLY, GZMB, CST7, CD7, KLRB1, FCGR3A, KLRD1, FCER1G, B2M, RPLP1, CD52, VIM, FTH1, PTMA, TMSB4X, MALAT1, RPL39, MT-ND1, MT-CYB, RPS2, MT-ND3, RPLP0, MT-ND2
# Clus_NK_CD56bright: SELL, GZMK, XCL2, GNLY, KLRD1, XCL1, CTSW, CD44, NCAM1, GPR183, KLRC1, AREG, CMC1, IL2RB, SPTSSB, IFITM3, IL18R1, CD2, TCF7, TSC22D3, HOPX, FOS, TAGLN2, DUSP2, KLRF1, ITGAX, ID2, RPS3A, IL7R, TYROBP, COTL1, FXYD5, JAK1, GATA3, IFITM2, RPS24, RPL3, EEF1B2, TNFRSF18, RPS18, RPS19, NOP53, RPS15A, RPL10A, RPL13A, TPT1, RPS27A, RPS2, EEF1A1, RPS23, RPS28, RPS14, RPL27A, RPS4X, RACK1, RPS5, RPLP1, RPL9, RPS13, MALAT1, TMSB4X, S100A4, CCL5, MT-CO1, CYBA, GZMB, ACTB, CST7, S100A6, PPP2R5C, B2M, SARAF, ACTG1, MT-CO2, PRF1, HLA-B, MYL12A, PTPRC, OAZ1, CXCR4, CD247, TMSB10, ITM2B, GZMA, JUNB, LCP1, RNF213, SYNE2, EIF1, SH3BGRL3, IL32, FTH1, VIM, GZMM, EFHD2, ARPC2, MT-ATP6, LYZ, HLA-A, TMA7
# Clus_NK_Proliferating: STMN1, DEK, GNLY, HMGB2, PCNA, KLRF1, TUBA1B, TYMS, CD7, DNMT1, TRDC, GZMA, IFITM2, IGFBP7, NKG7, CTSW, NASP, HNRNPAB, DUT, HMGN2, CLSPN, PRF1, SMC4, NUCKS1, CD247, MCM7, H2AFZ, TMPO, MALAT1, CD52, FTL, RPS27, MT-CYB, NEAT1, RPL41, RPL13, TPT1, TMSB4X, MT-CO3, RPS12, EEF1A1, B2M, RPS28, RPLP2, RPL13A, RPL10, RPL26, RPL34, MT-CO1, RPS18, RPL30, RPS3, MT-ATP6, RPL32, RPL11, RPS27A, RPS15A, IL32, S100A4
# Clus_Plasmablast: JCHAIN, MZB1, SEC11C, IGKC, IGHA1, HSP90B1, IGLC2, MALAT1, TMSB4X, FTH1, RPS27, RPS12, HLA-DRA, RPL30, ACTB
# Clus_Platelet: PPBP, PF4, NRGN, MALAT1
# Clus_Treg: RTKN2, TIGIT, FOXP3, BIRC3, IKZF2, RPL36, IL32, USP15, TRAC, C12orf57, S100A4, IL2RA, RPL12, IL10RA, RPL8, AC243960.1, S100A10, SOD1, LEF1, ANKRD12, LDHB, PIK3IP1, CXCR4, PIK3R1, RCAN3, NSD3, RPS6, CD27, SMCHD1, TNFRSF1B, TRBC2, SELL, ARID5B, CDKN1B, RPS17, TRAF3IP3, C6orf48, FOXP1, LEPROTL1, SAMHD1, ITGB1, ETS1, PTMA, SYNE2, RPL29, GIMAP7, CIRBP, RPS15, RPL10A, RPL32, FYN, RPL5, RPL13, SRSF5, RPL35, CD3G, AAK1, NAP1L1, CCNI, GIMAP1, TPR, ISG20, RACK1, MPHOSPH8, TMEM123, RPS8, PYHIN1, RPS27, SARAF, PSIP1, RPS28, RPL11, RPL18A, EEF1D, BCL2, RPL30, EEF2, SKAP1, IL7R, NOSIP, ZFP36L2, MT-CO3, ANXA1, CD74, MT-CO1, CCL5, CYBA, ARPC3, RPLP0, RPS24, UBB, PRMT2, SSR4, STK17A, HINT1, MSN, ATP5MG, ARPC2, HMGB1, YWHAZ, SERF2, LRRFIP1, ATM, IFITM2, MYL12A, HLA-C, LCP1, MT-CO2, TPM3, NEAT1, VIM, CLEC2D, RIPOR2, ARPC1B, RGS10, TCF7, HCST, SEPT7, COX6C, MBNL1, UQCRB, FTH1, CD37, HLA-B, H3F3B, GNAS, PNRC1, COX4I1, ATP5F1E, ARPC5, IKZF1, OAZ1, PLAC8, NUCB2, ITGA4, MYL6, RAP1B, RNF213, ARL4C, SERP1, UQCR11, MT-ND1, HLA-DRA, ERP29, ACTG1, JUNB, HSP90B1, S100A6, GPSM3, TMSB10, LIMD2, EVI2B, RBM39, COX7C, LTB, HLA-F, DDX5, MT-ND4, RPL7A, MTPN, SLC25A5, KLF2, CDC42SE2, CD52, SH3BGRL3, PSME1, HMGN1, HIGD2A
# Clus_cDC1: IRF8, CPVL, CLEC9A, CPNE3, C1orf54, CST3, WDFY4, SNX3, ID2, SHTN1, BASP1, S100A10, HLA-DPB1, HLA-DPA1, HLA-DQB1, HLA-DRB1, BATF3, MALAT1, S100A4, FTL, TPT1, B2M, TYROBP, ITM2B, S100A9, CD52, CTSS, OAZ1, MT-CO1, SH3BGRL3, MT-ND3, BTG1, EEF1A1, MT-ATP6, RPS27, MT-ND2, MT-CO2
# Clus_cDC2: FCER1A, HLA-DQA1, CLEC10A, HLA-DPB1, CST3, LYZ, HLA-DRA, HLA-DQB1, HLA-DPA1, MALAT1, B2M, FTL
# Clus_dnT: GZMK, NUCB2, CD27, TCF7, SEPT6, FCMR, LYAR, GPR183, MT2A, CD3D, FYB1, LDHB, PIK3IP1, FOXP1, NAP1L1, FTH1, IL7R, CCL5, CYBA, PTPRC, B2M, HLA-C, MT-ND1, RPS19, NEAT1, NKG7, MT-ND2, RPS18, RPS2, RPL3, RPL18A, RPL41, MT-ND3, RPS12, VIM, RPS26, RPL35, S100A4, RPLP0, HSP90AA1, MT-ND4, HLA-B, RPS11, RPS9, H3F3B
# Clus_gdT: TRDC, TRGC1, CD3D, CD3G, TRGC2, DUSP2, CCL5, IL32, CD3E, PPP2R5C, B2M, TMSB4X, MALAT1, TMSB10, RPLP1, ACTB, GNLY, NEAT1, MT-CO1, RPS26, MT-CO3, IFITM2
# Clus_pDC: TCF4, GZMB, CCDC50, UGCG, IRF8, PPP1R14B, JCHAIN, IRF7, TMSB4X, MALAT1, TXNIP, MT-ATP6, MT-CO3, B2M, MT-ND3, MT-CO2, MT-CO1, MT-CYB
