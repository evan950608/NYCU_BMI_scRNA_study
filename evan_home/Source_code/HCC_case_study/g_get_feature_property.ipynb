# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import sys
# sys.path.append('/Users/evanli/Documents/EvanPys/Progress')
# sys.path.append('/home/jovyan/work/GitHub/EvanPys/Progress')
# sys.path.append(r'C:\Users\evanlee\Documents\GitHub\EvanPys\Progress')
sys.path.append(str(source_code_dir))
from ADlasso2 import AD2_w_utils_lossdiff_noZ as ad

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
import json

# %%
import scanpy as sc

# adata = sc.read_h5ad(r"C:\Users\evanlee\Documents\Research_datasets\HCC_Lu\HCC_Lu_preprocessed_noscale.h5ad")
adata = sc.read_h5ad(dataset_dir / 'HCC_Lu/HCC_Lu_preprocessed_noscale.h5ad')
print('Original adata:', adata.shape)
# Out:
# Original adata: (71915, 25712)

# %%
def plot_feature_property(adata, Y, AD_object, celltype):
    # Get feature property
    prop = ad.featureProperty(adata.X, Y, AD_object)
    prop['featureID'] = adata.var_names
    print(prop.head())

    # Plot feature property
    # Filter the data
    positive_data = prop[prop['select'] == 'PreLect_positive']
    negative_data = prop[prop['select'] == 'PreLect_negative']
    other_data = prop[prop['select'] == 'No selected']

    # Plot the other dots with grey color and alpha=0.5
    sns.scatterplot(x="prevalence_1", y="prevalence_0", color='#BCBCBC', alpha=0.5, data=other_data, label='Others')
    # Plot the positive dots with red color and alpha=1
    sns.scatterplot(x="prevalence_1", y="prevalence_0", color='r', alpha=1, data=positive_data, label='PreLect_positive')
    # Plot the negative dots with blue color and alpha=1
    sns.scatterplot(x="prevalence_1", y="prevalence_0", color='b', alpha=1, data=negative_data, label='PreLect_negative')

    # Get the current axes
    ax = plt.gca()

    # Get the handles and labels from the scatterplot
    handles, labels = ax.get_legend_handles_labels()
    order = [1, 2, 0]
    # Set the legend
    try:
        plt.legend(handles=[handles[idx] for idx in order], labels=[labels[idx] for idx in order], loc='upper left', fontsize='small')
    except:
        print('Failed to plot legend')
    plt.xlabel('Target prevalence')
    plt.ylabel('Other prevalence')
    plt.title(f'{celltype}: selection profile')
    # plt.show()
    plt.savefig(f'./feature_property_plot_new/{celltype}_selection_profile.png', dpi=300)
    plt.close('all')
    del adata

    return prop

# %%
# os.chdir(r'C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\HCC_case_study\feature_selection_k3')
os.chdir(source_code_dir / 'HCC_case_study/feature_selection_k3')

clusters = [f'Leiden_{i}' for i in range(24)]
label = adata.obs['leiden'].tolist()
for clus in clusters:
    print('=====')
    print(clus)
    # Binary classification of a celltype
    celltype_label = [1 if x == clus else 0 for x in label]
    # create index for a celltype
    celltype_indices = [idx for idx, label in enumerate(celltype_label) if label == 1]

    with open(f'{clus}_PreL_model.pkl', 'rb') as f:
        prelect = pickle.load(f)
    
    property_df = plot_feature_property(adata, celltype_label, prelect, clus)
    property_df.to_csv(f'./feature_property_plot_new/{clus}_property_df.csv')
    print(property_df.head())
# Out:
# =====
# Leiden_0
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.001496
# 1       0.046556  0.029140  No selected    0.117222      0.082202
# 2       0.040168  0.022520  No selected    0.107113      0.082916
# 3       0.001608  0.000998  No selected    0.005131      0.003158
# 4       0.000339  0.000173  No selected    0.001196      0.000848
#
#    prevalence_1      featureID
# 0      0.006549   RP11-34P13.7
# 1      0.296394     FO538757.2
# 2      0.230907     AP006222.2
# 3      0.015224  RP4-669L17.10
# 4      0.002977   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.001496
# 1       0.046556  0.029140  No selected    0.117222      0.082202
# 2       0.040168  0.022520  No selected    0.107113      0.082916
# 3       0.001608  0.000998  No selected    0.005131      0.003158
# 4       0.000339  0.000173  No selected    0.001196      0.000848
#
#    prevalence_1      featureID
# 0      0.006549   RP11-34P13.7
# 1      0.296394     FO538757.2
# 2      0.230907     AP006222.2
# 3      0.015224  RP4-669L17.10
# 4      0.002977   RP5-857K21.4
# =====
# Leiden_1
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002641
# 1       0.046556  0.029140  No selected    0.117222      0.131239
# 2       0.040168  0.022520  No selected    0.107113      0.122183
# 3       0.001608  0.000998  No selected    0.005131      0.005784
# 4       0.000339  0.000173  No selected    0.001196      0.001377
#
#    prevalence_1      featureID
# 0      0.000393   RP11-34P13.7
# 1      0.032293     FO538757.2
# 2      0.015803     AP006222.2
# 3      0.001178  RP4-669L17.10
# 4      0.000098   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002641
# 1       0.046556  0.029140  No selected    0.117222      0.131239
# 2       0.040168  0.022520  No selected    0.107113      0.122183
# 3       0.001608  0.000998  No selected    0.005131      0.005784
# 4       0.000339  0.000173  No selected    0.001196      0.001377
#
#    prevalence_1      featureID
# 0      0.000393   RP11-34P13.7
# 1      0.032293     FO538757.2
# 2      0.015803     AP006222.2
# 3      0.001178  RP4-669L17.10
# 4      0.000098   RP5-857K21.4
# =====
# Leiden_2
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002509
# 1       0.046556  0.029140  No selected    0.117222      0.124636
# 2       0.040168  0.022520  No selected    0.107113      0.104901
# 3       0.001608  0.000998  No selected    0.005131      0.005694
# 4       0.000339  0.000173  No selected    0.001196      0.001335
#
#    prevalence_1      featureID
# 0      0.001129   RP11-34P13.7
# 1      0.069904     FO538757.2
# 2      0.121228     AP006222.2
# 3      0.001540  RP4-669L17.10
# 4      0.000308   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002509
# 1       0.046556  0.029140  No selected    0.117222      0.124636
# 2       0.040168  0.022520  No selected    0.107113      0.104901
# 3       0.001608  0.000998  No selected    0.005131      0.005694
# 4       0.000339  0.000173  No selected    0.001196      0.001335
#
#    prevalence_1      featureID
# 0      0.001129   RP11-34P13.7
# 1      0.069904     FO538757.2
# 2      0.121228     AP006222.2
# 3      0.001540  RP4-669L17.10
# 4      0.000308   RP5-857K21.4
# =====
# Leiden_3
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002309
# 1       0.046556  0.029140  No selected    0.117222      0.121470
# 2       0.040168  0.022520  No selected    0.107113      0.111539
# 3       0.001608  0.000998  No selected    0.005131      0.005358
# 4       0.000339  0.000173  No selected    0.001196      0.001223
#
#    prevalence_1      featureID
# 0      0.002473   RP11-34P13.7
# 1      0.067491     FO538757.2
# 2      0.055300     AP006222.2
# 3      0.002473  RP4-669L17.10
# 4      0.000883   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002309
# 1       0.046556  0.029140  No selected    0.117222      0.121470
# 2       0.040168  0.022520  No selected    0.107113      0.111539
# 3       0.001608  0.000998  No selected    0.005131      0.005358
# 4       0.000339  0.000173  No selected    0.001196      0.001223
#
#    prevalence_1      featureID
# 0      0.002473   RP11-34P13.7
# 1      0.067491     FO538757.2
# 2      0.055300     AP006222.2
# 3      0.002473  RP4-669L17.10
# 4      0.000883   RP5-857K21.4
# =====
# Leiden_4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002407
# 1       0.046556  0.029140  No selected    0.117222      0.120175
# 2       0.040168  0.022520  No selected    0.107113      0.107185
# 3       0.001608  0.000998  No selected    0.005131      0.005352
# 4       0.000339  0.000173  No selected    0.001196      0.001271
#
#    prevalence_1      featureID
# 0      0.001195   RP11-34P13.7
# 1      0.077873     FO538757.2
# 2      0.106154     AP006222.2
# 3      0.002191  RP4-669L17.10
# 4      0.000199   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002407
# 1       0.046556  0.029140  No selected    0.117222      0.120175
# 2       0.040168  0.022520  No selected    0.107113      0.107185
# 3       0.001608  0.000998  No selected    0.005131      0.005352
# 4       0.000339  0.000173  No selected    0.001196      0.001271
#
#    prevalence_1      featureID
# 0      0.001195   RP11-34P13.7
# 1      0.077873     FO538757.2
# 2      0.106154     AP006222.2
# 3      0.002191  RP4-669L17.10
# 4      0.000199   RP5-857K21.4
# =====
# Leiden_5
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002456
# 1       0.046556  0.029140  No selected    0.117222      0.122471
# 2       0.040168  0.022520  No selected    0.107113      0.113316
# 3       0.001608  0.000998  No selected    0.005131      0.005344
# 4       0.000339  0.000173  No selected    0.001196      0.001250
#
#    prevalence_1      featureID
# 0      0.000422   RP11-34P13.7
# 1      0.042827     FO538757.2
# 2      0.019198     AP006222.2
# 3      0.002110  RP4-669L17.10
# 4      0.000422   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002456
# 1       0.046556  0.029140  No selected    0.117222      0.122471
# 2       0.040168  0.022520  No selected    0.107113      0.113316
# 3       0.001608  0.000998  No selected    0.005131      0.005344
# 4       0.000339  0.000173  No selected    0.001196      0.001250
#
#    prevalence_1      featureID
# 0      0.000422   RP11-34P13.7
# 1      0.042827     FO538757.2
# 2      0.019198     AP006222.2
# 3      0.002110  RP4-669L17.10
# 4      0.000422   RP5-857K21.4
# =====
# Leiden_6
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002307
# 1       0.046556  0.029140  No selected    0.117222      0.116902
# 2       0.040168  0.022520  No selected    0.107113      0.104956
# 3       0.001608  0.000998  No selected    0.005131      0.005143
# 4       0.000339  0.000173  No selected    0.001196      0.001205
#
#    prevalence_1      featureID
# 0      0.002592   RP11-34P13.7
# 1      0.122862     FO538757.2
# 2      0.145153     AP006222.2
# 3      0.004925  RP4-669L17.10
# 4      0.001037   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002307
# 1       0.046556  0.029140  No selected    0.117222      0.116902
# 2       0.040168  0.022520  No selected    0.107113      0.104956
# 3       0.001608  0.000998  No selected    0.005131      0.005143
# 4       0.000339  0.000173  No selected    0.001196      0.001205
#
#    prevalence_1      featureID
# 0      0.002592   RP11-34P13.7
# 1      0.122862     FO538757.2
# 2      0.145153     AP006222.2
# 3      0.004925  RP4-669L17.10
# 4      0.001037   RP5-857K21.4
# =====
# Leiden_7
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002364
# 1       0.046556  0.029140  No selected    0.117222      0.121982
# 2       0.040168  0.022520  No selected    0.107113      0.112394
# 3       0.001608  0.000998  No selected    0.005131      0.005374
# 4       0.000339  0.000173  No selected    0.001196      0.001263
#
#    prevalence_1      featureID
# 0      0.001573   RP11-34P13.7
# 1      0.032241     FO538757.2
# 2      0.012844     AP006222.2
# 3      0.000786  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002364
# 1       0.046556  0.029140  No selected    0.117222      0.121982
# 2       0.040168  0.022520  No selected    0.107113      0.112394
# 3       0.001608  0.000998  No selected    0.005131      0.005374
# 4       0.000339  0.000173  No selected    0.001196      0.001263
#
#    prevalence_1      featureID
# 0      0.001573   RP11-34P13.7
# 1      0.032241     FO538757.2
# 2      0.012844     AP006222.2
# 3      0.000786  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# =====
# Leiden_8
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002391
# 1       0.046556  0.029140  No selected    0.117222      0.120516
# 2       0.040168  0.022520  No selected    0.107113      0.110950
# 3       0.001608  0.000998  No selected    0.005131      0.005290
# 4       0.000339  0.000173  No selected    0.001196      0.001232
#
#    prevalence_1      featureID
# 0      0.000685   RP11-34P13.7
# 1      0.039384     FO538757.2
# 2      0.016438     AP006222.2
# 3      0.001370  RP4-669L17.10
# 4      0.000342   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002391
# 1       0.046556  0.029140  No selected    0.117222      0.120516
# 2       0.040168  0.022520  No selected    0.107113      0.110950
# 3       0.001608  0.000998  No selected    0.005131      0.005290
# 4       0.000339  0.000173  No selected    0.001196      0.001232
#
#    prevalence_1      featureID
# 0      0.000685   RP11-34P13.7
# 1      0.039384     FO538757.2
# 2      0.016438     AP006222.2
# 3      0.001370  RP4-669L17.10
# 4      0.000342   RP5-857K21.4
# =====
# Leiden_9
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002216
# 1       0.046556  0.029140  No selected    0.117222      0.105209
# 2       0.040168  0.022520  No selected    0.107113      0.096184
# 3       0.001608  0.000998  No selected    0.005131      0.004635
# 4       0.000339  0.000173  No selected    0.001196      0.001000
#
#    prevalence_1      featureID
# 0      0.004859   RP11-34P13.7
# 1      0.405068     FO538757.2
# 2      0.368969     AP006222.2
# 3      0.017008  RP4-669L17.10
# 4      0.005901   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002216
# 1       0.046556  0.029140  No selected    0.117222      0.105209
# 2       0.040168  0.022520  No selected    0.107113      0.096184
# 3       0.001608  0.000998  No selected    0.005131      0.004635
# 4       0.000339  0.000173  No selected    0.001196      0.001000
#
#    prevalence_1      featureID
# 0      0.004859   RP11-34P13.7
# 1      0.405068     FO538757.2
# 2      0.368969     AP006222.2
# 3      0.017008  RP4-669L17.10
# 4      0.005901   RP5-857K21.4
# =====
# Leiden_10
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002324
# 1       0.046556  0.029140  No selected    0.117222      0.119564
# 2       0.040168  0.022520  No selected    0.107113      0.109534
# 3       0.001608  0.000998  No selected    0.005131      0.005251
# 4       0.000339  0.000173  No selected    0.001196      0.001220
#
#    prevalence_1      featureID
# 0      0.002252   RP11-34P13.7
# 1      0.043694     FO538757.2
# 2      0.031081     AP006222.2
# 3      0.001351  RP4-669L17.10
# 4      0.000450   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002324
# 1       0.046556  0.029140  No selected    0.117222      0.119564
# 2       0.040168  0.022520  No selected    0.107113      0.109534
# 3       0.001608  0.000998  No selected    0.005131      0.005251
# 4       0.000339  0.000173  No selected    0.001196      0.001220
#
#    prevalence_1      featureID
# 0      0.002252   RP11-34P13.7
# 1      0.043694     FO538757.2
# 2      0.031081     AP006222.2
# 3      0.001351  RP4-669L17.10
# 4      0.000450   RP5-857K21.4
# =====
# Leiden_11
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002335
# 1       0.046556  0.029140  No selected    0.117222      0.117688
# 2       0.040168  0.022520  No selected    0.107113      0.103750
# 3       0.001608  0.000998  No selected    0.005131      0.005085
# 4       0.000339  0.000173  No selected    0.001196      0.001189
#
#    prevalence_1      featureID
# 0      0.001902   RP11-34P13.7
# 1      0.101759     FO538757.2
# 2      0.218735     AP006222.2
# 3      0.006657  RP4-669L17.10
# 4      0.001427   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002335
# 1       0.046556  0.029140  No selected    0.117222      0.117688
# 2       0.040168  0.022520  No selected    0.107113      0.103750
# 3       0.001608  0.000998  No selected    0.005131      0.005085
# 4       0.000339  0.000173  No selected    0.001196      0.001189
#
#    prevalence_1      featureID
# 0      0.001902   RP11-34P13.7
# 1      0.101759     FO538757.2
# 2      0.218735     AP006222.2
# 3      0.006657  RP4-669L17.10
# 4      0.001427   RP5-857K21.4
# =====
# Leiden_12
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002362
# 1       0.046556  0.029140  No selected    0.117222      0.118906
# 2       0.040168  0.022520  No selected    0.107113      0.108874
# 3       0.001608  0.000998  No selected    0.005131      0.005251
# 4       0.000339  0.000173  No selected    0.001196      0.001224
#
#    prevalence_1      featureID
# 0      0.000609   RP11-34P13.7
# 1      0.045094     FO538757.2
# 2      0.031688     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002362
# 1       0.046556  0.029140  No selected    0.117222      0.118906
# 2       0.040168  0.022520  No selected    0.107113      0.108874
# 3       0.001608  0.000998  No selected    0.005131      0.005251
# 4       0.000339  0.000173  No selected    0.001196      0.001224
#
#    prevalence_1      featureID
# 0      0.000609   RP11-34P13.7
# 1      0.045094     FO538757.2
# 2      0.031688     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# =====
# Leiden_13
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002343
# 1       0.046556  0.029140  No selected    0.117222      0.119128
# 2       0.040168  0.022520  No selected    0.107113      0.109032
# 3       0.001608  0.000998  No selected    0.005131      0.005169
# 4       0.000339  0.000173  No selected    0.001196      0.001207
#
#    prevalence_1      featureID
# 0      0.001338   RP11-34P13.7
# 1      0.027425     FO538757.2
# 2      0.016722     AP006222.2
# 3      0.003344  RP4-669L17.10
# 4      0.000669   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002343
# 1       0.046556  0.029140  No selected    0.117222      0.119128
# 2       0.040168  0.022520  No selected    0.107113      0.109032
# 3       0.001608  0.000998  No selected    0.005131      0.005169
# 4       0.000339  0.000173  No selected    0.001196      0.001207
#
#    prevalence_1      featureID
# 0      0.001338   RP11-34P13.7
# 1      0.027425     FO538757.2
# 2      0.016722     AP006222.2
# 3      0.003344  RP4-669L17.10
# 4      0.000669   RP5-857K21.4
# =====
# Leiden_14
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002315
# 1       0.046556  0.029140  No selected    0.117222      0.117784
# 2       0.040168  0.022520  No selected    0.107113      0.107833
# 3       0.001608  0.000998  No selected    0.005131      0.005194
# 4       0.000339  0.000173  No selected    0.001196      0.001200
#
#    prevalence_1      featureID
# 0      0.002817   RP11-34P13.7
# 1      0.079812     FO538757.2
# 2      0.059155     AP006222.2
# 3      0.000939  RP4-669L17.10
# 4      0.000939   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002315
# 1       0.046556  0.029140  No selected    0.117222      0.117784
# 2       0.040168  0.022520  No selected    0.107113      0.107833
# 3       0.001608  0.000998  No selected    0.005131      0.005194
# 4       0.000339  0.000173  No selected    0.001196      0.001200
#
#    prevalence_1      featureID
# 0      0.002817   RP11-34P13.7
# 1      0.079812     FO538757.2
# 2      0.059155     AP006222.2
# 3      0.000939  RP4-669L17.10
# 4      0.000939   RP5-857K21.4
# =====
# Leiden_15
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002339
# 1       0.046556  0.029140  No selected    0.117222      0.116473
# 2       0.040168  0.022520  No selected    0.107113      0.107850
# 3       0.001608  0.000998  No selected    0.005131      0.005101
# 4       0.000339  0.000173  No selected    0.001196      0.001170
#
#    prevalence_1      featureID
# 0      0.001057   RP11-34P13.7
# 1      0.173362     FO538757.2
# 2      0.051797     AP006222.2
# 3      0.007400  RP4-669L17.10
# 4      0.003171   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002339
# 1       0.046556  0.029140  No selected    0.117222      0.116473
# 2       0.040168  0.022520  No selected    0.107113      0.107850
# 3       0.001608  0.000998  No selected    0.005131      0.005101
# 4       0.000339  0.000173  No selected    0.001196      0.001170
#
#    prevalence_1      featureID
# 0      0.001057   RP11-34P13.7
# 1      0.173362     FO538757.2
# 2      0.051797     AP006222.2
# 3      0.007400  RP4-669L17.10
# 4      0.003171   RP5-857K21.4
# =====
# Leiden_16
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002300
# 1       0.046556  0.029140  No selected    0.117222      0.115977
# 2       0.040168  0.022520  No selected    0.107113      0.106764
# 3       0.001608  0.000998  No selected    0.005131      0.005034
# 4       0.000339  0.000173  No selected    0.001196      0.001164
#
#    prevalence_1      featureID
# 0      0.005008   RP11-34P13.7
# 1      0.265442     FO538757.2
# 2      0.148581     AP006222.2
# 3      0.016694  RP4-669L17.10
# 4      0.005008   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002300
# 1       0.046556  0.029140  No selected    0.117222      0.115977
# 2       0.040168  0.022520  No selected    0.107113      0.106764
# 3       0.001608  0.000998  No selected    0.005131      0.005034
# 4       0.000339  0.000173  No selected    0.001196      0.001164
#
#    prevalence_1      featureID
# 0      0.005008   RP11-34P13.7
# 1      0.265442     FO538757.2
# 2      0.148581     AP006222.2
# 3      0.016694  RP4-669L17.10
# 4      0.005008   RP5-857K21.4
# =====
# Leiden_17
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002320
# 1       0.046556  0.029140  No selected    0.117222      0.115838
# 2       0.040168  0.022520  No selected    0.107113      0.106502
# 3       0.001608  0.000998  No selected    0.005131      0.005032
# 4       0.000339  0.000173  No selected    0.001196      0.001160
#
#    prevalence_1      featureID
# 0      0.002725   RP11-34P13.7
# 1      0.386921     FO538757.2
# 2      0.226158     AP006222.2
# 3      0.024523  RP4-669L17.10
# 4      0.008174   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002320
# 1       0.046556  0.029140  No selected    0.117222      0.115838
# 2       0.040168  0.022520  No selected    0.107113      0.106502
# 3       0.001608  0.000998  No selected    0.005131      0.005032
# 4       0.000339  0.000173  No selected    0.001196      0.001160
#
#    prevalence_1      featureID
# 0      0.002725   RP11-34P13.7
# 1      0.386921     FO538757.2
# 2      0.226158     AP006222.2
# 3      0.024523  RP4-669L17.10
# 4      0.008174   RP5-857K21.4
# =====
# Leiden_18
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002319
# 1       0.046556  0.029140  No selected    0.117222      0.117244
# 2       0.040168  0.022520  No selected    0.107113      0.107160
# 3       0.001608  0.000998  No selected    0.005131      0.005154
# 4       0.000339  0.000173  No selected    0.001196      0.001201
#
#    prevalence_1      featureID
# 0      0.003115   RP11-34P13.7
# 1      0.112150     FO538757.2
# 2      0.096573     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002319
# 1       0.046556  0.029140  No selected    0.117222      0.117244
# 2       0.040168  0.022520  No selected    0.107113      0.107160
# 3       0.001608  0.000998  No selected    0.005131      0.005154
# 4       0.000339  0.000173  No selected    0.001196      0.001201
#
#    prevalence_1      featureID
# 0      0.003115   RP11-34P13.7
# 1      0.112150     FO538757.2
# 2      0.096573     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# =====
# Leiden_19
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002331
# 1       0.046556  0.029140  No selected    0.117222      0.117508
# 2       0.040168  0.022520  No selected    0.107113      0.107334
# 3       0.001608  0.000998  No selected    0.005131      0.005150
# 4       0.000339  0.000173  No selected    0.001196      0.001186
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.038462     FO538757.2
# 2      0.046154     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.003846   RP5-857K21.4
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002331
# 1       0.046556  0.029140  No selected    0.117222      0.117508
# 2       0.040168  0.022520  No selected    0.107113      0.107334
# 3       0.001608  0.000998  No selected    0.005131      0.005150
# 4       0.000339  0.000173  No selected    0.001196      0.001186
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.038462     FO538757.2
# 2      0.046154     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.003846   RP5-857K21.4
# =====
# Leiden_20
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002328
# 1       0.046556  0.029140  No selected    0.117222      0.116975
# 2       0.040168  0.022520  No selected    0.107113      0.106882
# 3       0.001608  0.000998  No selected    0.005131      0.005102
# 4       0.000339  0.000173  No selected    0.001196      0.001199
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.214286     FO538757.2
# 2      0.197802     AP006222.2
# 3      0.016484  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# Failed to plot legend
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002328
# 1       0.046556  0.029140  No selected    0.117222      0.116975
# 2       0.040168  0.022520  No selected    0.107113      0.106882
# 3       0.001608  0.000998  No selected    0.005131      0.005102
# 4       0.000339  0.000173  No selected    0.001196      0.001199
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.214286     FO538757.2
# 2      0.197802     AP006222.2
# 3      0.016484  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# =====
# Leiden_21
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002326
# 1       0.046556  0.029140  No selected    0.117222      0.117132
# 2       0.040168  0.022520  No selected    0.107113      0.107008
# 3       0.001608  0.000998  No selected    0.005131      0.005125
# 4       0.000339  0.000173  No selected    0.001196      0.001184
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.177570     FO538757.2
# 2      0.177570     AP006222.2
# 3      0.009346  RP4-669L17.10
# 4      0.009346   RP5-857K21.4
# Failed to plot legend
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002326
# 1       0.046556  0.029140  No selected    0.117222      0.117132
# 2       0.040168  0.022520  No selected    0.107113      0.107008
# 3       0.001608  0.000998  No selected    0.005131      0.005125
# 4       0.000339  0.000173  No selected    0.001196      0.001184
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.177570     FO538757.2
# 2      0.177570     AP006222.2
# 3      0.009346  RP4-669L17.10
# 4      0.009346   RP5-857K21.4
# =====
# Leiden_22
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002323
# 1       0.046556  0.029140  No selected    0.117222      0.117253
# 2       0.040168  0.022520  No selected    0.107113      0.107141
# 3       0.001608  0.000998  No selected    0.005131      0.005132
# 4       0.000339  0.000173  No selected    0.001196      0.001196
#
#    prevalence_1      featureID
# 0           0.0   RP11-34P13.7
# 1           0.0     FO538757.2
# 2           0.0     AP006222.2
# 3           0.0  RP4-669L17.10
# 4           0.0   RP5-857K21.4
# Failed to plot legend
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002323
# 1       0.046556  0.029140  No selected    0.117222      0.117253
# 2       0.040168  0.022520  No selected    0.107113      0.107141
# 3       0.001608  0.000998  No selected    0.005131      0.005132
# 4       0.000339  0.000173  No selected    0.001196      0.001196
#
#    prevalence_1      featureID
# 0           0.0   RP11-34P13.7
# 1           0.0     FO538757.2
# 2           0.0     AP006222.2
# 3           0.0  RP4-669L17.10
# 4           0.0   RP5-857K21.4
# =====
# Leiden_23
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002322
# 1       0.046556  0.029140  No selected    0.117222      0.117233
# 2       0.040168  0.022520  No selected    0.107113      0.107109
# 3       0.001608  0.000998  No selected    0.005131      0.005132
# 4       0.000339  0.000173  No selected    0.001196      0.001196
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.000000     FO538757.2
# 2      0.142857     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
# Failed to plot legend
#    meanAbundance  Variance       select  prevalence  prevalence_0  \
# 0       0.000839  0.000518  No selected    0.002322      0.002322
# 1       0.046556  0.029140  No selected    0.117222      0.117233
# 2       0.040168  0.022520  No selected    0.107113      0.107109
# 3       0.001608  0.000998  No selected    0.005131      0.005132
# 4       0.000339  0.000173  No selected    0.001196      0.001196
#
#    prevalence_1      featureID
# 0      0.000000   RP11-34P13.7
# 1      0.000000     FO538757.2
# 2      0.142857     AP006222.2
# 3      0.000000  RP4-669L17.10
# 4      0.000000   RP5-857K21.4
