# %%
from pathlib import Path

# Get the current working directory as a Path object
current_path = Path.cwd()
home_folder = 'evan_home'

# Traverse up the directory tree until you find the target folder
for parent in [current_path] + list(current_path.parents):
    if parent.name == home_folder:
        home_path = parent
        break
else:
    raise ValueError(f"Folder '{home_folder}' not found in the current working directory.")

print("Home Path:", home_path)
source_code_dir = home_path / 'Source_code'
dataset_dir = home_path / 'Dataset'
# Out:
# Home Path: c:\Users\evanlee\Documents\Bmi_NAS_evan\evan_home

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc
import os

# %%
clusters = [f'Leiden_{i}' for i in range(24)]
clusters
# Out:
# ['Leiden_0',
#  'Leiden_1',
#  'Leiden_2',
#  'Leiden_3',
#  'Leiden_4',
#  'Leiden_5',
#  'Leiden_6',
#  'Leiden_7',
#  'Leiden_8',
#  'Leiden_9',
#  'Leiden_10',
#  'Leiden_11',
#  'Leiden_12',
#  'Leiden_13',
#  'Leiden_14',
#  'Leiden_15',
#  'Leiden_16',
#  'Leiden_17',
#  'Leiden_18',
#  'Leiden_19',
#  'Leiden_20',
#  'Leiden_21',
#  'Leiden_22',
#  'Leiden_23']

# %% [markdown]
# ## Read PreLect features

# %%
# os.chdir(r"C:\Users\evanlee\Documents\GitHub\EvanPys\Progress\HCC_case_study\feature_selection_k3")
# os.chdir('/Users/evanli/Documents/EvanPys/Progress/HCC_case_study/feature_selection_k3')
os.chdir(source_code_dir / 'HCC_case_study/feature_selection_k3')

features_dict = {}
positive_features_dict = {}
# Read features for each leiden cluster
for celltype in clusters:
    try:
        feature_df = pd.read_csv(f'{celltype}_features.txt', names=['Gene', 'Weight', 'Tendency'], sep='\t')
        feature_df['abs_weight'] = feature_df['Weight'].abs()
        feature_df = feature_df.sort_values(by=['Tendency', 'abs_weight'], ascending=[False, False])
        feature_df.drop(columns=['abs_weight'], inplace=True)
        positive_df = feature_df.loc[feature_df['Tendency'] == 1, :]

        features_dict[celltype] = feature_df
        positive_features_dict[celltype] = positive_df
    except:
        print('skipping:', celltype)
        continue
    # print(celltype, 'Feature count:', feature_df.shape[0])
    # print(celltype, 'Positive feature count:', feature_df[feature_df['Tendency'] == 1].shape[0])
    # print('------------------')

count_df = pd.DataFrame(columns=['Feature_count', 'Positive_feature_count'])
for celltype in features_dict.keys():
    feature_df = features_dict[celltype]
    feature_count = feature_df.shape[0]
    positive_count = feature_df[feature_df['Tendency'] == 1].shape[0]
    count_df.loc[celltype] = [feature_count, positive_count]
# row_order = [f'Leiden_{i}' for i in range(24)]
# count_df = count_df.loc[row_order]
count_df
# Out:
#            Feature_count  Positive_feature_count
# Leiden_0              41                      27
# Leiden_1              91                      44
# Leiden_2              32                      13
# Leiden_3             117                      60
# Leiden_4              34                      21
# Leiden_5             182                      69
# Leiden_6              38                      21
# Leiden_7              63                      30
# Leiden_8              99                      48
# Leiden_9              69                      42
# Leiden_10             18                       7
# Leiden_11             33                      16
# Leiden_12             33                      14
# Leiden_13             20                       8
# Leiden_14             15                       6
# Leiden_15             47                      15
# Leiden_16             35                      17
# Leiden_17             15                       9
# Leiden_18             12                       6
# Leiden_19             31                      11
# Leiden_20              8                       0
# Leiden_21              8                       0
# Leiden_22              9                       0
# Leiden_23              8                       0

# %%
# write to query for ACT
# all features
all_text = ''
for celltype in clusters:
    features = features_dict[celltype]['Gene'].tolist()
    features = ', '.join(features)
    # print(features)
    text_celltype = f'{celltype}: {features}\n'
    all_text += text_celltype

# %%
print(all_text)
# Out:
# Leiden_0: MT-ND1, NDUFB9, NEAT1, TMEM176A, AMBP, SERPINA1, VTN, MPC2, MT-CO1, RARRES2, SPINK1, ANG, PRAP1, BNIP3, HSPA5, KRT18, TM4SF4, MDK, MT-CO2, NDUFC2, RBP4, SEC61G, CD63, COX6C, COX6A1, S100A10, HSP90B1, TUBA1B, B2M, PTMA, TMSB4X, CD74, H2AFZ, RPL10, ALB, HLA-DRA, APOA1, HMGB1, MT2A, ACTB, SRGN
# Leiden_1: IL7R, CXCR4, ANXA1, GZMK, ZFP36L2, CD3D, RGCC, CD69, RPS29, TRAC, LTB, LEPROTL1, RPS25, S100A4, CD52, RPS27, SRGN, TNFAIP3, RORA, CD3E, RP11-138A9.1, SARAF, GPR183, RPL28, RPL17, RPL31, CD2, RPS4Y1, RPL36A, CCL5, BTG1, BIRC3, AC090498.1, JUNB, RPS12, CD44, RPL10A, IL32, YPEL5, CREM, MCL1, ZFP36, RPS15A, RPL23A, NKG7, ACTB, CMC1, FTL, CD74, IGKC, HLA-DRA, DDX5, H3F3A, APOA2, ALB, GAPDH, HLA-DRB1, CD63, MALAT1, SAT1, HMGB1, MT-CO1, HLA-DPB1, NEAT1, MT-ND3, SRP14, UBB, HLA-C, MT-CO2, SERF2, HNRNPA2B1, MT-ND4, MYL6, HLA-A, CYBA, OAZ1, LGALS1, PPIA, HSPE1, ACTG1, TMBIM6, SUB1, FOS, HSPA5, HSP90AA1, MT-CO3, DUSP1, UBC, HLA-B, HLA-E, PFN1
# Leiden_2: C1QA, CTSB, TYROBP, GPNMB, LGMN, C1QB, C1QC, CCL3, CTSD, PSAP, FABP5, RNASE1, CCL4L2, RPL3, HLA-C, RPL10, EEF1A1, ALB, RPS27, RPL41, RPS18, RPLP1, MALAT1, RPS7, RPS4X, RPS19, RPS6, RPL6, RPL23A, APOA2, RPL15, RPL8
# Leiden_3: TYROBP, LST1, AIF1, LYZ, SAT1, HLA-DPB1, HLA-DRA, CST3, HLA-DPA1, NEAT1, GPX1, COTL1, FTH1, BCL2A1, IL1B, TIMP1, LGALS2, G0S2, SLC25A6, FCN1, HLA-DQB1, APOA2, NAP1L1, CSTA, SRGN, LSP1, RPL26, FCER1G, S100A6, LGALS1, C15orf48, RPS3A, SH3BGRL3, ENO1, RPS24, NAMPT, PLAUR, SOD2, ANXA1, S100A4, AP1S2, CSTB, RPL18A, MT2A, S100A10, GABARAP, RPS2, RPL29, PLIN2, C1orf162, CXCL8, RPL36A, UBA52, EEF1B2, GSTP1, RPL11, S100A11, ATP5G2, ARPC2, GNB2L1, B2M, C1QA, SEPP1, C1QB, FTL, APOE, APOC1, CTSD, HLA-A, CTSB, PRDX1, TMBIM6, TMSB4X, MT-ND3, MT-CO1, SRP14, MT-CO3, JUNB, ZFP36, UBB, CCL4, DYNLL1, PPIA, FOS, JUND, MT-ATP6, CALM1, COX6C, LGMN, MYL6, HSPA5, LIPA, OST4, MALAT1, SERF2, IGKC, HLA-E, MT-CO2, HSP90B1, UBC, CTSL, CD63, NR4A2, CREM, HSP90AB1, DDX5, ITM2B, GLUL, UQCRB, C1QC, JUN, CTSC, NDUFA4, RPLP1, TPT1, PPDPF, HINT1
# Leiden_4: RPL30, APOA2, RPL31, UQCRB, MGST1, COX6C, ALB, RPS18, TUBB, RPL8, TXN, SERPINA1, APOC1, APOA1, IFITM3, RPS6, PEBP1, GAPDH, MT1X, RPL37, PRDX6, MALAT1, MT-CO1, MT-ND1, NEAT1, MT-ND2, MT-ND4, MT-CO2, MT-CYB, CD74, HLA-B, B2M, NPC2, HLA-C
# Leiden_5: FGFBP2, NKG7, GNLY, GZMB, GZMH, TXNIP, CCL5, RPL13, RPS29, DDX5, MALAT1, EMP3, CD52, PRF1, IL32, HSPA1B, S100A4, CD53, EIF4A2, HLA-E, KLRD1, HSPA1A, FCGR3A, ITGB2, TRGC2, RPL21, RPS27, HSPA8, PFN1, CMC1, SH3BGRL3, CYBA, PLAC8, ANXA1, CD3G, CD69, CTSW, KLRG1, CST7, HSP90AA1, DUSP2, HCST, HSPE1, CD48, TRAC, HSPH1, PPP2R5C, LAPTM5, CD3E, CD37, SPON2, DNAJB1, BIN2, S100A10, TMSB10, S100A6, RAC2, LCK, CDC42SE1, CD3D, RPS3, IRF1, TSC22D3, RPLP2, CORO1A, DNAJA1, LRRFIP1, RPS14, RGS2, RPLP1, PTMA, ZFP36, FTL, EIF1, YPEL5, TPT1, CD74, MCL1, MT-CO1, FAM177A1, CALM2, H3F3A, RPS26, TUBA1B, ZNF331, GAPDH, MYL6, SRGN, CYCS, ATP5L, HERPUD1, CD63, HMGB2, ATP5E, CCNH, GSTP1, CD7, RPL8, NEAT1, IGHG4, SYTL3, CHCHD2, SELK, REL, RGS1, HLA-DRA, JUND, COX7C, NPM1, IGKC, ITM2B, RP11-138A9.1, ARHGDIB, RPS3A, RPS24, GZMK, TCEB2, RPLP0, RPS11, SUB1, RPS23, COX6C, SAMSN1, IGLC2, COX7A2, OAZ1, MT-ND2, H2AFZ, SUMO2, LEPROTL1, HMGB1, IFITM3, ELF1, BTG1, COX4I1, SAT1, RPS5, POLR2L, CREM, PARK7, VIM, RGCC, HINT1, TPI1, ZFP36L2, ATP5G2, SERF2, COX6A1, NFKBIA, NAP1L1, PABPC1, LDHA, RPL36AL, SRSF7, RPS4Y1, MT2A, ALB, SRSF2, RPL29, RPS9, PPP1CB, RPL28, TNFAIP3, BTF3, NDUFA4, UBC, MT-ND1, RPL24, COX8A, CST3, MT-ND4, COX5B, SKP1, SRP14, OST4, YWHAZ, FOS, TMSB4X, SDCBP, RPL37A, UBA52, JUNB
# Leiden_6: GNG11, IFI27, TM4SF1, SDPR, RAMP2, DNASE1L3, HSPG2, HYAL2, SOCS3, IGFBP7, FKBP1A, NEAT1, PCAT19, FCN3, HES1, TIMP3, APP, CLDN5, SPARC, ENG, IFITM3, FTL, ACTB, RPL41, RPLP1, CALM2, RPL21, RPS27, ALB, MT-CO1, FTH1, IGKC, EEF1A1, RPL10, MALAT1, HLA-DRA, CST3, RPL13A
# Leiden_7: CCL5, CMC1, CD3D, TUBA4A, TRGC2, CXCR4, RGS1, CREM, HLA-DRB1, YPEL5, FAM177A1, IL32, DUSP2, ZNF331, CST7, SRSF7, PIK3R1, MCL1, ZFP36L2, GZMK, PTPRC, ZFP36, JUND, CD3E, CALM2, RP11-138A9.1, SUB1, SELK, TRBC2, DDX24, B2M, TMSB10, NFKBIA, MT-CO1, FTH1, RPS24, MT-CO3, EEF1A1, MT-CO2, ACTB, RPL10, RPL7, TPT1, MALAT1, RPLP1, S100A4, RPS23, TXNIP, RPS3A, RPLP0, NEAT1, MT-ND4, RPS26, GNB2L1, RPL15, RPL29, IGKC, RPL26, RPL6, RPS8, MYL12A, FTL, RPL23
# Leiden_8: CD7, TYROBP, FCER1G, GZMK, KLRB1, CMC1, REL, AREG, YPEL5, B3GNT7, SRGN, KLRF1, GSTP1, CLIC3, CD160, IL2RB, HSPD1, FAM177A1, HSPE1, IFRD1, KLRC1, IFITM2, ALOX5AP, HSP90AB1, DNAJB6, NFKBIA, EVL, GZMA, XCL1, IRF8, HSP90AA1, ZNF331, DUSP1, ATP1B3, KLRD1, RGCC, NKG7, DNAJA1, HSPA1A, PIK3R1, VPS37B, DNAJB1, FYN, GADD45B, STK17A, CORO1A, IFITM1, H3F3B, B2M, FTL, CXCR4, HLA-E, HLA-DPB1, HLA-C, RPS20, TMSB10, RPL38, S100A4, RPL28, MALAT1, TUBA1B, IGKC, HLA-DRB1, FTH1, RPS25, RPL7A, MT2A, CYBA, EIF1, GZMB, NEAT1, PPIA, GAPDH, RPS16, ANXA1, MT-CYB, RPL36, RPL9, UQCRB, RPS12, SAT1, AC090498.1, RPS13, RPL39, H2AFZ, RPL36A, HLA-DRA, SH3BGRL3, UBA52, SUB1, RPS11, RGS1, RPL12, TOMM7, RPL14, PRF1, NPM1, RPL27A, S100A6
# Leiden_9: STMN1, H2AFZ, HIST1H4C, PTTG1, PDIA6, KRT18, GGH, HMGN2, ANXA4, NUCKS1, CD24, TUBA1B, RAN, MPC2, MT-ND1, TM4SF4, MGST1, LSM4, DEK, TXN, MT-ND4, CBX3, TXNDC12, LAPTM4A, KRT8, HSD17B11, RPN2, MT-CO1, ANXA2, BIRC5, CCT5, SPINK1, UGDH, RHEB, LSM5, NPM1, CKS1B, SRP9, TMEM14B, MDK, UBE2S, HMGB1, B2M, RPL10, ACTB, TMSB4X, APOA2, SRGN, RPL34, GAPDH, RPL21, UBC, APOA1, RPS6, HLA-DRA, FTL, CD74, APOC3, RPL31, EIF1, HSPA1A, EEF1A1, RPL13A, TPT1, RPL28, RPS15A, MALAT1, RPLP2, IGKC
# Leiden_10: MZB1, JCHAIN, IGHG1, IGKC, IGHG4, IGLC2, IGHG3, RPS27, ACTB, FTH1, FTL, MT-CO1, MT-CO3, APOA2, TMSB4X, HLA-A, EEF1A1, APOC1
# Leiden_11: CALD1, BGN, IGFBP7, TAGLN, COL1A2, MYL9, TPM2, LGALS1, TIMP1, RGS5, DCN, COL3A1, SPARC, MT2A, NDUFA4L2, COL6A2, TMSB10, B2M, RPS28, FTL, HLA-C, MT-CO1, RPLP1, ALB, NEAT1, APOA2, MT-CO2, RPS29, HLA-A, SRP14, IGKC, RPS18, RPL41
# Leiden_12: BATF, IL32, CARD16, TRAC, S100A4, TIGIT, SAT1, DUSP4, CD2, CTSC, SAMSN1, ARID5B, CD3D, RGS1, FTL, RPLP2, RPS12, MT-CO1, MALAT1, RPS27, ZFP36, MT-CO3, MT-CO2, RPLP1, MT-ND4, RPS18, RPL41, RPS27A, RPL10, RPL21, RPL27A, CXCR4, RPL23A
# Leiden_13: CD79A, HLA-DRA, MS4A1, CD52, CD37, CD74, EZR, LAPTM5, FTL, TMSB10, B2M, SRGN, TMSB4X, GAPDH, ACTB, NEAT1, HLA-C, IGHG1, FTH1, SERF2
# Leiden_14: STMN1, CORO1A, HMGB2, HIST1H4C, HMGN2, PFN1, FTL, RPS27, MALAT1, RPL41, MT-ND2, RPL10, EEF1A1, ALB, MT-CO1
# Leiden_15: MALAT1, MT-CO2, MT-CO3, MT-ND2, MT-ND3, NEAT1, MT-ND1, MT-CO1, MT-CYB, SERPINA1, KLF6, KRT8, MT-ND4, HSPA1A, TF, B2M, RPL10, TPT1, TMSB4X, FTL, EEF1A1, APOC1, RPS10, RPL39, RPS27A, RPS29, RPL9, RPL21, RPS15A, IGKC, APOC3, RPS16, UBB, RPL34, RPS28, RPL27A, RPL41, RPS27, RPS4X, RPS8, SOD1, RPL23A, RPLP1, RPS25, ATP5E, RPL7, RPS13
# Leiden_16: KRT8, TNFRSF12A, SOX4, RHOB, KRT18, ZFAS1, KLF6, PERP, ANXA4, TM4SF1, ELF3, ATP1B1, DEFB1, ATF3, S100A10, FXYD2, JUN, FTL, B2M, RPS29, EEF1A1, APOA1, RPLP1, SERPINA1, HLA-C, MT-CO2, HSP90AA1, TMSB4X, ACTB, APOC1, APOA2, PTMA, RPL10, HSP90B1, VTN
# Leiden_17: HP, ALDOB, ORM1, FGL1, APOC3, CFHR1, CFH, RARRES2, APOA1, B2M, FTH1, FTL, RPS18, RPL13, APOE
# Leiden_18: MARCO, C1QB, HLA-DRB5, C1QA, C1QC, CD5L, RPL41, MALAT1, MT-CO1, MT-ND4, MT-CO2, SERPINA1
# Leiden_19: GZMB, GPR183, ALOX5AP, TPSB2, TPSAB1, RGS2, AREG, SEC61B, SOX4, VIM, CAPG, FTL, HLA-C, MT-CO3, GAPDH, HLA-A, B2M, BTG1, MT-CO1, ACTB, TMSB10, RPL8, TMSB4X, RPLP1, MT-ATP6, MT-ND2, MT-CO2, RPS19, ALB, RPL41, IGHG1
# Leiden_20: MALAT1, FTL, B2M, RPL41, RPS27, RPS18, RPLP1, RPL10
# Leiden_21: MALAT1, FTL, B2M, RPL41, RPS18, RPS27, RPLP1, RPL10
# Leiden_22: MALAT1, FTL, B2M, MT-CO1, RPL41, RPS18, RPLP1, RPS19, RPL10
# Leiden_23: B2M, FTL, MT-CO1, RPL41, RPLP1, MALAT1, RPS18, RPS27

# %%
# positive features
positive_text = ''
for celltype in clusters:
    positive_features = positive_features_dict[celltype]['Gene'].tolist()
    positive_features = ', '.join(positive_features)

    text_celltype = f'{celltype}: {positive_features}\n'
    positive_text += text_celltype

# %%
print(positive_text)
# Out:
# Leiden_0: MT-ND1, NDUFB9, NEAT1, TMEM176A, AMBP, SERPINA1, VTN, MPC2, MT-CO1, RARRES2, SPINK1, ANG, PRAP1, BNIP3, HSPA5, KRT18, TM4SF4, MDK, MT-CO2, NDUFC2, RBP4, SEC61G, CD63, COX6C, COX6A1, S100A10, HSP90B1
# Leiden_1: IL7R, CXCR4, ANXA1, GZMK, ZFP36L2, CD3D, RGCC, CD69, RPS29, TRAC, LTB, LEPROTL1, RPS25, S100A4, CD52, RPS27, SRGN, TNFAIP3, RORA, CD3E, RP11-138A9.1, SARAF, GPR183, RPL28, RPL17, RPL31, CD2, RPS4Y1, RPL36A, CCL5, BTG1, BIRC3, AC090498.1, JUNB, RPS12, CD44, RPL10A, IL32, YPEL5, CREM, MCL1, ZFP36, RPS15A, RPL23A
# Leiden_2: C1QA, CTSB, TYROBP, GPNMB, LGMN, C1QB, C1QC, CCL3, CTSD, PSAP, FABP5, RNASE1, CCL4L2
# Leiden_3: TYROBP, LST1, AIF1, LYZ, SAT1, HLA-DPB1, HLA-DRA, CST3, HLA-DPA1, NEAT1, GPX1, COTL1, FTH1, BCL2A1, IL1B, TIMP1, LGALS2, G0S2, SLC25A6, FCN1, HLA-DQB1, APOA2, NAP1L1, CSTA, SRGN, LSP1, RPL26, FCER1G, S100A6, LGALS1, C15orf48, RPS3A, SH3BGRL3, ENO1, RPS24, NAMPT, PLAUR, SOD2, ANXA1, S100A4, AP1S2, CSTB, RPL18A, MT2A, S100A10, GABARAP, RPS2, RPL29, PLIN2, C1orf162, CXCL8, RPL36A, UBA52, EEF1B2, GSTP1, RPL11, S100A11, ATP5G2, ARPC2, GNB2L1
# Leiden_4: RPL30, APOA2, RPL31, UQCRB, MGST1, COX6C, ALB, RPS18, TUBB, RPL8, TXN, SERPINA1, APOC1, APOA1, IFITM3, RPS6, PEBP1, GAPDH, MT1X, RPL37, PRDX6
# Leiden_5: FGFBP2, NKG7, GNLY, GZMB, GZMH, TXNIP, CCL5, RPL13, RPS29, DDX5, MALAT1, EMP3, CD52, PRF1, IL32, HSPA1B, S100A4, CD53, EIF4A2, HLA-E, KLRD1, HSPA1A, FCGR3A, ITGB2, TRGC2, RPL21, RPS27, HSPA8, PFN1, CMC1, SH3BGRL3, CYBA, PLAC8, ANXA1, CD3G, CD69, CTSW, KLRG1, CST7, HSP90AA1, DUSP2, HCST, HSPE1, CD48, TRAC, HSPH1, PPP2R5C, LAPTM5, CD3E, CD37, SPON2, DNAJB1, BIN2, S100A10, TMSB10, S100A6, RAC2, LCK, CDC42SE1, CD3D, RPS3, IRF1, TSC22D3, RPLP2, CORO1A, DNAJA1, LRRFIP1, RPS14, RGS2
# Leiden_6: GNG11, IFI27, TM4SF1, SDPR, RAMP2, DNASE1L3, HSPG2, HYAL2, SOCS3, IGFBP7, FKBP1A, NEAT1, PCAT19, FCN3, HES1, TIMP3, APP, CLDN5, SPARC, ENG, IFITM3
# Leiden_7: CCL5, CMC1, CD3D, TUBA4A, TRGC2, CXCR4, RGS1, CREM, HLA-DRB1, YPEL5, FAM177A1, IL32, DUSP2, ZNF331, CST7, SRSF7, PIK3R1, MCL1, ZFP36L2, GZMK, PTPRC, ZFP36, JUND, CD3E, CALM2, RP11-138A9.1, SUB1, SELK, TRBC2, DDX24
# Leiden_8: CD7, TYROBP, FCER1G, GZMK, KLRB1, CMC1, REL, AREG, YPEL5, B3GNT7, SRGN, KLRF1, GSTP1, CLIC3, CD160, IL2RB, HSPD1, FAM177A1, HSPE1, IFRD1, KLRC1, IFITM2, ALOX5AP, HSP90AB1, DNAJB6, NFKBIA, EVL, GZMA, XCL1, IRF8, HSP90AA1, ZNF331, DUSP1, ATP1B3, KLRD1, RGCC, NKG7, DNAJA1, HSPA1A, PIK3R1, VPS37B, DNAJB1, FYN, GADD45B, STK17A, CORO1A, IFITM1, H3F3B
# Leiden_9: STMN1, H2AFZ, HIST1H4C, PTTG1, PDIA6, KRT18, GGH, HMGN2, ANXA4, NUCKS1, CD24, TUBA1B, RAN, MPC2, MT-ND1, TM4SF4, MGST1, LSM4, DEK, TXN, MT-ND4, CBX3, TXNDC12, LAPTM4A, KRT8, HSD17B11, RPN2, MT-CO1, ANXA2, BIRC5, CCT5, SPINK1, UGDH, RHEB, LSM5, NPM1, CKS1B, SRP9, TMEM14B, MDK, UBE2S, HMGB1
# Leiden_10: MZB1, JCHAIN, IGHG1, IGKC, IGHG4, IGLC2, IGHG3
# Leiden_11: CALD1, BGN, IGFBP7, TAGLN, COL1A2, MYL9, TPM2, LGALS1, TIMP1, RGS5, DCN, COL3A1, SPARC, MT2A, NDUFA4L2, COL6A2
# Leiden_12: BATF, IL32, CARD16, TRAC, S100A4, TIGIT, SAT1, DUSP4, CD2, CTSC, SAMSN1, ARID5B, CD3D, RGS1
# Leiden_13: CD79A, HLA-DRA, MS4A1, CD52, CD37, CD74, EZR, LAPTM5
# Leiden_14: STMN1, CORO1A, HMGB2, HIST1H4C, HMGN2, PFN1
# Leiden_15: MALAT1, MT-CO2, MT-CO3, MT-ND2, MT-ND3, NEAT1, MT-ND1, MT-CO1, MT-CYB, SERPINA1, KLF6, KRT8, MT-ND4, HSPA1A, TF
# Leiden_16: KRT8, TNFRSF12A, SOX4, RHOB, KRT18, ZFAS1, KLF6, PERP, ANXA4, TM4SF1, ELF3, ATP1B1, DEFB1, ATF3, S100A10, FXYD2, JUN
# Leiden_17: HP, ALDOB, ORM1, FGL1, APOC3, CFHR1, CFH, RARRES2, APOA1
# Leiden_18: MARCO, C1QB, HLA-DRB5, C1QA, C1QC, CD5L
# Leiden_19: GZMB, GPR183, ALOX5AP, TPSB2, TPSAB1, RGS2, AREG, SEC61B, SOX4, VIM, CAPG
# Leiden_20:
# Leiden_21:
# Leiden_22:
# Leiden_23:
